# %% [markdown]
# macros latex
# $$
# \def\R{{\mathbb R}}
# $$

# %% [markdown]
# # Notions de Calcul différentiel

# %% [markdown]
# ## Notion de dérivabilité en dimension 1
# **Rappel** : une fonction d'un intervalle ouvert $I \subset \R$ dans $\mathbb R$ est dite *dérivable* ou *différentiable* en $x \in I$ si la quantité
# $$\lim_{h \rightarrow 0, h \neq 0} \frac{f(x+h)-f(x)}{h}$$
# a une limite, qui est alors notée $f'(x)$.

# %% [markdown]
# Si on pose alors
# $$\epsilon(h) = \frac{f(x+h)-f(x)}{h} -f'(x)$$ la fonction $\epsilon$
# vérifie alors
# $$\lim_{h \to 0, h \neq 0} \epsilon(h) = 0.$$

# %% [markdown]
# On peut reformuler la notion de dérivabilité comme le fait que $f$ puisse s'écrire (pour $h$ assez petit) sous la forme
# $$f(x+h) = f(x) + h \cdot f'(x) + h \cdot\epsilon(h)$$
#
# avec $\epsilon$ une fonction qui tend vers $0$ en $0$.

# %% [markdown]
# La partie
# $$h \mapsto f(h) + h \cdot f'(x)$$
#
# est une approximation linéaire de $h \mapsto f(x+h)$ au voisinage de $0$ et la partie
#
# $$h \cdot \epsilon(h) = o(h)$$
#
# est une fonction **négligeable devant** $h$.

# %% [markdown]
# **exemple** Si $f(x) = x^3$ alors
# $$f(x+h) = (x+h)^3 = x^3 + 3x^2 h + 3x h^2 + h^3$$
# $$ = \boxed{f(x) + 3x^2 \cdot h} + h\cdot (3xh+h^2)$$
# L'application $h \mapsto 3x^2 \cdot h$ est linéaire, et $h \mapsto h(3xh+h^2)$ est négligeable devant $h$ (de la forme $h \times \epsilon(h)$ avec $\lim_{h \rightarrow 0} \epsilon(h) = 0$ ).
# On retrouve donc la formule $(x^3)' = 3x^2$.

# %% [markdown]
# Représentation graphique des fonctions
# $$h \mapsto f(2+h) = (2+h)^3$$
# et
# $$h \mapsto f(2) + h f'(2) = 8+12h$$

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 12))
h = np.linspace(-3,2,100)
plt.plot(h, (2+h)**3, color='red', label= "f(2+h)")
plt.plot(h, 8 + 12*h, color = 'green', label= "f(2) + h f'(2)")
plt.grid()
plt.axhline()
plt.axvline()
plt.legend(fontsize=20)
plt.close()

# %%
fig

# %% [markdown]
# ## L'espace ${\mathbb R}^n$
# ${\mathbb R}^n$ est l'espace vectoriel des $n$-uplets de réels de la forme
# $$x = (x_1, x_2, \dots, x_n)$$
# On peut identifier dans la base canonique ce vecteur à une matrice (vecteur colonne) de dimension $n \times 1$.
# $${\bf x} = \begin{pmatrix}
# x_1 \\
# x_2 \\
# \dots \\
# x_n
# \end{pmatrix}$$

# %% [markdown]
# On peut mesurer les distances en utilisant des **normes**. La norme d'un vecteur mesure sa "longueur" qui peut aussi être vue comme sa distance à $\bf 0$.
#
# Norme 2 (euclidienne) : $\|x\|_2 = \sqrt{\sum_{i=1}^n x_i^2}$
# Norme 1 : $\|x\|_1 = \sum_{i=1}^n | x_i | $
# Norme infinie : $\|x\|_\infty = \max_{1 \leq i \leq n} \| x_i \| $

# %% [markdown]
# On peut alors mesurer des distances entre vecteurs par
# $$d(x,y) = \|x-y\|$$
#
# Pour les propriétés topologiques (continuité, limites) on peut utiliser de façon *équivalente* n'importe laquelle de ces normes.

# %% [markdown]
# Une application linéaire de $\R^n$ dans $\R^m$ est une application
# $$ f :  \R^n \rightarrow \R^m$$
# qui vérifie
# $$\forall x,y \in \R^n, f(x+y) = f(x) + f(y)$$
# $$\forall \lambda \in \R, \forall x \in \R^n, f(\lambda x) = \lambda f(x)$$

# %% [markdown]
# **exemple :** $f$ de $\R^3$ dans $\R^2$ définie par
#
# $$f(x_1,x_2,x_3) = (2x_1+x_2-x_3, x_1+3x_3)$$
# est linéaire.

# %% [markdown]
# Une telle application peut s'écrire sous la forme
# $$f(x_1, x_2, \dots, x_n) = ( \sum_{j=1}^n a_{1,j} x_j, \sum_{i=j}^n a_{2,i} x_j, \dots, \sum_{i=1}^n a_{m,j} x_j )$$

# %% [markdown]
# On peut représenter $f$ par une matrice à $m$ lignes et $n$ colonnes
# $$ A = (a_{i,j})_{1\leq i \leq m, 1 \leq j \leq m} $$
# Les espaces $\R^n$ et $\R^m$ sont identifiés à l'ensemble des  vecteurs colonnes $n \times 1$ et $m \times 1$
# et l'application linéaire correspond au produit matriciel
# $$ Y = A X $$
# $$ (m,1) \sim (m,n) \cdot (n,1)$$

# %% [markdown]
# **cas particulier** Les applications linéaires sur $\R^n$ à valeur dans $\R$ (formes linéaires) sont représentées par des matrices de dimensions $(1,n)$ donc des matrices ligne.
#
# On peut représenter une telle ligne comme la transposée d'un vecteur colonne donc une forme linéaire
# peut s'écrire sous la forme
#
# $$f({\bf x}) = {\bf a}^T \bf x$$
#
# où $\bf a$ est un vecteur colonne de dimension $n$. Le produit
# $${\bf a}^T {\bf x} = \sum_{j=1}^n a_i x_i$$
# est aussi le produit scalaire (euclidien) des vecteurs.

# %% [markdown]
# **exemple :** $f$ de $\R^3$ dans $\R$
#
# $$ f(x_1,x_2,x_3) = 3x_1-x_2-2x_3 $$
# est représentée par le vecteur
# $${\bf a} = \begin{pmatrix}
# 3 \\
# -1 \\
# -2
# \end{pmatrix}$$

# %% [markdown]
# ## Différentielle en dimension $n$
# Soit maintenant $f$ une fonction de ${\mathbb R}^n$ dans ${\mathbb R}$. La différentielle $\ell$ de $f$ en un point $x$ est une approximation linéaire de $f$ et $x$, elle doit donc réaliser
# $$f(x+h) = f(x) + \ell(h) + o(h)$$
# Ici $h \mapsto \ell(h)$ doit être une *application linéaire* (forme linéaire en fait) de ${\mathbb R}^n$ dans ${\mathbb R}$
# et $o(h)$ est une fonction qui est négligeable devant $h$.

# %% [markdown]
# Rappel : une application linéaire de  ${\mathbb R}^n$ dans ${\mathbb R}$ peut s'écrire dans une base
# sous la forme
# $$\ell(h) = \sum_{i=1}^n a_i h_i$$
# On peut représenter ce calcul aussi comme le produit matriciel ${\bf a}^T \cdot \bf h$ où $\bf a$ et $\bf h$ sont les vecteurs colonnes correspondant à $a$ et $h$.

# %% [markdown]
# **exemple :** Soit $f(x_1,x_2) = (x_1+3x_2)^2$. On considère sa différentielle au point $x =(x_1,x_2)$.
#
# On a $$f(x_1 + h_1, x_2 + h_2) = (x_1 + h_1 +3 x_2 + 3 h_2)^2$$
# $$ = (x_1 + 3x_2)^2 + 2(x_1+3x_2)(h_1+3h_2) + (h_1+3h_2)^2$$

# %% [markdown]
# On peut facilement montrer que $h = (h_1,h_2) \mapsto (h_1+3h_2)^2$ est un $o(h)$ (négligeable) car
# $$| (h_1+3h_2)^2 | = (h_1+3h_2)  (h_1+3h_2) \leq 3 (|h_1| + |h_2|) (h_1 + 3h_2)$$
# donc est de la forme $\|h\|_1 \epsilon(h)$.

# %% [markdown]
# On peut donc écrire que
# $$f(x+h) = f(x) +  2(x_1+3x_2)h_1 + 6(x_1+3x_2) h_2 + o(h)$$
# La différentielle de $f$ en $x=(x_1,x_2)$ est l'application linéaire à valeurs dans $\R$
# $$h = (h_1,h_2) \mapsto 2(x_1+3x_2)h_1 + 6(x_1+3x_2) h_2 $$
# et peut être représentée par le vecteur
# $${\bf a} = \begin{pmatrix}
# 2 x_1+ 6 x_2 \\
# 6 x_1 + 18x_2
# \end{pmatrix}$$

# %% [markdown]
# Rappel : $f(x_1,x_2) = (x_1+3x_2)^2$
#
# On a $$\frac{\partial f}{\partial x_1}(x) = 2(x_1 + 3 x_2) = 2x_1 + 6 x_2$$
# et
# $$\frac{\partial f}{\partial x_2}(x) = 3 \times 2(x_1 + 3 x_2) = 6 x_1 + 18 x_2$$
# On retrouve les coordonnées du vecteur de la différentielle.

# %% [markdown]
# Le vecteur $a$ représentant la différentielle de $f$ est appelé le **gradient de f en x** et est noté $grad(f)(x)$ ou  $\nabla f (x)$ et ses coordonnées sont
# $$\nabla f (x) = (\frac{\partial f}{\partial x_1}(x), \frac{\partial f}{\partial x_2}(x), \dots, \frac{\partial f}{\partial x_n}(x))^T$$
# où $\frac{\partial f}{\partial x_i}(x)$ est la dérivée partielle de $f$ par rapport à $x_i$.

# %% [markdown]
# L'ensemble des vecteurs $h$ tels que $\langle \nabla f (x), h\rangle > 0$ forme un demi-espace et  ces vecteurs sont appelés directions de montée ; à l'inverse les vecteurs $h$ tels que $\langle \nabla f (x), h\rangle < 0$ sont les directions de descente.
# Si h est une direction de descente alors
# $$ f(x+h) = f(x) + \langle \nabla f (x), h\rangle + o(||h||) < f(x) $$
# si $h$ est assez petit ($||h|| < \epsilon$ pour un $\epsilon > 0$).

# %% [markdown]
# <img src="images/gradient.png" width=400 alt="schéma gradient" align="left"/>

# %% [markdown]
# ** exemple ** Toujours avec  $f(x_1,x_2) = (x_1+3x_2)^2$ et
# $${\bf \nabla f(x)} = \begin{pmatrix}
# 2 x_1+ 6 x_2 \\
# 6 x_1 + 18x_2
# \end{pmatrix}$$
#
# En $x_0 = (2,1)$ on a $\nabla f(x) = (10, 30)^T$. Toutes les directions $h=(h_1,h_2)$ vérifiant
# $$\langle \nabla f(x), h \rangle = 10 h_1 + 30 h_2 > 0$$
# sont des directions de montée et donc vérifient $f(x_0+h) > f(x_0)$ pour $h$ assez petit,
# et les directions vérifiant  $10 h_1 + 30 h_2 < 0$ sont des directions de descente.

# %% [markdown]
# ## gradient et extremums
# **Propriété** : Si $f$ admet un gradient en $x$ et que $x$ est un minimum ou un maximum local de $f$, alors
# $$\nabla f(x) = 0$$
# Attention, la réciproque est fausse. Considérer $f(x)=x^3$ en $x=0$.
#
# Trouver les $x$ qui annulent le gradient permet trouver les candidats potentiels à être un minimum ou maximum.

# %% [markdown]
# *preuve* (cas du minimum) Si $\nabla f (x) \neq 0$ alors si $t$ est suffisament petit on a
# (en postant $h = - t \nabla f(x)$)
# $$f(x - t \nabla f(x) )  = f(x)  -  \langle \nabla f(x), t \nabla f(x) \rangle + o(t)$$
# soit
# $$f(x - t \nabla f(x) )  = f(x)  -  t ||\nabla f(x)||^2 + o(t)$$
# qui est $ < f(x)$ pour $t$ assez petit, contredisant le fait que $f$ est un minimum local.

# %% [markdown]
# <img src="images/convex2d.png" width=800>
# Une fonction convexe sur $\R^2$

# %% [markdown]
# **exemple**  $f(x_1,x_2) = 2 x_1^2 -4 x_1 + 2x_1 x_2 + x_2^2$ fonction continue qui tend vers $+\infty$ quand $x,y$ tend vers l'infini donc admet (au moins) un minimum. On peut le trouver car
#
# $$\nabla f(x_1,x_2) = (4x_1-4 +2x_2, 2x_1 + 2x_2)^T = \bf 0$$
#
# seulement si $x = (2,-2) $
#
# Comme $f$ doit avoir un minimum c'est forcément $(2,-2)$.

# %%
import numpy as np
a1 = np.arange(0,4,0.05)
b1 = np.arange(-4,0,0.05)
A, B = np.meshgrid(a1,b1)

# %%
import matplotlib.pyplot as plt
f = lambda x1,x2: 2*x1**2 - 4*x1 +2*x1*x2 + x2**2
Z = f(A,B) ; levels = [-4+i*0.1 for i in range(50)]
plt.figure(figsize=(8,8))
cp = plt.contourf(A, B, Z, levels)
plt.colorbar(cp) ; plt.show()

# %% [markdown]
# ## Descente de gradient
# ### algorithme
# Bien souvent (en grande dimension) il n'est pas possible de résoudre le système d'équations $\nabla f(x)=\bf 0$.
# On utilise alors une méthode *itérative*.
# La *descente de gradient* est un algorithme pour calculer un minimum d'une fonction.
# L'algorithme produit une suite de points (vecteurs) $p_0, p_1, p_2, \dots$ et va s'arrêter quand le gradient de $f$
# est suffisament petit ( $\| \nabla f\| <  \epsilon$ )

# %% [markdown]
# * paramètres : choisir $\epsilon >0$ la tolérance, et $\alpha > 0$ le pas de gradient
# * Initialisation : choisir $p_0$, poser $k =0$
# * Tant que $\| \nabla f(p_k)\| \geq \epsilon$ répéter :
#     * $\displaystyle p_{k+1} = p_k - \alpha \nabla f(p_k)$
#     * $k \leftarrow k+1$

# %% [markdown]
# Dans le cas général il n'y a pas de garantie de trouver un minimum par cette manière. Cependant si $f$ est convexe (forme en bol comme $x^2$ ) alors la méthode convergera vers l'unique minimum de $f$. Il peut être nécessaire pour cela de faire diminuer le pas lorsqu'on approche du minimum.

# %% [markdown]
# ### Exemple
# On considère la fonction sur ${\mathbb R}^3$
# $$f(x_1,x_2,x_3) = 7x_1^2 - 6 x_1 x_2 + 5 x_2^2 - 12x_1 x_3 + 8 x_2 x_3 + 6 x_3^2 - 36x_1 + 44x_2 + 40x_3 + 100$$

# %%
f = lambda x1,x2,x3 : 7*x1**2 - 6*x1*x2 + 5*x2**2 - 12*x1*x3 + 8*x2*x3 + 6*x3**2 - 36*x1 + 44*x2 + 40*x3 + 100
diff = lambda x1,x2,x3 : np.array((14*x1 - 6*x2 - 12*x3 - 36, -6*x1 + 10*x2 + 8*x3 + 44, -12*x1 + 8*x2 + 12*x3 + 40))

# %%
import numpy as np
def descente_gradient(f, diff, epsilon, alpha, p0):
    p = p0
    k = 0
    points = [p0]
    while (diff(*p)**2).sum() >= epsilon**2 and k<10000:
        p = p - alpha*diff(*p)
        print( "f(" +str(p)+ ")=" + str(f(*p)))
        k +=1
        points.append(p)
    return k, np.array(points)

# %%
descente_gradient(f, diff, 0.01, 0.06, np.array((20.0,20.0,20.0)))
# Out:
# f([26.96  2.96  8.  ])=2217.8496000000005
# f([13.2992  4.4096 17.8304])=1202.8839628799994
# f([18.713216 -4.64704  10.051328])=680.3317567487995
# f([10.71813632 -2.58669568 16.11846656])=401.1847629928656
# f([14.54898729 -7.55301315 11.07184271])=246.55982819381614
# f([ 9.74047999 -5.73805434 14.80083312])=157.97252876672678
# f([12.30937708 -8.53304884 11.51164495])=105.6613764399699
# f([ 9.34598711 -7.14743336 13.78187553])=73.93017175279442
# f([11.00523231 -8.74971823 11.61880388])=54.20400368879348
# f([ 9.1364774  -7.75502953 12.9768971 ])=41.64412401563368
# f([10.17339167 -8.68179056 11.53420909])=33.44259158361683
# f([ 8.96692861 -7.98671558 12.32168001])=27.932185053744888
# f([ 9.59110058 -8.52099834 11.33988248])=24.105008383829215
# f([ 8.79173208 -8.03874672 11.77083871])=21.34330881800986
# f([ 9.14773219 -8.34047772 11.08448036])=19.264491176172157
# f([ 8.60189103 -8.00355808 11.29345098])=17.629695406610892
# f([ 8.78630636 -8.16559893 10.79723569])=16.288828541950522
# f([ 8.4002031  -7.92584241 10.86885406])=15.147032047399875
# f([ 8.47630415 -8.0033138  10.49582973])=14.144005464060797
# f([ 8.1920131  -7.82785429 10.48336194])=13.241158269270272
# f([ 8.20071515 -7.85403073 10.19096084])=12.41358194400459
# f([ 7.98215516 -7.72101604 10.12791869])=11.645014176051859
# f([ 7.94968051 -7.71623153  9.88905665])=10.924671152151632
# f([ 7.77422632 -7.61135482  9.79649696])=10.245250898657787
# f([ 7.71726629 -7.588139    9.59391241])=9.60167280374651
# f([ 7.57064951 -7.50211769  9.48503392])=8.990280860877135
# f([ 7.49976597 -7.46822954  9.30769363])=8.408339418967557
# f([ 7.37293934 -7.39506901  9.1907359 ])=7.853713625406556
# f([ 7.2947753  -7.35532267  9.0315555 ])=7.3246665742721575
# f([ 7.18196785 -7.2911566   8.91162864])=6.819730244053801
# f([ 7.1006711  -7.24853596  8.76602804])=6.337623116494115
# f([ 6.99817461 -7.19086625  8.6462683 ])=5.877197344666911
# f([ 6.91630927 -7.14721242  8.51125665])=5.437404639388433
# f([ 6.8217178  -7.09441682  8.3935565 ])=5.017274024616711
# f([ 6.74084547 -7.05085544  8.26715271])=4.615897129270195
# f([ 6.65257726 -7.00187111  8.15262211])=4.232418274170072
# f([ 6.57362668 -6.95907924  8.03348795])=3.8660276190818195
# f([ 6.49062307 -6.91320031  7.92274587])=3.5159562712755132
# f([ 6.41412461 -6.87157384  7.8099536 ])=3.181472659583676
# f([ 6.33565995 -6.8283224   7.70331217])=2.861879732603768
# f([ 6.26189429 -6.78808122  7.59619732])=2.556512700829046
# f([ 6.18745592 -6.74712526  7.49377812])=2.264737144446485
# f([ 6.1165481  -6.70837947  7.39184626])=1.9859473730836612
# f([ 6.04576039 -6.66948068  7.29365373])=1.7195649646596394
# f([ 5.97773931 -6.63227232  7.19652125])=1.465037436374189
# f([ 5.91031556 -6.59525298  7.10248897])=1.2218370172961386
# f([ 5.84515147 -6.5595823   7.00984554])=0.9894595024297246
# f([ 5.7808634  -6.52430425  6.91986531])=0.7674231747608928
# f([ 5.71849164 -6.49014623  6.83144997])=0.5552677860221138
# f([ 5.65715    -6.45649749  6.74539016])=0.35255358960966987
# f([ 5.59748582 -6.42381227  6.66097604])=0.1588604208363904
# f([ 5.53892806 -6.39169851  6.57869297])=-0.026213179164756184
# f([ 5.48187597 -6.36043793  6.49807752])=-0.2030507988308159
# f([ 5.42595832 -6.32977704  6.41942261])=-0.3720189532946847
# f([ 5.37141788 -6.29988867  6.3424213 ])=-0.5334678453496338
# f([ 5.31801027 -6.27060726  6.2672454 ])=-0.6877320921148851
# f([ 5.26587972 -6.24203699  6.19368759])=-0.8351314190877019
# f([ 5.2148625  -6.21406814  6.12184368])=-0.9759713231361218
# f([ 5.16504092 -6.18676172  6.05156994])=-1.1105437058776886
# f([ 5.11630268 -6.16004353  5.98291467])=-1.2391274788014641
# f([ 5.06869132 -6.13394749  5.91577493])=-1.3619891414178653
# f([ 5.02212747 -6.10842209  5.85016953])=-1.4793833336533453
# f([ 4.9766305  -6.08348432  5.78602185])=-1.5915533636436408
# f([ 4.93214225 -6.05909723  5.72333255])=-1.6987317120295131
# f([ 4.88866719 -6.03526731  5.66204221])=-1.8011405138037162
# f([ 4.84616091 -6.01196699  5.60214051])=-1.8989920187102598
# f([ 4.80461879 -5.98919631  5.54357936])=-1.992489031153582
# f([ 4.76400547 -5.96693385  5.48634198])=-2.0818253305284316
# f([ 4.72431091 -5.94517572  5.43038794])=-2.1671860728441175
# f([ 4.6855058  -5.92390457  5.37569683])=-2.248748174475395
# f([ 4.647577   -5.90311422  5.32223348])=-2.3266806788353733
# f([ 4.61049931 -5.88279004  5.26997564])=-2.401145106730695
# f([ 4.57425794 -5.86292457  5.2188919 ])=-2.472295791125873
# f([ 4.53883059 -5.84350508  5.16895924])=-2.5402801970097357
# f([ 4.50420172 -5.82452346  5.12014906])=-2.6052392270273117
# f([ 4.47035115 -5.80596831  5.07243823])=-2.6673075135114743
# f([ 4.43726312 -5.78783126  5.02580032])=-2.7266136975173936
# f([ 4.40491908 -5.77010194  4.98021254])=-2.7832806954416753
# f([ 4.37330338 -5.75277193  4.93565018])=-2.837425953774698
# f([ 4.34239877 -5.73583164  4.89209101])=-2.889161692517689
# f([ 4.31218994 -5.71927278  4.84951179])=-2.9385951377663275
# f([ 4.28266068 -5.70308639  4.80789099])=-2.9858287439450066
# f([ 4.25379612 -5.68726439  4.76720663])=-3.030960406150939
# f([ 4.22558097 -5.67179834  4.72743797])=-3.074083663049464
# f([ 4.1980009  -5.65668041  4.68856413])=-3.115287890738557
# f([ 4.17104137 -5.64190263  4.6505652 ])=-3.1546584879886836
# f([ 4.14468862 -5.62745745  4.6134213 ])=-3.1922770532369498
# f([ 4.11892884 -5.6133373   4.57711335])=-3.2282215537064474
# f([ 4.09374879 -5.59953495  4.54162241])=-3.262566486998651
# f([ 4.06913536 -5.58604317  4.50693018])=-3.295383035495206
# f([ 4.04507585 -5.57285502  4.47301863])=-3.3267392138889704
# f([ 4.02155774 -5.55996365  4.43987024])=-3.3567000101488986
# f([ 3.9985689  -5.54736239  4.40746779])=-3.385327520212627
# f([ 3.97609737 -5.53504469  4.37579453])=-3.412681076684976
# f([ 3.95413155 -5.5230042   4.34483403])=-3.438817371808625
# f([ 3.93266004 -5.51123465  4.31457026])=-3.463790574963639
# f([ 3.91167172 -5.49972997  4.28498753])=-3.4876524449367707
# f([ 3.89115571 -5.48848419  4.25607053])=-3.5104524371956245
# f([ 3.87110139 -5.47749148  4.22780427])=-3.5322378063888493
# f([ 3.85149837 -5.46674614  4.20017411])=-3.5530537042845367
# f([ 3.83233648 -5.45624261  4.17316572])=-3.5729432733508872
# f([ 3.81360581 -5.44597546  4.14676513])=-3.591947736172017
# f([ 3.79529666 -5.43593935  4.12095864])=-3.6101064808844967
# f([ 3.77739952 -5.42612909  4.0957329 ])=-3.6274571428127445
# f([ 3.75990514 -5.4165396   4.07107483])=-3.6440356824700757
# f([ 3.74280444 -5.40716591  4.04697166])=-3.659876460090402
# f([ 3.72608858 -5.39800316  4.0234109 ])=-3.6750123068420635
# f([ 3.70974888 -5.38904661  4.00038035])=-3.6894745928723296
# f([ 3.69377689 -5.38029161  3.97786806])=-3.7032932923248154
# f([ 3.67816433 -5.37173363  3.95586239])=-3.7164970454633135
# f([ 3.66290311 -5.36336824  3.93435193])=-3.7291132180300224
# f([ 3.64798532 -5.35519111  3.91332554])=-3.7411679579637394
# f([ 3.63340324 -5.34719798  3.89277231])=-3.7526862495929834
# f([ 3.61914931 -5.33938474  3.87268161])=-3.763691965418218
# f([ 3.60521614 -5.33174732  3.85304303])=-3.7742079155889883
# f([ 3.59159653 -5.32428177  3.83384638])=-3.784255895179797
# f([ 3.5782834  -5.31698422  3.81508174])=-3.7938567293620054
# f([ 3.56526988 -5.3098509   3.79673936])=-3.8030303165652697
# f([ 3.5525492  -5.3028781   3.77880976])=-3.81179566971889
# f([ 3.54011479 -5.29606221  3.76128364])=-3.820170955657261
# f([ 3.52796019 -5.28939971  3.74415193])=-3.8281735327720128
# f([ 3.51607912 -5.28288714  3.72740574])=-3.835819986988355
# f([ 3.50446542 -5.27652113  3.7110364 ])=-3.843126166141076
# f([ 3.49311307 -5.27029837  3.69503544])=-3.850107212819637
# f([ 3.48201619 -5.26421565  3.67939455])=-3.8567775957533286
# f([ 3.47116903 -5.25826982  3.66410565])=-3.863151139797509
# f([ 3.46056598 -5.25245779  3.6491608 ])=-3.8692410545876044
# f([ 3.45020153 -5.24677655  3.63455226])=-3.8750599619166337
# f([ 3.44007032 -5.24122315  3.62027248])=-3.880619921894919
# f([ 3.4301671  -5.23579474  3.60631404])=-3.8859324579454437
# f([ 3.42048674 -5.23048848  3.59266971])=-3.8910085806870143
# f([ 3.41102422 -5.22530163  3.57933244])=-3.8958588107545324
# f([ 3.40177465 -5.2202315   3.5662953 ])=-3.9004932006040747
# f([ 3.39273322 -5.21527547  3.55355155])=-3.904921355346943
# f([ 3.38389526 -5.21043097  3.54109458])=-3.909152452657054
# f([ 3.37525619 -5.20569549  3.52891794])=-3.9131952617925094
# f([ 3.36681153 -5.20106658  3.51701532])=-3.9170581617705125
# f([ 3.3585569  -5.19654183  3.50538055])=-3.920749158733088
# f([ 3.35048804 -5.19211891  3.4940076 ])=-3.9242759025412113
# f([ 3.34260075 -5.18779552  3.48289059])=-3.9276457026286664
# f([ 3.33489096 -5.18356942  3.47202376])=-3.930865543152237
# f([ 3.32735467 -5.17943843  3.46140147])=-3.9339420974665984
# f([ 3.31998797 -5.17540039  3.45101822])=-3.9368817419549202
# f([ 3.31278705 -5.17145323  3.44086863])=-3.939690569245329
# f([ 3.30574818 -5.1675949   3.43094744])=-3.942374400837309
# f([ 3.2988677  -5.16382339  3.42124952])=-3.9449387991677156
# f([ 3.29214207 -5.16013675  3.41176984])=-3.947389079139498
# f([ 3.28556778 -5.15653308  3.40250349])=-3.9497303191366484
# f([ 3.27914145 -5.1530105   3.39344566])=-3.9519673715500403
# f([ 3.27285972 -5.1495672   3.38459167])=-3.9541048728341366
# f([ 3.26671937 -5.14620138  3.37593692])=-3.9561472531162565
# f([ 3.26071719 -5.1429113   3.36747694])=-3.9580987453789476
# f([ 3.25485008 -5.13969527  3.35920734])=-3.9599633942321475
# f([ 3.249115   -5.1365516   3.35112384])=-3.9617450642967356
# f([ 3.24350899 -5.13347868  3.34322225])=-3.9634474482143673
# f([ 3.23802913 -5.13047492  3.33549847])=-3.96507407429948
# f([ 3.23267259 -5.12753874  3.32794851])=-3.9666283138537324
# f([ 3.22743659 -5.12466865  3.32056844])=-3.9681133881520623
# f([ 3.22231842 -5.12186314  3.31335446])=-3.9695323751191722
# f([ 3.21731543 -5.11912077  3.30630282])=-3.9708882157092944
# f([ 3.21242502 -5.1164401   3.29940987])=-3.9721837200011407
# f([ 3.20764467 -5.11381977  3.29267203])=-3.9734215730217386
# f([ 3.20297189 -5.1112584   3.28608582])=-3.9746043403119415
# f([ 3.19840427 -5.10875467  3.27964782])=-3.975734473243392
# f([ 3.19393943 -5.10630729  3.27335471])=-3.976814314098931
# f([ 3.18957507 -5.10391498  3.26720321])=-3.9778461009277066
# f([ 3.18530893 -5.1015765   3.26119014])=-3.978831972183258
# f([ 3.18113879 -5.09929065  3.25531239])=-3.979773971155538
# f([ 3.17706249 -5.09705625  3.24956691])=-3.980674050206403
# f([ 3.17307793 -5.09487212  3.24395073])=-3.9815340748153574
# f([ 3.16918303 -5.09273714  3.23846093])=-3.982355827446156
# f([ 3.16537578 -5.09065021  3.23309467])=-3.9831410112412016
# f([ 3.16165421 -5.08861024  3.22784917])=-3.983891253551093
# f([ 3.15801639 -5.08661618  3.22272172])=-3.984608109307885
# f([ 3.15446043 -5.084667    3.21770965])=-3.9852930642475144
# f([ 3.1509845  -5.08276168  3.21281037])=-3.985947537988949
# f([ 3.14758678 -5.08089923  3.20802135])=-3.9865728869770294
# f([ 3.14426553 -5.0790787   3.20334009])=-3.987170407292979
# f([ 3.14101902 -5.07729913  3.19876418])=-3.98774133734139
# f([ 3.13784557 -5.07555961  3.19429125])=-3.988286860416366
# f([ 3.13474353 -5.07385924  3.18991897])=-3.988808107154483
# f([ 3.1317113  -5.07219713  3.18564509])=-3.9893061578774365
# f([ 3.1287473  -5.07057243  3.18146738])=-3.9897820448319408
# f([ 3.12585001 -5.06898429  3.17738369])=-3.990236754328336
# f([ 3.12301792 -5.06743188  3.1733919 ])=-3.99067122878526
# f([ 3.12024956 -5.06591441  3.16948994])=-3.991086368682687
# f([ 3.11754349 -5.06443109  3.16567578])=-3.991483034428441
# f([ 3.11489833 -5.06298116  3.16194746])=-3.9918620481413853
# f([ 3.11231269 -5.06156384  3.15830304])=-3.9922241953547513
# f([ 3.10978523 -5.06017843  3.15474063])=-3.9925702266453698
# f([ 3.10731466 -5.05882419  3.15125839])=-3.9929008591882678
# f([ 3.10489968 -5.05750043  3.14785451])=-3.9932167782434504
# f([ 3.10253904 -5.05620645  3.14452724])=-3.9935186385764183
# f([ 3.10023153 -5.0549416   3.14127484])=-3.9938070658146074
# f([ 3.09797595 -5.05370521  3.13809563])=-3.994082657744471
# f([ 3.09577113 -5.05249664  3.13498796])=-3.9943459855505523
# f([ 3.09361592 -5.05131527  3.13195023])=-3.994597594998851
# f([ 3.09150921 -5.05016049  3.12898086])=-3.994838007568376
# f([ 3.08944992 -5.04903169  3.12607831])=-3.9950677215317114
# f([ 3.08743696 -5.04792829  3.12324108])=-3.995287212987847
# f([ 3.0854693  -5.04684973  3.12046769])=-3.995496936848781
# f([ 3.08354593 -5.04579544  3.11775672])=-3.995697327782608
# f([ 3.08166583 -5.04476487  3.11510676])=-3.995888801114063
# f([ 3.07982805 -5.04375749  3.11251643])=-3.9960717536857686
# f([ 3.07803162 -5.04277279  3.10998439])=-3.996246564680092
# f([ 3.07627562 -5.04181024  3.10750933])=-3.9964135964057306
# f([ 3.07455913 -5.04086935  3.10508997])=-3.996573195048015
# f([ 3.07288127 -5.03994964  3.10272506])=-3.9967256913868567
# f([ 3.07124117 -5.03905062  3.10041336])=-3.9968714014821103
# f([ 3.06963798 -5.03817184  3.09815369])=-3.9970106273285495
# f([ 3.06807087 -5.03731283  3.09594486])=-3.9971436574816863
# f([ 3.06653902 -5.03647315  3.09378575])=-3.997270767656545
# f([ 3.06504164 -5.03565237  3.09167522])=-3.9973922212981137
# f([ 3.06357797 -5.03485006  3.08961218])=-3.9975082701280087
# f([ 3.06214722 -5.0340658   3.08759558])=-3.9976191546656423
# f([ 3.06074868 -5.0332992   3.08562435])=-3.99772510472755
# f([ 3.05938161 -5.03254984  3.08369748])=-3.997826339903014
# f([ 3.0580453  -5.03181735  3.08181398])=-3.9979230700090795
# f([ 3.05673907 -5.03110134  3.07997286])=-3.998015495526218
# f([ 3.05546223 -5.03040144  3.07817317])=-3.9981038080128997
# f([ 3.05421412 -5.0297173   3.07641398])=-3.9981881905033276
# f([ 3.0529941  -5.02904855  3.07469439])=-3.998268817886185
# f([ 3.05180154 -5.02839485  3.07301348])=-3.9983458572678217
# f([ 3.05063581 -5.02775586  3.07137041])=-3.998419468317806
# f([ 3.04949631 -5.02713125  3.06976431])=-3.998489803600492
# f([ 3.04838246 -5.02652069  3.06819435])=-3.9985570088908844
# f([ 3.04729368 -5.02592388  3.06665973])=-3.998621223476789
# f([ 3.04622939 -5.0253405   3.06515963])=-3.9986825804477775
# f([ 3.04518906 -5.02477024  3.0636933 ])=-3.998741206970493
# f([ 3.04417214 -5.02421282  3.06225996])=-3.9987972245527743
# f([ 3.0431781  -5.02366794  3.06085888])=-3.998850749295187
# f([ 3.04220643 -5.02313532  3.05948933])=-3.998901892131485
# f([ 3.04125663 -5.02261469  3.0581506 ])=-3.9989507590591558
# f([ 3.0403282  -5.02210578  3.05684199])=-3.9989974513583775
# f([ 3.03942067 -5.02160832  3.05556284])=-3.9990420658022856
# f([ 3.03853356 -5.02112205  3.05431247])=-3.9990846948576007
# f([ 3.03766641 -5.02064672  3.05309023])=-3.9991254268762475
# f([ 3.03681877 -5.02018209  3.05189551])=-3.9991643462782633
# f([ 3.03599021 -5.01972792  3.05072766])=-3.999201533726861
# f([ 3.0351803  -5.01928397  3.0495861 ])=-3.9992370662959047
# f([ 3.03438861 -5.01885001  3.04847023])=-3.9992710176290416
# f([ 3.03361474 -5.01842581  3.04737947])=-3.999303458093138
# f([ 3.03285828 -5.01801116  3.04631326])=-3.9993344549230727
# f([ 3.03211885 -5.01760585  3.04527104])=-3.9993640723623685
# f([ 3.03139606 -5.01720965  3.04425227])=-3.999392371795153
# f([ 3.03068953 -5.01682237  3.04325643])=-3.9994194118742854
# f([ 3.0299989 -5.0164438  3.042283 ])=-3.9994452486419476
# f([ 3.02932381 -5.01607376  3.04133147])=-3.999469935646971
# f([ 3.02866392 -5.01571204  3.04040136])=-3.999493524054941
# f([ 3.02801887 -5.01535846  3.03949218])=-3.999516062754509
# f([ 3.02738834 -5.01501283  3.03860346])=-3.9995375984588293
# f([ 3.026772   -5.01467499  3.03773474])=-3.9995581758021785
# f([ 3.02616954 -5.01434475  3.03688557])=-3.9995778374325965
# f([ 3.02558062 -5.01402194  3.0360555 ])=-3.9995966241003487
# f([ 3.02500496 -5.01370639  3.03524412])=-3.9996145747420115
# f([ 3.02444226 -5.01339795  3.034451  ])=-3.999631726561759
# f([ 3.02389222 -5.01309644  3.03367572])=-3.999648115107888
# f([ 3.02335455 -5.01280172  3.03291789])=-3.9996637743469137
# f([ 3.02282899 -5.01251364  3.03217712])=-3.9996787367336992
# f([ 3.02231525 -5.01223203  3.03145301])=-3.999693033278888
# f([ 3.02181308 -5.01195677  3.0307452 ])=-3.999706693613149
# f([ 3.0213222  -5.0116877   3.03005332])=-3.9997197460485836
# f([ 3.02084237 -5.01142468  3.02937701])=-3.9997322176371313
# f([ 3.02037334 -5.01116758  3.02871592])=-3.999744134227228
# f([ 3.01991486 -5.01091627  3.0280697 ])=-3.9997555205168425
# f([ 3.01946671 -5.01067061  3.02743803])=-3.999766400104832
# f([ 3.01902863 -5.01043048  3.02682057])=-3.9997767955400576
# f([ 3.01860042 -5.01019576  3.02621701])=-3.9997867283676953
# f([ 3.01818184 -5.00996632  3.02562703])=-3.9997962191742715
# f([ 3.01777268 -5.00974204  3.02505032])=-3.999805287630224
# f([ 3.01737273 -5.00952281  3.0244866 ])=-3.9998139525306016
# f([ 3.01698178 -5.00930851  3.02393556])=-3.999822231834102
# f([ 3.01659962 -5.00909903  3.02339692])=-3.9998301426999774
# f([ 3.01622607 -5.00889427  3.0228704 ])=-3.999837701524214
# f([ 3.01586092 -5.00869412  3.02235573])=-3.999844923973029
# f([ 3.01550399 -5.00849847  3.02185265])=-3.999851825015483
# f([ 3.0151551  -5.00830722  3.02136088])=-3.99985841895446
# f([ 3.01481405 -5.00812027  3.02088018])=-3.9998647194562977
# f([ 3.01448068 -5.00793754  3.0204103 ])=-3.9998707395793645
# (279,
#  array([[20.        , 20.        , 20.        ],
#         [26.96      ,  2.96      ,  8.        ],
#         [13.2992    ,  4.4096    , 17.8304    ],
#         [18.713216  , -4.64704   , 10.051328  ],
#         [10.71813632, -2.58669568, 16.11846656],
#         [14.54898729, -7.55301315, 11.07184271],
#         [ 9.74047999, -5.73805434, 14.80083312],
#         [12.30937708, -8.53304884, 11.51164495],
#         [ 9.34598711, -7.14743336, 13.78187553],
#         [11.00523231, -8.74971823, 11.61880388],
#         [ 9.1364774 , -7.75502953, 12.9768971 ],
#         [10.17339167, -8.68179056, 11.53420909],
#         [ 8.96692861, -7.98671558, 12.32168001],
#         [ 9.59110058, -8.52099834, 11.33988248],
#         [ 8.79173208, -8.03874672, 11.77083871],
#         [ 9.14773219, -8.34047772, 11.08448036],
#         [ 8.60189103, -8.00355808, 11.29345098],
#         [ 8.78630636, -8.16559893, 10.79723569],
#         [ 8.4002031 , -7.92584241, 10.86885406],
#         [ 8.47630415, -8.0033138 , 10.49582973],
#         [ 8.1920131 , -7.82785429, 10.48336194],
#         [ 8.20071515, -7.85403073, 10.19096084],
#         [ 7.98215516, -7.72101604, 10.12791869],
#         [ 7.94968051, -7.71623153,  9.88905665],
#         [ 7.77422632, -7.61135482,  9.79649696],
#         [ 7.71726629, -7.588139  ,  9.59391241],
#         [ 7.57064951, -7.50211769,  9.48503392],
#         [ 7.49976597, -7.46822954,  9.30769363],
#         [ 7.37293934, -7.39506901,  9.1907359 ],
#         [ 7.2947753 , -7.35532267,  9.0315555 ],
#         [ 7.18196785, -7.2911566 ,  8.91162864],
#         [ 7.1006711 , -7.24853596,  8.76602804],
#         [ 6.99817461, -7.19086625,  8.6462683 ],
#         [ 6.91630927, -7.14721242,  8.51125665],
#         [ 6.8217178 , -7.09441682,  8.3935565 ],
#         [ 6.74084547, -7.05085544,  8.26715271],
#         [ 6.65257726, -7.00187111,  8.15262211],
#         [ 6.57362668, -6.95907924,  8.03348795],
#         [ 6.49062307, -6.91320031,  7.92274587],
#         [ 6.41412461, -6.87157384,  7.8099536 ],
#         [ 6.33565995, -6.8283224 ,  7.70331217],
#         [ 6.26189429, -6.78808122,  7.59619732],
#         [ 6.18745592, -6.74712526,  7.49377812],
#         [ 6.1165481 , -6.70837947,  7.39184626],
#         [ 6.04576039, -6.66948068,  7.29365373],
#         [ 5.97773931, -6.63227232,  7.19652125],
#         [ 5.91031556, -6.59525298,  7.10248897],
#         [ 5.84515147, -6.5595823 ,  7.00984554],
#         [ 5.7808634 , -6.52430425,  6.91986531],
#         [ 5.71849164, -6.49014623,  6.83144997],
#         [ 5.65715   , -6.45649749,  6.74539016],
#         [ 5.59748582, -6.42381227,  6.66097604],
#         [ 5.53892806, -6.39169851,  6.57869297],
#         [ 5.48187597, -6.36043793,  6.49807752],
#         [ 5.42595832, -6.32977704,  6.41942261],
#         [ 5.37141788, -6.29988867,  6.3424213 ],
#         [ 5.31801027, -6.27060726,  6.2672454 ],
#         [ 5.26587972, -6.24203699,  6.19368759],
#         [ 5.2148625 , -6.21406814,  6.12184368],
#         [ 5.16504092, -6.18676172,  6.05156994],
#         [ 5.11630268, -6.16004353,  5.98291467],
#         [ 5.06869132, -6.13394749,  5.91577493],
#         [ 5.02212747, -6.10842209,  5.85016953],
#         [ 4.9766305 , -6.08348432,  5.78602185],
#         [ 4.93214225, -6.05909723,  5.72333255],
#         [ 4.88866719, -6.03526731,  5.66204221],
#         [ 4.84616091, -6.01196699,  5.60214051],
#         [ 4.80461879, -5.98919631,  5.54357936],
#         [ 4.76400547, -5.96693385,  5.48634198],
#         [ 4.72431091, -5.94517572,  5.43038794],
#         [ 4.6855058 , -5.92390457,  5.37569683],
#         [ 4.647577  , -5.90311422,  5.32223348],
#         [ 4.61049931, -5.88279004,  5.26997564],
#         [ 4.57425794, -5.86292457,  5.2188919 ],
#         [ 4.53883059, -5.84350508,  5.16895924],
#         [ 4.50420172, -5.82452346,  5.12014906],
#         [ 4.47035115, -5.80596831,  5.07243823],
#         [ 4.43726312, -5.78783126,  5.02580032],
#         [ 4.40491908, -5.77010194,  4.98021254],
#         [ 4.37330338, -5.75277193,  4.93565018],
#         [ 4.34239877, -5.73583164,  4.89209101],
#         [ 4.31218994, -5.71927278,  4.84951179],
#         [ 4.28266068, -5.70308639,  4.80789099],
#         [ 4.25379612, -5.68726439,  4.76720663],
#         [ 4.22558097, -5.67179834,  4.72743797],
#         [ 4.1980009 , -5.65668041,  4.68856413],
#         [ 4.17104137, -5.64190263,  4.6505652 ],
#         [ 4.14468862, -5.62745745,  4.6134213 ],
#         [ 4.11892884, -5.6133373 ,  4.57711335],
#         [ 4.09374879, -5.59953495,  4.54162241],
#         [ 4.06913536, -5.58604317,  4.50693018],
#         [ 4.04507585, -5.57285502,  4.47301863],
#         [ 4.02155774, -5.55996365,  4.43987024],
#         [ 3.9985689 , -5.54736239,  4.40746779],
#         [ 3.97609737, -5.53504469,  4.37579453],
#         [ 3.95413155, -5.5230042 ,  4.34483403],
#         [ 3.93266004, -5.51123465,  4.31457026],
#         [ 3.91167172, -5.49972997,  4.28498753],
#         [ 3.89115571, -5.48848419,  4.25607053],
#         [ 3.87110139, -5.47749148,  4.22780427],
#         [ 3.85149837, -5.46674614,  4.20017411],
#         [ 3.83233648, -5.45624261,  4.17316572],
#         [ 3.81360581, -5.44597546,  4.14676513],
#         [ 3.79529666, -5.43593935,  4.12095864],
#         [ 3.77739952, -5.42612909,  4.0957329 ],
#         [ 3.75990514, -5.4165396 ,  4.07107483],
#         [ 3.74280444, -5.40716591,  4.04697166],
#         [ 3.72608858, -5.39800316,  4.0234109 ],
#         [ 3.70974888, -5.38904661,  4.00038035],
#         [ 3.69377689, -5.38029161,  3.97786806],
#         [ 3.67816433, -5.37173363,  3.95586239],
#         [ 3.66290311, -5.36336824,  3.93435193],
#         [ 3.64798532, -5.35519111,  3.91332554],
#         [ 3.63340324, -5.34719798,  3.89277231],
#         [ 3.61914931, -5.33938474,  3.87268161],
#         [ 3.60521614, -5.33174732,  3.85304303],
#         [ 3.59159653, -5.32428177,  3.83384638],
#         [ 3.5782834 , -5.31698422,  3.81508174],
#         [ 3.56526988, -5.3098509 ,  3.79673936],
#         [ 3.5525492 , -5.3028781 ,  3.77880976],
#         [ 3.54011479, -5.29606221,  3.76128364],
#         [ 3.52796019, -5.28939971,  3.74415193],
#         [ 3.51607912, -5.28288714,  3.72740574],
#         [ 3.50446542, -5.27652113,  3.7110364 ],
#         [ 3.49311307, -5.27029837,  3.69503544],
#         [ 3.48201619, -5.26421565,  3.67939455],
#         [ 3.47116903, -5.25826982,  3.66410565],
#         [ 3.46056598, -5.25245779,  3.6491608 ],
#         [ 3.45020153, -5.24677655,  3.63455226],
#         [ 3.44007032, -5.24122315,  3.62027248],
#         [ 3.4301671 , -5.23579474,  3.60631404],
#         [ 3.42048674, -5.23048848,  3.59266971],
#         [ 3.41102422, -5.22530163,  3.57933244],
#         [ 3.40177465, -5.2202315 ,  3.5662953 ],
#         [ 3.39273322, -5.21527547,  3.55355155],
#         [ 3.38389526, -5.21043097,  3.54109458],
#         [ 3.37525619, -5.20569549,  3.52891794],
#         [ 3.36681153, -5.20106658,  3.51701532],
#         [ 3.3585569 , -5.19654183,  3.50538055],
#         [ 3.35048804, -5.19211891,  3.4940076 ],
#         [ 3.34260075, -5.18779552,  3.48289059],
#         [ 3.33489096, -5.18356942,  3.47202376],
#         [ 3.32735467, -5.17943843,  3.46140147],
#         [ 3.31998797, -5.17540039,  3.45101822],
#         [ 3.31278705, -5.17145323,  3.44086863],
#         [ 3.30574818, -5.1675949 ,  3.43094744],
#         [ 3.2988677 , -5.16382339,  3.42124952],
#         [ 3.29214207, -5.16013675,  3.41176984],
#         [ 3.28556778, -5.15653308,  3.40250349],
#         [ 3.27914145, -5.1530105 ,  3.39344566],
#         [ 3.27285972, -5.1495672 ,  3.38459167],
#         [ 3.26671937, -5.14620138,  3.37593692],
#         [ 3.26071719, -5.1429113 ,  3.36747694],
#         [ 3.25485008, -5.13969527,  3.35920734],
#         [ 3.249115  , -5.1365516 ,  3.35112384],
#         [ 3.24350899, -5.13347868,  3.34322225],
#         [ 3.23802913, -5.13047492,  3.33549847],
#         [ 3.23267259, -5.12753874,  3.32794851],
#         [ 3.22743659, -5.12466865,  3.32056844],
#         [ 3.22231842, -5.12186314,  3.31335446],
#         [ 3.21731543, -5.11912077,  3.30630282],
#         [ 3.21242502, -5.1164401 ,  3.29940987],
#         [ 3.20764467, -5.11381977,  3.29267203],
#         [ 3.20297189, -5.1112584 ,  3.28608582],
#         [ 3.19840427, -5.10875467,  3.27964782],
#         [ 3.19393943, -5.10630729,  3.27335471],
#         [ 3.18957507, -5.10391498,  3.26720321],
#         [ 3.18530893, -5.1015765 ,  3.26119014],
#         [ 3.18113879, -5.09929065,  3.25531239],
#         [ 3.17706249, -5.09705625,  3.24956691],
#         [ 3.17307793, -5.09487212,  3.24395073],
#         [ 3.16918303, -5.09273714,  3.23846093],
#         [ 3.16537578, -5.09065021,  3.23309467],
#         [ 3.16165421, -5.08861024,  3.22784917],
#         [ 3.15801639, -5.08661618,  3.22272172],
#         [ 3.15446043, -5.084667  ,  3.21770965],
#         [ 3.1509845 , -5.08276168,  3.21281037],
#         [ 3.14758678, -5.08089923,  3.20802135],
#         [ 3.14426553, -5.0790787 ,  3.20334009],
#         [ 3.14101902, -5.07729913,  3.19876418],
#         [ 3.13784557, -5.07555961,  3.19429125],
#         [ 3.13474353, -5.07385924,  3.18991897],
#         [ 3.1317113 , -5.07219713,  3.18564509],
#         [ 3.1287473 , -5.07057243,  3.18146738],
#         [ 3.12585001, -5.06898429,  3.17738369],
#         [ 3.12301792, -5.06743188,  3.1733919 ],
#         [ 3.12024956, -5.06591441,  3.16948994],
#         [ 3.11754349, -5.06443109,  3.16567578],
#         [ 3.11489833, -5.06298116,  3.16194746],
#         [ 3.11231269, -5.06156384,  3.15830304],
#         [ 3.10978523, -5.06017843,  3.15474063],
#         [ 3.10731466, -5.05882419,  3.15125839],
#         [ 3.10489968, -5.05750043,  3.14785451],
#         [ 3.10253904, -5.05620645,  3.14452724],
#         [ 3.10023153, -5.0549416 ,  3.14127484],
#         [ 3.09797595, -5.05370521,  3.13809563],
#         [ 3.09577113, -5.05249664,  3.13498796],
#         [ 3.09361592, -5.05131527,  3.13195023],
#         [ 3.09150921, -5.05016049,  3.12898086],
#         [ 3.08944992, -5.04903169,  3.12607831],
#         [ 3.08743696, -5.04792829,  3.12324108],
#         [ 3.0854693 , -5.04684973,  3.12046769],
#         [ 3.08354593, -5.04579544,  3.11775672],
#         [ 3.08166583, -5.04476487,  3.11510676],
#         [ 3.07982805, -5.04375749,  3.11251643],
#         [ 3.07803162, -5.04277279,  3.10998439],
#         [ 3.07627562, -5.04181024,  3.10750933],
#         [ 3.07455913, -5.04086935,  3.10508997],
#         [ 3.07288127, -5.03994964,  3.10272506],
#         [ 3.07124117, -5.03905062,  3.10041336],
#         [ 3.06963798, -5.03817184,  3.09815369],
#         [ 3.06807087, -5.03731283,  3.09594486],
#         [ 3.06653902, -5.03647315,  3.09378575],
#         [ 3.06504164, -5.03565237,  3.09167522],
#         [ 3.06357797, -5.03485006,  3.08961218],
#         [ 3.06214722, -5.0340658 ,  3.08759558],
#         [ 3.06074868, -5.0332992 ,  3.08562435],
#         [ 3.05938161, -5.03254984,  3.08369748],
#         [ 3.0580453 , -5.03181735,  3.08181398],
#         [ 3.05673907, -5.03110134,  3.07997286],
#         [ 3.05546223, -5.03040144,  3.07817317],
#         [ 3.05421412, -5.0297173 ,  3.07641398],
#         [ 3.0529941 , -5.02904855,  3.07469439],
#         [ 3.05180154, -5.02839485,  3.07301348],
#         [ 3.05063581, -5.02775586,  3.07137041],
#         [ 3.04949631, -5.02713125,  3.06976431],
#         [ 3.04838246, -5.02652069,  3.06819435],
#         [ 3.04729368, -5.02592388,  3.06665973],
#         [ 3.04622939, -5.0253405 ,  3.06515963],
#         [ 3.04518906, -5.02477024,  3.0636933 ],
#         [ 3.04417214, -5.02421282,  3.06225996],
#         [ 3.0431781 , -5.02366794,  3.06085888],
#         [ 3.04220643, -5.02313532,  3.05948933],
#         [ 3.04125663, -5.02261469,  3.0581506 ],
#         [ 3.0403282 , -5.02210578,  3.05684199],
#         [ 3.03942067, -5.02160832,  3.05556284],
#         [ 3.03853356, -5.02112205,  3.05431247],
#         [ 3.03766641, -5.02064672,  3.05309023],
#         [ 3.03681877, -5.02018209,  3.05189551],
#         [ 3.03599021, -5.01972792,  3.05072766],
#         [ 3.0351803 , -5.01928397,  3.0495861 ],
#         [ 3.03438861, -5.01885001,  3.04847023],
#         [ 3.03361474, -5.01842581,  3.04737947],
#         [ 3.03285828, -5.01801116,  3.04631326],
#         [ 3.03211885, -5.01760585,  3.04527104],
#         [ 3.03139606, -5.01720965,  3.04425227],
#         [ 3.03068953, -5.01682237,  3.04325643],
#         [ 3.0299989 , -5.0164438 ,  3.042283  ],
#         [ 3.02932381, -5.01607376,  3.04133147],
#         [ 3.02866392, -5.01571204,  3.04040136],
#         [ 3.02801887, -5.01535846,  3.03949218],
#         [ 3.02738834, -5.01501283,  3.03860346],
#         [ 3.026772  , -5.01467499,  3.03773474],
#         [ 3.02616954, -5.01434475,  3.03688557],
#         [ 3.02558062, -5.01402194,  3.0360555 ],
#         [ 3.02500496, -5.01370639,  3.03524412],
#         [ 3.02444226, -5.01339795,  3.034451  ],
#         [ 3.02389222, -5.01309644,  3.03367572],
#         [ 3.02335455, -5.01280172,  3.03291789],
#         [ 3.02282899, -5.01251364,  3.03217712],
#         [ 3.02231525, -5.01223203,  3.03145301],
#         [ 3.02181308, -5.01195677,  3.0307452 ],
#         [ 3.0213222 , -5.0116877 ,  3.03005332],
#         [ 3.02084237, -5.01142468,  3.02937701],
#         [ 3.02037334, -5.01116758,  3.02871592],
#         [ 3.01991486, -5.01091627,  3.0280697 ],
#         [ 3.01946671, -5.01067061,  3.02743803],
#         [ 3.01902863, -5.01043048,  3.02682057],
#         [ 3.01860042, -5.01019576,  3.02621701],
#         [ 3.01818184, -5.00996632,  3.02562703],
#         [ 3.01777268, -5.00974204,  3.02505032],
#         [ 3.01737273, -5.00952281,  3.0244866 ],
#         [ 3.01698178, -5.00930851,  3.02393556],
#         [ 3.01659962, -5.00909903,  3.02339692],
#         [ 3.01622607, -5.00889427,  3.0228704 ],
#         [ 3.01586092, -5.00869412,  3.02235573],
#         [ 3.01550399, -5.00849847,  3.02185265],
#         [ 3.0151551 , -5.00830722,  3.02136088],
#         [ 3.01481405, -5.00812027,  3.02088018],
#         [ 3.01448068, -5.00793754,  3.0204103 ]]))

# %% [markdown]
# **Etude  théorique**
# On a dans la base canonique
# $$\nabla f (x) = (14x_1 - 6x_2 - 12x_3 - 36, -6x_1 + 10x_2 + 8x_3 + 44, -12x_1 + 8x_2 + 12x_3 + 40)$$
# Résoudre $\nabla f (x) =0$ donne une solution unique $x^* = (3,-5,3)$ et $f(x^*)= -4$.

# %%
f(3,-5,3)
# Out:
# -4

# %% [markdown]
# ### Comportements de la descente de gradient
# Considérons la fonction $f(x)=x^2$ ayant un unique minimum en $x=0$. Comme $f'(x)=2x$ la descente de gradient consiste à poser
# $$x_{k+1} = x_k - \alpha \cdot 2x_k = (1-2\alpha)x_k$$
# On voit essentiellement deux cas :
# *  Si $ \alpha \geq 1$ alors  $|1-2\alpha| \geq 1$ oscille entre $x_k$ et $-x_k$ (pour $\alpha=1$) ou bien alterne entre positif et négatif avec $|x_k| \rightarrow \infty$ (pour $\alpha > 1)$
# *  Si $0 < \alpha < 1$ alors $x_k$ va converger vers $0$:
#     * en une étape si $\alpha = \frac1{2}$
#     * sinon le temps pour obtenir $| x_k | < \epsilon$ est
#         $$\frac{ \log( x_0 / \epsilon)}{ - \log | 1 - 2\alpha |  }$$

# %%
# TEMPS DE CONVERGENCE EN FONCTION DE ALPHA
X = np.linspace(0.01, .49,100)
plt.plot(X, -1/np.log(1-2*X))
plt.show()

# %%
# GRADIENT POUR ALPHA PETIT : convergence lente
f = lambda x : x**2
diff = lambda x: 2*x
k, points = descente_gradient(f, diff, epsilon = 0.01, alpha = 0.05, p0 = np.array([5]))
# Out:
# f([4.5])=20.25
# f([4.05])=16.4025
# f([3.645])=13.286024999999997
# f([3.2805])=10.761680249999998
# f([2.95245])=8.716961002499998
# f([2.657205])=7.060738412024999
# f([2.3914845])=5.719198113740249
# f([2.15233605])=4.632550472129601
# f([1.93710244])=3.7523658824249773
# f([1.7433922])=3.0394163647642314
# f([1.56905298])=2.4619272554590275
# f([1.41214768])=1.9941610769218119
# f([1.27093291])=1.6152704723066673
# f([1.14383962])=1.3083690825684005
# f([1.02945566])=1.0597789568804041
# f([0.92651009])=0.8584209550731274
# f([0.83385908])=0.6953209736092332
# f([0.75047318])=0.5632099886234788
# f([0.67542586])=0.4562000907850177
# f([0.60788327])=0.36952207353586436
# f([0.54709495])=0.2993128795640501
# f([0.49238545])=0.2424434324468806
# f([0.44314691])=0.1963791802819733
# f([0.39883222])=0.15906713602839836
# f([0.35894899])=0.12884438018300265
# f([0.32305409])=0.10436394794823214
# f([0.29074869])=0.08453479783806803
# f([0.26167382])=0.0684731862488351
# f([0.23550643])=0.05546328086155643
# f([0.21195579])=0.04492525749786071
# f([0.19076021])=0.03638945857326717
# f([0.17168419])=0.02947546144434641
# f([0.15451577])=0.02387512376992059
# f([0.13906419])=0.01933885025363568
# f([0.12515778])=0.0156644687054449
# f([0.112642])=0.01268821965141037
# f([0.1013778])=0.0102774579176424
# f([0.09124002])=0.008324740913290343
# f([0.08211602])=0.006743040139765177
# f([0.07390441])=0.005461862513209795
# f([0.06651397])=0.004424108635699933
# f([0.05986258])=0.003583527994916946
# f([0.05387632])=0.0029026576758827264
# f([0.04848869])=0.002351152717465008
# f([0.04363982])=0.0019044337011466562
# f([0.03927584])=0.0015425912979287915
# f([0.03534825])=0.001249498951322321
# f([0.03181343])=0.00101209415057108
# f([0.02863208])=0.0008197962619625747
# f([0.02576888])=0.0006640349721896855
# f([0.02319199])=0.0005378683274736453
# f([0.02087279])=0.00043567334525365274
# f([0.01878551])=0.0003528954096554587
# f([0.01690696])=0.00028584528182092154
# f([0.01521626])=0.00023153467827494644
# f([0.01369464])=0.00018754308940270662
# f([0.01232517])=0.00015190990241619235
# f([0.01109266])=0.00012304702095711578
# f([0.00998339])=9.966808697526379e-05
# f([0.00898505])=8.073115044996368e-05
# f([0.00808655])=6.539223186447059e-05
# f([0.00727789])=5.296770781022117e-05
# f([0.0065501])=4.290384332627914e-05
# f([0.00589509])=3.475211309428611e-05
# f([0.00530558])=2.814921160637175e-05
# f([0.00477502])=2.2800861401161113e-05

# %%
X = np.linspace(-5,5,200)
plt.plot()
Z = points[0:10]
plt.plot(X,X**2, 'r')
plt.scatter(Z,Z**2)
plt.show()

# %%
# GRADIENT POUR ALPHA = environ 0.5 : convergence  très rapide
k, points = descente_gradient(f, diff, epsilon = 0.01, alpha = 0.45, p0 = np.array([5]))
# Out:
# f([0.5])=0.25
# f([0.05])=0.0024999999999999988
# f([0.005])=2.4999999999999974e-05

# %%
# GRADIENT POUR ALPHA TROP GRAND : pas de convergence
k, points = descente_gradient(f, diff, epsilon = 0.01, alpha = 1.2, p0 = np.array([5]))
# Out:
# f([-7.])=49.0
# f([9.8])=96.04000000000002
# f([-13.72])=188.23839999999996
# f([19.208])=368.94726399999996
# f([-26.8912])=723.1366374399998
# f([37.64768])=1417.3478093823996
# f([-52.706752])=2778.0017063895034
# f([73.7894528])=5444.883344523427
# f([-103.30523392])=10671.971355265914
# f([144.62732749])=20917.06385632119
# f([-202.47825848])=40997.44515838953
# f([283.46956188])=80354.99251044348
# f([-396.85738663])=157495.78532046918
# f([555.60034128])=308691.7392281195
# f([-777.84047779])=605035.8088871143
# f([1088.9766689])=1185870.1854187436
# f([-1524.56733647])=2324305.5634207376
# f([2134.39427105])=4555638.904304644
# f([-2988.15197947])=8929052.2524371
# f([4183.41277126])=17500942.414776713
# f([-5856.77787977])=34301847.132962346
# f([8199.48903168])=67231620.38060622
# f([-11479.28464435])=131773975.94598821
# f([16070.99850209])=258276992.85413688
# f([-22499.39790292])=506222905.9941081
# f([31499.15706409])=992196895.7484517
# f([-44098.81988973])=1944705915.6669652
# f([61738.34784562])=3811623594.707252
# f([-86433.68698387])=7470782245.626216
# f([121007.16177742])=14642733201.42738
# f([-169410.02648839])=28699757074.79765
# f([237174.03708375])=56251523866.603386
# f([-332043.65191725])=110252986778.54262
# f([464861.11268415])=216095854085.94345
# f([-650805.55775781])=423547874008.4493
# f([911127.78086093])=830153833056.5607
# f([-1275578.8932053])=1627101512790.8594
# f([1785810.45048742])=3189118965070.0835
# f([-2500134.63068239])=6250673171537.364
# f([3500188.48295534])=12251319416213.236
# f([-4900263.87613748])=24012586055777.94
# f([6860369.42659247])=47064668669324.76
# f([-9604517.19722946])=92246750591876.52
# f([13446324.07612125])=180803631160077.94
# f([-18824853.70656975])=354375117073752.7
# f([26354795.18919764])=694575229464555.2
# f([-36896713.2648767])=1361367449750528.2
# f([51655398.57082737])=2668280201511034.5
# f([-72317557.99915832])=5229829194961628.0
# f([1.01244581e+08])=1.0250465222124788e+16
# f([-1.41742414e+08])=2.0090911835364576e+16
# f([1.98439379e+08])=3.937818719731458e+16
# f([-2.77815131e+08])=7.718124690673658e+16
# f([3.88941183e+08])=1.5127524393720365e+17
# f([-5.44517656e+08])=2.96499478116919e+17
# f([7.62324719e+08])=5.811389771091613e+17
# f([-1.06725461e+09])=1.139032395133956e+18
# f([1.49415645e+09])=2.2325034944625533e+18
# f([-2.09181903e+09])=4.375706849146604e+18
# f([2.92854664e+09])=8.576385424327342e+18
# f([-4.0999653e+09])=1.6809715431681591e+19
# f([5.73995141e+09])=3.294704224609592e+19
# f([-8.03593198e+09])=6.457620280234801e+19
# f([1.12503048e+10])=1.2656935749260204e+20
# f([-1.57504267e+10])=2.4807594068549996e+20
# f([2.20505974e+10])=4.8622884374357987e+20
# f([-3.08708363e+10])=9.530085337374164e+20
# f([4.32191708e+10])=1.8678967261253366e+21
# f([-6.05068391e+10])=3.66107758320566e+21
# f([8.47095748e+10])=7.175712063083093e+21
# f([-1.18593405e+11])=1.406439564364286e+22
# f([1.66030767e+11])=2.756621546153999e+22
# f([-2.32443073e+11])=5.402978230461838e+22
# f([3.25420303e+11])=1.0589837331705204e+23
# f([-4.55588424e+11])=2.07560811701422e+23
# f([6.37823793e+11])=4.068191909347871e+23
# f([-8.9295331e+11])=7.973656142321827e+23
# f([1.25013463e+12])=1.5628366038950777e+24
# f([-1.75018849e+12])=3.0631597436343516e+24
# f([2.45026388e+12])=6.003793097523329e+24
# f([-3.43036944e+12])=1.176743447114572e+25
# f([4.80251721e+12])=2.306417156344561e+25
# f([-6.7235241e+12])=4.520577626435337e+25
# f([9.41293373e+12])=8.860332147813258e+25
# f([-1.31781072e+13])=1.7366251009713988e+26
# f([1.84493501e+13])=3.403785197903941e+26
# f([-2.58290902e+13])=6.671418987891723e+26
# f([3.61607262e+13])=1.3075981216267773e+27
# f([-5.06250167e+13])=2.5628923183884836e+27
# f([7.08750234e+13])=5.023268944041427e+27
# f([-9.92250328e+13])=9.845607130321197e+27
# f([1.38915046e+14])=1.9297389975429544e+28
# f([-1.94481064e+14])=3.782288435184191e+28
# f([2.7227349e+14])=7.413285332961015e+28
# f([-3.81182886e+14])=1.4530039252603594e+29
# f([5.3365604e+14])=2.847887693510304e+29
# f([-7.47118456e+14])=5.581859879280193e+29
# f([1.04596584e+15])=1.0940445363389175e+30
# f([-1.46435217e+15])=2.1443272912242786e+30
# f([2.05009304e+15])=4.2028814907995846e+30
# f([-2.87013026e+15])=8.237647721967184e+30
# f([4.01818237e+15])=1.6145789535055678e+31
# f([-5.62545531e+15])=3.1645747488709115e+31
# f([7.87563744e+15])=6.202566507786986e+31
# f([-1.10258924e+16])=1.2157030355262487e+32
# f([1.54362494e+16])=2.3827779496314477e+32
# f([-2.16107491e+16])=4.670244781277638e+32
# f([3.02550488e+16])=9.153679771304172e+32
# f([-4.23570683e+16])=1.794121235175617e+33
# f([5.92998956e+16])=3.516477620944208e+33
# f([-8.30198539e+16])=6.892296137050648e+33
# f([1.16227795e+17])=1.3508900428619273e+34
# f([-1.62718914e+17])=2.647744484009378e+34
# f([2.27806479e+17])=5.189579188658379e+34
# f([-3.18929071e+17])=1.0171575209770422e+35
# f([4.46500699e+17])=1.993628741115003e+35
# f([-6.25100978e+17])=3.9075123325854055e+35
# f([8.7514137e+17])=7.658724171867392e+35
# f([-1.22519792e+18])=1.5011099376860092e+36
# f([1.71527708e+18])=2.9421754778645774e+36
# f([-2.40138792e+18])=5.766663936614572e+36
# f([3.36194309e+18])=1.1302661315764563e+37
# f([-4.70672032e+18])=2.2153216178898545e+37
# f([6.58940845e+18])=4.342030371064115e+37
# f([-9.22517183e+18])=8.510379527285664e+37
# f([1.29152406e+19])=1.6680343873479901e+38
# f([-1.80813368e+19])=3.2693473992020607e+38
# f([2.53138715e+19])=6.40792090243604e+38
# f([-3.54394201e+19])=1.255952496877464e+39
# f([4.96151881e+19])=2.4616668938798288e+39
# f([-6.94612634e+19])=4.8248671120044645e+39
# f([9.72457687e+19])=9.456739539528746e+39
# f([-1.36144076e+20])=1.8535209497476339e+40
# f([1.90601707e+20])=3.632901061505363e+40
# f([-2.66842389e+20])=7.12048608055051e+40
# f([3.73579345e+20])=1.3956152717878995e+41
# f([-5.23011083e+20])=2.7354059327042823e+41
# f([7.32215517e+20])=5.3613956281003946e+41
# f([-1.02510172e+21])=1.0508335431076775e+42
# f([1.43514241e+21])=2.0596337444910476e+42
# f([-2.00919938e+21])=4.036882139202454e+42
# f([2.81287913e+21])=7.912288992836804e+42
# f([-3.93803078e+21])=1.5508086425960135e+43
# f([5.51324309e+21])=3.039584939488187e+43
# f([-7.71854033e+21])=5.957586481396845e+43
# f([1.08059565e+22])=1.1676869503537815e+44
# f([-1.5128339e+22])=2.2886664226934122e+44
# f([2.11796747e+22])=4.485786188479087e+44
# f([-2.96515445e+22])=8.792140929419007e+44
# f([4.15121623e+22])=1.7232596221661248e+45
# f([-5.81170273e+22])=3.377588859445604e+45
# f([8.13638382e+22])=6.620074164513383e+45
# f([-1.13909373e+23])=1.2975345362446227e+46
# f([1.59473123e+23])=2.5431676910394594e+46
# f([-2.23262372e+23])=4.984608674437339e+46
# f([3.12567321e+23])=9.769833001897184e+46
# f([-4.37594249e+23])=1.914887268371848e+47
# f([6.12631949e+23])=3.753179046008821e+47
# f([-8.57684728e+23])=7.356230930177288e+47
# f([1.20075862e+24])=1.4418212623147487e+48
# f([-1.68106207e+24])=2.8259696741369075e+48
# f([2.35348689e+24])=5.5389005613083396e+48
# f([-3.29488165e+24])=1.0856245100164344e+49
# f([4.61283431e+24])=2.1278240396322112e+49
# f([-6.45796804e+24])=4.170535117679132e+49
# f([9.04115525e+24])=8.174248830651097e+49
# f([-1.26576174e+25])=1.6021527708076153e+50
# f([1.77206643e+25])=3.1402194307829257e+50
# f([-2.480893e+25])=6.154830084334535e+50
# f([3.4732502e+25])=1.2063466965295686e+51
# f([-4.86255028e+25])=2.3644395251979543e+51
# f([6.8075704e+25])=4.634301469387991e+51
# f([-9.53059855e+25])=9.083230880000463e+51
# f([1.3342838e+26])=1.7803132524800904e+52
# f([-1.86799732e+26])=3.4894139748609774e+52
# f([2.61519624e+26])=6.839251390727513e+52
# f([-3.66127474e+26])=1.3404932725825923e+53
# f([5.12578464e+26])=2.6273668142618798e+53
# f([-7.17609849e+26])=5.149638955953284e+53
# f([1.00465379e+27])=1.0093292353668432e+54
# f([-1.4065153e+27])=1.978285301319012e+54
# f([1.96912143e+27])=3.877439190585263e+54
# f([-2.75677e+27])=7.599780813547115e+54
# f([3.859478e+27])=1.4895570394552345e+55
# f([-5.40326919e+27])=2.919531797332259e+55
# f([7.56457687e+27])=5.722282322771227e+55
# f([-1.05904076e+28])=1.1215673352631603e+56
# f([1.48265707e+28])=2.198271977115794e+56
# f([-2.07571989e+28])=4.308613075146955e+56
# f([2.90600785e+28])=8.444881627288029e+56
# f([-4.06841099e+28])=1.6551967989484534e+57
# f([5.69577539e+28])=3.2441857259389686e+57
# f([-7.97408554e+28])=6.358604022840381e+57
# f([1.11637198e+29])=1.2462863884767143e+58
# f([-1.56292077e+29])=2.4427213214143597e+58
# f([2.18808907e+29])=4.787733789972143e+58
# f([-3.0633247e+29])=9.3839582283454e+58
# f([4.28865458e+29])=1.8392558127556984e+59
# f([-6.00411642e+29])=3.604941393001168e+59
# f([8.40576298e+29])=7.06568513028229e+59
# f([-1.17680682e+30])=1.3848742855353285e+60
# f([1.64752954e+30])=2.7143535996492426e+60
# f([-2.30654136e+30])=5.320133055312515e+60
# f([3.22915791e+30])=1.0427460788412528e+61
# f([-4.52082107e+30])=2.0437823145288553e+61
# f([6.3291495e+30])=4.005813336476555e+61
# f([-8.8608093e+30])=7.851394139494046e+61
# f([1.2405133e+31])=1.5388732513408329e+62
# f([-1.73671862e+31])=3.0161915726280315e+62
# f([2.43140607e+31])=5.91173548235094e+62
# f([-3.4039685e+31])=1.1587001545407839e+63
# f([4.7655559e+31])=2.2710523028999352e+63
# f([-6.67177826e+31])=4.451262513683873e+63
# f([9.34048956e+31])=8.724474526820388e+63
# f([-1.30766854e+32])=1.7099970072567958e+64
# f([1.83073595e+32])=3.3515941342233194e+64
# f([-2.56303034e+32])=6.569124503077704e+64
# f([3.58824247e+32])=1.2875484026032299e+65
# f([-5.02353946e+32])=2.52359486910233e+65
# f([7.03295524e+32])=4.946245943440568e+65
# f([-9.84613734e+32])=9.694642049143509e+65
# f([1.37845923e+33])=1.9001498416321272e+66
# f([-1.92984292e+33])=3.724293689598968e+66
# f([2.70178009e+33])=7.299615631613977e+66
# f([-3.78249212e+33])=1.43072466379634e+67
# f([5.29548897e+33])=2.804220341040825e+67
# f([-7.41368456e+33])=5.496271868440016e+67
# f([1.03791584e+34])=1.0772692862142431e+68
# f([-1.45308217e+34])=2.1114478009799169e+68
# f([2.03431504e+34])=4.1384376899206375e+68
# f([-2.84804106e+34])=8.111337872244448e+68
# f([3.98725748e+34])=1.5898222229599118e+69
# f([-5.58216048e+34])=3.1160515570014273e+69
# f([7.81502467e+34])=6.1074610517227955e+69
# f([-1.09410345e+35])=1.1970623661376677e+70
# f([1.53174483e+35])=2.3462422376298285e+70
# f([-2.14444277e+35])=4.5986347857544625e+70
# f([3.00221988e+35])=9.013324180078744e+70
# f([-4.20310783e+35])=1.7666115392954337e+71
# f([5.88435096e+35])=3.4625586170190507e+71
# f([-8.23809134e+35])=6.786614889357337e+71
# f([1.15333279e+36])=1.3301765183140378e+72
# f([-1.6146659e+36])=2.6071459758955145e+72
# f([2.26053226e+36])=5.1100061127552094e+72
# f([-3.16474517e+36])=1.0015611981000205e+73
# f([4.43064324e+36])=1.9630599482760403e+73
# f([-6.20290053e+36])=3.847597498621039e+73
# f([8.68406074e+36])=7.541291097297235e+73
# f([-1.2157685e+37])=1.4780930550702575e+74
# f([1.70207591e+37])=2.897062387937705e+74
# f([-2.38290627e+37])=5.6782422803579e+74
# f([3.33606877e+37])=1.1129354869501482e+75
# f([-4.67049628e+37])=2.18135355442229e+75
# f([6.5386948e+37])=4.275452966667688e+75
# f([-9.15417272e+37])=8.379887814668665e+75
# f([1.28158418e+38])=1.642458011675058e+76
# f([-1.79421785e+38])=3.2192177028831134e+76
# f([2.51190499e+38])=6.309666697650903e+76
# f([-3.51666699e+38])=1.236694672739577e+77
# f([4.92333379e+38])=2.4239215585695705e+77
# f([-6.8926673e+38])=4.750886254796358e+77
# f([9.64973422e+38])=9.311737059400857e+77
# f([-1.35096279e+39])=1.825100463642568e+78
# f([1.89134791e+39])=3.5771969087394336e+78
# f([-2.64788707e+39])=7.011305941129289e+78
# f([3.7070419e+39])=1.3742159644613408e+79
# f([-5.18985866e+39])=2.693463290344227e+79
# f([7.26580212e+39])=5.279188049074687e+79
# f([-1.0172123e+40])=1.0347208576186388e+80
# f([1.42409722e+40])=2.0280528809325322e+80
# f([-1.9937361e+40])=3.974983646627762e+80
# f([2.79123054e+40])=7.790967947390411e+80
# f([-3.90772276e+40])=1.5270297176885207e+81
# f([5.47081187e+40])=2.9929782466694993e+81
# f([-7.65913661e+40])=5.866237363472218e+81
# f([1.07227913e+41])=1.1497825232405548e+82
# f([-1.50119078e+41])=2.253573745551487e+82
# f([2.10166709e+41])=4.417004541280913e+82
# f([-2.94233392e+41])=8.65732890091059e+82
# f([4.11926749e+41])=1.6968364645784752e+83
# f([-5.76697448e+41])=3.325799470573811e+83
# f([8.07376428e+41])=6.518566962324669e+83
# f([-1.130327e+42])=1.2776391246156346e+84
# f([1.5824578e+42])=2.5041726842466426e+84
# f([-2.21544092e+42])=4.908178461123418e+84
# f([3.10161729e+42])=9.620029783801899e+84
# f([-4.3422642e+42])=1.8855258376251718e+85
# f([6.07916988e+42])=3.695630641745335e+85
# f([-8.51083783e+42])=7.243436057820856e+85
# f([1.1915173e+43])=1.4197134673328874e+86
# f([-1.66812421e+43])=2.7826383959724587e+86
# f([2.3353739e+43])=5.453971256106018e+86
# f([-3.26952346e+43])=1.0689783661967793e+87
# f([4.57733285e+43])=2.0951975977456875e+87
# f([-6.40826598e+43])=4.106587291581546e+87
# f([8.97157238e+43])=8.04891109149983e+87
# f([-1.25602013e+44])=1.577586573933967e+88
# f([1.75842819e+44])=3.0920696849105746e+88
# f([-2.46179946e+44])=6.060456582424724e+88
# f([3.44651924e+44])=1.1878494901552459e+89
# f([-4.82512694e+44])=2.3281850007042827e+89
# f([6.75517772e+44])=4.563242601380394e+89
# f([-9.45724881e+44])=8.943955498705573e+89
# f([1.32401483e+45])=1.7530152777462925e+90
# f([-1.85362077e+45])=3.4359099443827344e+90
# f([2.59506907e+45])=6.7343834909901585e+90
# f([-3.6330967e+45])=1.319939164234071e+91
# f([5.08633538e+45])=2.5870807618987793e+91
# f([-7.12086953e+45])=5.0706782933216075e+91
# f([9.96921735e+45])=9.93852945491035e+91
# f([-1.39569043e+46])=1.947951773162429e+92
# f([1.9539666e+46])=3.81798547539836e+92
# f([-2.73555324e+46])=7.483251531780784e+92
# f([3.82977454e+46])=1.4667173002290336e+93
# f([-5.36168435e+46])=2.8747659084489045e+93
# f([7.50635809e+46])=5.634541180559852e+93
# f([-1.05089013e+47])=1.104370071389731e+94
# f([1.47124619e+47])=2.164565339923872e+94
# f([-2.05974466e+47])=4.24254806625079e+94
# f([2.88364252e+47])=8.315394209851549e+94
# f([-4.03709953e+47])=1.629817265130903e+95
# f([5.65193935e+47])=3.19444183965657e+95
# f([-7.91271509e+47])=6.261106005726877e+95
# f([1.10778011e+48])=1.2271767771224678e+96
# f([-1.55089216e+48])=2.405266483160036e+96
# f([2.17124902e+48])=4.714322306993672e+96
# f([-3.03974863e+48])=9.240071721707596e+96
# f([4.25564808e+48])=1.8110540574546886e+97
# f([-5.95790731e+48])=3.549665952611189e+97
# f([8.34107024e+48])=6.95734526711793e+97
# f([-1.16774983e+49])=1.3636396723551143e+98
# f([1.63484977e+49])=2.6727337578160238e+98
# f([-2.28878967e+49])=5.2385581653194054e+98
# f([3.20430554e+49])=1.0267574004026034e+99
# f([-4.48602776e+49])=2.0124445047891028e+99
# f([6.28043886e+49])=3.944391229386642e+99
# f([-8.79261441e+49])=7.731006809597817e+99
# f([1.23096602e+50])=1.515277334681172e+100
# f([-1.72335242e+50])=2.9699435759750966e+100
# f([2.41269339e+50])=5.8210894089111895e+100
# f([-3.37777075e+50])=1.1409335241465928e+101
# f([4.72887905e+50])=2.2362297073273214e+101
# f([-6.62043067e+50])=4.38301022636155e+101
# f([9.26860294e+50])=8.590700043668638e+101
# f([-1.29760441e+51])=1.683777208559053e+102
# f([1.81664618e+51])=3.300203328775744e+102
# f([-2.54330465e+51])=6.468398524400455e+102
# f([3.5606265e+51])=1.2678061107824887e+103
# f([-4.98487711e+51])=2.484899977133677e+103
# f([6.97882795e+51])=4.870403955182007e+103
# f([-9.77035913e+51])=9.545991752156732e+103
# f([1.36785028e+52])=1.871014383422719e+104
# f([-1.91499039e+52])=3.667188191508528e+104
# f([2.68098655e+52])=7.187688855356713e+104
# f([-3.75338116e+52])=1.408787015649916e+105
# f([5.25473363e+52])=2.761222550673835e+105
# f([-7.35662708e+52])=5.411996199320715e+105
# f([1.02992779e+53])=1.0607512550668597e+106
# f([-1.44189891e+53])=2.0790724599310445e+106
# f([2.01865847e+53])=4.074982021464847e+106
# f([-2.82612186e+53])=7.986964762071098e+106
# f([3.9565706e+53])=1.565445093365935e+107
# f([-5.53919884e+53])=3.0682723829972324e+107
# f([7.75487838e+53])=6.013813870674575e+107
# f([-1.08568297e+54])=1.1787075186522166e+108
# f([1.51995616e+54])=2.3102667365583446e+108
# f([-2.12793863e+54])=4.5281228036543545e+108
# f([2.97911408e+54])=8.875120695162534e+108
# f([-4.17075971e+54])=1.739523656251857e+109
# f([5.83906359e+54])=3.4094663662536394e+109
# f([-8.17468903e+54])=6.682554077857131e+109
# f([1.14445646e+55])=1.3097805992599976e+110
# f([-1.60223905e+55])=2.567169974549595e+110
# f([2.24313467e+55])=5.031653150117205e+110
# f([-3.14038854e+55])=9.862040174229718e+110
# f([4.39654395e+55])=1.9329598741490241e+111
# f([-6.15516154e+55])=3.788601353332087e+111
# f([8.61722615e+55])=7.42565865253089e+111
# f([-1.20641166e+56])=1.4554290958960544e+112
# f([1.68897633e+56])=2.852641027956266e+112
# f([-2.36456686e+56])=5.59117641479428e+112
# f([3.3103936e+56])=1.0958705772996786e+113
# f([-4.63455104e+56])=2.1479063315073704e+113
# f([6.48837145e+56])=4.209896409754445e+113
# f([-9.08372003e+56])=8.25139696311871e+113
# f([1.2717208e+57])=1.6172738047712672e+114
# f([-1.78040913e+57])=3.1698566573516826e+114
# f([2.49257278e+57])=6.212919048409297e+114
# f([-3.48960189e+57])=1.217732133488222e+115
# f([4.88544264e+57])=2.386754981636915e+115
# f([-6.8396197e+57])=4.678039764008352e+115
# f([9.57546758e+57])=9.168957937456371e+115
# f([-1.34056546e+58])=1.7971157557414482e+116
# f([1.87679165e+58])=3.522346881253238e+116
# f([-2.6275083e+58])=6.903799887256346e+116
# f([3.67851163e+58])=1.3531447779022438e+117
# f([-5.14991628e+58])=2.6521637646883976e+117
# f([7.20988279e+58])=5.198240978789258e+117
# f([-1.00938359e+59])=1.018855231842695e+118
# f([1.41313703e+59])=1.996956254411682e+118
# f([-1.97839184e+59])=3.9140342586468956e+118
# f([2.76974857e+59])=7.671507146947914e+118
# f([-3.877648e+59])=1.503615400801791e+119
# f([5.4287072e+59])=2.947086185571511e+119
# f([-7.60019008e+59])=5.7762889237201605e+119
# f([1.06402661e+60])=1.1321526290491514e+120
# f([-1.48963726e+60])=2.219019152936337e+120
# f([2.08549216e+60])=4.3492775397552183e+120
# f([-2.91968902e+60])=8.524583977920229e+120
# f([4.08756463e+60])=1.6708184596723638e+121
# f([-5.72259048e+60])=3.274804180957833e+121
# f([8.01162667e+60])=6.418616194677353e+121
# f([-1.12162773e+61])=1.2580487741567611e+122
# f([1.57027883e+61])=2.4657755973472514e+122
# f([-2.19839036e+61])=4.8329201708006125e+122
# f([3.0777465e+61])=9.472523534769199e+122
# f([-4.3088451e+61])=1.856614612814763e+123
# f([6.03238315e+61])=3.6389646411169345e+123
# f([-8.4453364e+61])=7.132370696589189e+123
# f([1.1823471e+62])=1.3979446565314808e+124
# f([-1.65528594e+62])=2.7399715268017026e+124
# f([2.31740031e+62])=5.370344192531337e+124
# f([-3.24436043e+62])=1.0525874617361417e+125
# f([4.54210461e+62])=2.0630714250028377e+125
# f([-6.35894645e+62])=4.043619993005562e+125
# f([8.90252503e+62])=7.925495186290902e+125
# f([-1.2463535e+63])=1.5533970565130168e+126
# f([1.74489491e+63])=3.0446582307655126e+126
# f([-2.44285287e+63])=5.967530132300405e+126
# f([3.41999401e+63])=1.1696359059308794e+127
# f([-4.78799162e+63])=2.2924863756245242e+127
# f([6.70318827e+63])=4.493273296224067e+127
# f([-9.38446358e+63])=8.80681566059917e+127
# f([1.3138249e+64])=1.726135869477437e+128
# f([-1.83935486e+64])=3.383226304175776e+128
# f([2.57509681e+64])=6.631123556184522e+128
# f([-3.60513553e+64])=1.2997002170121662e+129
# f([5.04718974e+64])=2.5474124253438458e+129
# f([-7.06606563e+64])=4.992928353673935e+129
# f([9.89249189e+64])=9.786139573200913e+129
# f([-1.38494886e+65])=1.9180833563473786e+130
# f([1.93892841e+65])=3.7594433784408623e+130
# f([-2.71449977e+65])=7.368509021744087e+130
# f([3.80029968e+65])=1.4442277682618412e+131
# f([-5.32041956e+65])=2.8306864257932082e+131
# f([7.44858738e+65])=5.548145394554687e+131
# f([-1.04280223e+66])=1.0874364973327186e+132
# f([1.45992313e+66])=2.1313755347721284e+132
# f([-2.04389238e+66])=4.177496048153372e+132
# f([2.86144933e+66])=8.187892254380605e+132
# f([-4.00602906e+66])=1.6048268818585986e+133
# f([5.60844068e+66])=3.145460688442853e+133
# f([-7.85181695e+66])=6.16510294934799e+133
# f([1.09925437e+67])=1.2083601780722059e+134
# f([-1.53895612e+67])=2.3683859490215234e+134
# f([2.15453857e+67])=4.642036460082185e+134
# f([-3.016354e+67])=9.098391461761077e+134
# f([4.2228956e+67])=1.7832847265051705e+135
# f([-5.91205384e+67])=3.495238063950133e+135
# f([8.27687538e+67])=6.850666605342261e+135
# f([-1.15876255e+68])=1.3427306546470833e+136
# f([1.62226757e+68])=2.6317520831082836e+136
# f([-2.2711746e+68])=5.158234082892237e+136
# f([3.17964445e+68])=1.0110138802468783e+137
# f([-4.45150222e+68])=1.981587205283881e+137
# f([6.23210311e+68])=3.883910922356407e+137
# f([-8.72494436e+68])=7.612465407818557e+137
# f([1.22149221e+69])=1.4920432199324366e+138
# f([-1.71008909e+69])=2.9244047110675755e+138
# f([2.39412473e+69])=5.731833233692446e+138
# f([-3.35177463e+69])=1.1234393138037192e+139
# f([4.69248448e+69])=2.2019410550552897e+139
# f([-6.56947827e+69])=4.315804467908368e+139
# f([9.19726957e+69])=8.458976757100398e+139
# f([-1.28761774e+70])=1.6579594443916777e+140
# f([1.80266484e+70])=3.2496005110076882e+140
# f([-2.52373077e+70])=6.369217001575067e+140
# f([3.53322308e+70])=1.2483665323087125e+141
# f([-4.94651231e+70])=2.446798403325076e+141
# f([6.92511723e+70])=4.7957248705171493e+141
# f([-9.69516413e+70])=9.399620746213614e+141
# f([1.35732298e+71])=1.8423256662578675e+142
# f([-1.90025217e+71])=3.610958305865419e+142
# f([2.66035304e+71])=7.077478279496223e+142
# f([-3.72449425e+71])=1.3871857427812597e+143
# f([5.21429195e+71])=2.7188840558512693e+143
# f([-7.30000873e+71])=5.3290127494684885e+143
# f([1.02200122e+72])=1.0444864988958236e+144
# f([-1.43080171e+72])=2.047193537835814e+144
# f([2.0031224e+72])=4.012499334158196e+144
# f([-2.80437135e+72])=7.864498694950062e+144
# f([3.9261199e+72])=1.541441744210212e+145
# f([-5.49656786e+72])=3.021225818652016e+145
# f([7.695195e+72])=5.92160260455795e+145
# f([-1.0773273e+73])=1.160634110493358e+146
# f([1.50825822e+73])=2.274842856566981e+146
# f([-2.11156151e+73])=4.458691998871283e+146
# f([2.95618611e+73])=8.739036317787716e+146
# f([-4.13866055e+73])=1.7128511182863924e+147
# f([5.79412478e+73])=3.3571881918413295e+147
# f([-8.11177469e+73])=6.580088856009005e+147
# f([1.13564846e+74])=1.2896974157777648e+148
# f([-1.58990784e+74])=2.527806934924418e+148
# f([2.22587097e+74])=4.9545015924518596e+148
# f([-3.11621936e+74])=9.710823121205643e+148
# f([4.36270711e+74])=1.9033213317563058e+149
# f([-6.10778995e+74])=3.7305098102423594e+149
# f([8.55090593e+74])=7.311799228075023e+149
# f([-1.19712683e+75])=1.4331126487027045e+150
# f([1.67597756e+75])=2.8089007914573006e+150
# f([-2.34636859e+75])=5.5054455512563055e+150
# f([3.28491602e+75])=1.0790673280462357e+151
# f([-4.59888243e+75])=2.1149719629706218e+151
# f([6.43843541e+75])=4.145345047422417e+151
# f([-9.01380957e+75])=8.124876292947933e+151
# f([1.26193334e+76])=1.5924757534177944e+152
# f([-1.76670668e+76])=3.1212524766988756e+152
# f([2.47338935e+76])=6.117654854329795e+152
# f([-3.46274508e+76])=1.1990603514486392e+153
# f([4.84784312e+76])=2.350158288839332e+153
# f([-6.78698036e+76])=4.606310246125091e+153
# f([9.50177251e+76])=9.028368082405175e+153
# f([-1.33024815e+77])=1.769560144151414e+154
# f([1.86234741e+77])=3.468337882536771e+154
# f([-2.60728638e+77])=6.79794224977207e+154
# f([3.65020093e+77])=1.332396680955325e+155
# f([-5.1102813e+77])=2.6114974946724363e+155
# f([7.15439382e+77])=5.118535089557975e+155
# f([-1.00161513e+78])=1.003232877553363e+156
# f([1.40226119e+78])=1.9663364400045905e+156
# f([-1.96316566e+78])=3.8540194224089986e+156
# f([2.74843193e+78])=7.553878067921637e+156
# f([-3.8478047e+78])=1.4805601013126406e+157
# f([5.38692658e+78])=2.901897798572775e+157
# f([-7.54169721e+78])=5.68771968520264e+157
# f([1.05583761e+79])=1.1147930582997168e+158
# f([-1.47817265e+79])=2.1849943942674445e+158
# f([2.06944172e+79])=4.2825890127641897e+158
# f([-2.8972184e+79])=8.393874465017812e+158
# f([4.05610576e+79])=1.6451993951434905e+159
# f([-5.67854807e+79])=3.2245908144812405e+159
# f([7.94996729e+79])=6.320197996383232e+159
# f([-1.11299542e+80])=1.2387588072911131e+160
# f([1.55819359e+80])=2.4279672622905813e+160
# f([-2.18147103e+80])=4.7588158340895393e+160
# f([3.05405944e+80])=9.327279034815496e+160
# f([-4.27568321e+80])=1.828146690823837e+161
# f([5.98595649e+80])=3.583167514014719e+161
# f([-8.38033909e+80])=7.023008327468848e+161
# f([1.17324747e+81])=1.3765096321838935e+162
# f([-1.64254646e+81])=2.6979588790804304e+162
# f([2.29956505e+81])=5.287999402997642e+162
# f([-3.21939107e+81])=1.0364478829875378e+163
# f([4.50714749e+81])=2.0314378506555728e+163
# f([-6.31000649e+81])=3.981618187284922e+163
# f([8.83400908e+81])=7.803971647078447e+163
# f([-1.23676127e+82])=1.5295784428273753e+164
# f([1.73146578e+82])=2.997973747941655e+164
# f([-2.42405209e+82])=5.876028545965643e+164
# f([3.39367293e+82])=1.1517015950092655e+165
# f([-4.7511421e+82])=2.2573351262181602e+165
# f([6.65159894e+82])=4.424376847387593e+165
# f([-9.31223852e+82])=8.671778620879681e+165
# f([1.30371339e+83])=1.6996686096924175e+166
# f([-1.82519875e+83])=3.331350474997139e+166
# f([2.55527825e+83])=6.529446930994391e+166
# f([-3.57738955e+83])=1.2797715984749008e+167
# f([5.00834537e+83])=2.508352333010805e+167
# f([-7.01168352e+83])=4.916370572701178e+167
# f([9.81635692e+83])=9.636086322494307e+167
# f([-1.37428997e+84])=1.8886729192088842e+168
# f([1.92400596e+84])=3.701798921649413e+168
# f([-2.69360834e+84])=7.255525886432851e+168
# f([3.77105168e+84])=1.422083073740839e+169
# f([-5.27947235e+84])=2.7872828245320437e+169
# f([7.39126128e+84])=5.463074336082806e+169
# f([-1.03477658e+85])=1.07076256987223e+170
# f([1.44868721e+85])=2.0986946369495705e+170
# f([-2.0281621e+85])=4.1134414884211566e+170
# f([2.83942693e+85])=8.062345317305467e+170
# f([-3.97519771e+85])=1.5802196821918716e+171
# f([5.56527679e+85])=3.097230577096067e+171
# f([-7.79138751e+85])=6.07057193110829e+171
# f([1.09079425e+86])=1.189832098497225e+172
# f([-1.52711195e+86])=2.3320709130545614e+172
# f([2.13795673e+86])=4.570858989586939e+172
# f([-2.99313943e+86])=8.958883619590402e+172
# f([4.1903952e+86])=1.7559411894397184e+173
# f([-5.86655327e+86])=3.441644731301848e+173
# f([8.21317458e+86])=6.74562367335162e+173
# f([-1.14984444e+87])=1.3221422399769174e+174
# f([1.60978222e+87])=2.5913987903547583e+174
# f([-2.25369511e+87])=5.079141629095324e+174
# f([3.15517315e+87])=9.955117593026832e+174
# f([-4.41724241e+87])=1.9512030482332588e+175
# f([6.18413937e+87])=3.824357974537186e+175
# f([-8.65779512e+87])=7.495741630092883e+175
# f([1.21209132e+88])=1.4691653594982052e+176
# f([-1.69692784e+88])=2.8795641046164816e+176
# f([2.37569898e+88])=5.643945645048302e+176
# f([-3.32597857e+88])=1.106213346429467e+177
# f([4.65637e+88])=2.1681781590017557e+177
# f([-6.518918e+88])=4.249629191643441e+177
# f([9.1264852e+88])=8.329273215621146e+177
# f([-1.27770793e+89])=1.6325375502617442e+178
# f([1.7887911e+89])=3.199773598513018e+178
# f([-2.50430754e+89])=6.2715562530855154e+178
# f([3.50603056e+89])=1.2292250256047604e+179
# f([-4.90844278e+89])=2.40928105018533e+179
# f([6.87181989e+89])=4.722190858363246e+179
# f([-9.62054784e+89])=9.25549408239196e+179
# f([1.3468767e+90])=1.8140768401488239e+180
# f([-1.88562738e+90])=3.5555906066916948e+180
# f([2.63987833e+90])=6.96895758911572e+180
# f([-3.69582966e+90])=1.3659156874666811e+181
# f([5.17416152e+90])=2.6771947474346943e+181
# f([-7.24382613e+90])=5.2473017049720005e+181
# f([1.01413566e+91])=1.0284711341745117e+182
# f([-1.41978992e+91])=2.0158034229820427e+182
# f([1.98770589e+91])=3.950974709044804e+182
# f([-2.78278825e+91])=7.743910429727817e+182
# f([3.89590355e+91])=1.5178064442266518e+183
# f([-5.45426496e+91])=2.974900630684237e+183
# f([7.63597095e+91])=5.830805236141103e+183
# f([-1.06903593e+92])=1.1428378262836561e+184
# f([1.49665031e+92])=2.2399621395159654e+184
# f([-2.09531043e+92])=4.390325793451293e+184
# f([2.9334346e+92])=8.605038555164536e+184
# f([-4.10680844e+92])=1.686587556812249e+185
# f([5.74953182e+92])=3.3057116113520077e+185
# f([-8.04934454e+92])=6.479194758249933e+185
# f([1.12690824e+93])=1.2699221726169865e+186
# f([-1.57767153e+93])=2.489047458329293e+186
# f([2.20874014e+93])=4.8785330183254155e+186
# f([-3.0922362e+93])=9.561924715917816e+186
# f([4.32913068e+93])=1.8741372443198914e+187
# f([-6.06078295e+93])=3.6733089988669874e+187
# f([8.48509613e+93])=7.199685637779292e+187
# f([-1.18791346e+94])=1.411138385004741e+188
# f([1.66307884e+94])=2.7658312346092922e+188
# f([-2.32831038e+94])=5.421029219834212e+188
# f([3.25963453e+94])=1.0625217270875056e+189
# f([-4.56348834e+94])=2.08254258509151e+189
# f([6.38888368e+94])=4.08178346677936e+189
# f([-8.94443715e+94])=8.000295594887543e+189
# f([1.2522212e+95])=1.5680579365979583e+190
# f([-1.75310968e+95])=3.0733935557319976e+190
# f([2.45435355e+95])=6.023851369234716e+190
# f([-3.43609498e+95])=1.1806748683700047e+191
# f([4.81053297e+95])=2.3141227420052084e+191
# f([-6.73474615e+95])=4.535680574330207e+191
# f([9.42864461e+95])=8.889933925687205e+191
# f([-1.32001025e+96])=1.742427049434692e+192
# f([1.84801434e+96])=3.415157016891997e+192
# f([-2.58722008e+96])=6.69370775310831e+192
# f([3.62210811e+96])=1.3119667196092288e+193
# f([-5.07095136e+96])=2.571454770434088e+193
# f([7.09933191e+96])=5.040051350050812e+193
# f([-9.93906467e+96])=9.87850064609959e+193
# f([1.39146905e+97])=1.936186126635519e+194
# f([-1.94805667e+97])=3.794924808205616e+194
# f([2.72727934e+97])=7.438052624083006e+194
# f([-3.81819108e+97])=1.457858314320269e+195
# f([5.34546752e+97])=2.8574022960677273e+195
# f([-7.48365452e+97])=5.600508500292745e+195
# f([1.04771163e+98])=1.0976996660573779e+196
# f([-1.46679629e+98])=2.15149134547246e+196
# f([2.0535148e+98])=4.21692303712602e+196
# f([-2.87492072e+98])=8.265169152766998e+196
# f([4.02488901e+98])=1.6199731539423316e+197
# f([-5.63484461e+98])=3.17514738172697e+197
# f([7.88878246e+98])=6.223288868184859e+197
# f([-1.10442954e+99])=1.2197646181642327e+198
# f([1.54620136e+99])=2.3907386516018963e+198
# f([-2.16468191e+99])=4.685847757139717e+198
# f([3.03055467e+99])=9.184261603993845e+198
# f([-4.24277654e+99])=1.8001152743827934e+199
# f([5.93988715e+99])=3.5282259377902755e+199
# f([-8.31584201e+99])=6.915322838068939e+199
# f([1.16421788e+100])=1.3554032762615113e+200
# f([-1.62990503e+100])=2.656590421472562e+200
# f([2.28186705e+100])=5.206917226086221e+200
# f([-3.19461387e+100])=1.0205557763128994e+201
# f([4.47245941e+100])=2.0002893215732816e+201
# f([-6.26144318e+100])=3.9205670702836314e+201
# f([8.76602045e+100])=7.684311457755919e+201
# f([-1.22724286e+101])=1.5061250457201598e+202
# f([1.71814001e+101])=2.952005089611512e+202
# f([-2.40539601e+101])=5.785929975638562e+202
# f([3.36755442e+101])=1.1340422752251581e+203
# f([-4.71457618e+101])=2.222722859441309e+203
# f([6.60040666e+101])=4.356536804504967e+203
# f([-9.24056932e+101])=8.538812136829736e+203
# f([1.2936797e+102])=1.6736071788186279e+204
# f([-1.81115159e+102])=3.280270070484511e+204
# f([2.53561222e+102])=6.42932933814964e+204
# f([-3.54985711e+102])=1.260148550277329e+205
# f([4.96979995e+102])=2.469891158543564e+205
# f([-6.95771994e+102])=4.840986670745386e+205
# f([9.74080791e+102])=9.488333874660954e+205
# f([-1.36371311e+103])=1.859713439433547e+206
# f([1.90919835e+103])=3.645038341289751e+206
# f([-2.67287769e+103])=7.14427514892791e+206
# f([3.74202877e+103])=1.40027792918987e+207
# f([-5.23884027e+103])=2.7445447412121456e+207
# f([7.33437638e+103])=5.379307692775805e+207
# f([-1.02681269e+104])=1.0543443077840578e+208
# f([1.43753777e+104])=2.066514843256753e+208
# f([-2.01255288e+104])=4.0503690927832358e+208
# f([2.81757403e+104])=7.938723421855141e+208
# f([-3.94460364e+104])=1.5559897906836072e+209
# f([5.5224451e+104])=3.0497399897398693e+209
# f([-7.73142314e+104])=5.977490379890142e+209
# f([1.08239924e+105])=1.1715881144584678e+210
# f([-1.51535894e+105])=2.2963127043385963e+210
# f([2.12150251e+105])=4.500772900503648e+210
# f([-2.97010351e+105])=8.82151488498715e+210
# f([4.15814492e+105])=1.729016917457481e+211
# f([-5.82140289e+105])=3.3888731582166614e+211
# f([8.14996404e+105])=6.642191390104655e+211
# f([-1.14099497e+106])=1.3018695124605126e+212
# f([1.59739295e+106])=2.551664244422605e+212
# f([-2.23635013e+106])=5.001261919068305e+212
# f([3.13089019e+106])=9.802473361373875e+212
# f([-4.38324626e+106])=1.9212847788292793e+213
# f([6.13654477e+106])=3.765718166505387e+213
# f([-8.59116267e+106])=7.380807606350555e+213
# f([1.20276277e+107])=1.4466382908447088e+214
# f([-1.68386788e+107])=2.835411050055629e+214
# f([2.35741504e+107])=5.557405658109031e+214
# f([-3.30038105e+107])=1.0892515089893699e+215
# f([4.62053347e+107])=2.134932957619164e+215
# f([-6.46874686e+107])=4.1844685969335606e+215
# f([9.05624561e+107])=8.201558449989778e+215
# f([-1.26787439e+108])=1.6075054561979957e+216
# f([1.77502414e+108])=3.150710694148072e+216
# f([-2.48503379e+108])=6.175392960530219e+216
# f([3.47904731e+108])=1.2103770202639228e+217
# f([-4.87066624e+108])=2.3723389597172887e+217
# f([6.81893273e+108])=4.649784361045884e+217
# f([-9.54650583e+108])=9.113577347649931e+217
# f([1.33651082e+109])=1.786261160139387e+218
# f([-1.87111514e+109])=3.5010718738731974e+218
# f([2.6195612e+109])=6.862100872791463e+218
# f([-3.66738568e+109])=1.3449717710671264e+219
# f([5.13433995e+109])=2.6361446712915666e+219
# f([-7.18807593e+109])=5.1668435557314695e+219
# f([1.00633063e+110])=1.0127013369233677e+220
# f([-1.40886288e+110])=1.9848946203698004e+220
# f([1.97240803e+110])=3.8903934559248077e+220
# f([-2.76137125e+110])=7.625171173612623e+220
# f([3.86591975e+110])=1.494533550028074e+221
# f([-5.41228765e+110])=2.9292857580550246e+221
# f([7.57720271e+110])=5.741400085787845e+221
# f([-1.06080838e+111])=1.1253144168144176e+222
# f([1.48513173e+111])=2.2056162569562593e+222
# f([-2.07918442e+111])=4.323007863634269e+222
# f([2.91085819e+111])=8.473095412723168e+222
# f([-4.07520147e+111])=1.6607267008937404e+223
# f([5.70528206e+111])=3.25502433375173e+223
# f([-7.98739488e+111])=6.37984769415339e+223
# f([1.11823528e+112])=1.2504501480540641e+224
# f([-1.5655294e+112])=2.450882290185965e+224
# f([2.19174115e+112])=4.803729288764491e+224
# f([-3.06843762e+112])=9.4153094059784e+224
# f([4.29581266e+112])=1.845400643571766e+225
# f([-6.01413773e+112])=3.616985261400661e+225
# f([8.41979282e+112])=7.089291112345295e+225
# f([-1.17877099e+113])=1.3895010580196773e+226
# f([1.65027939e+113])=2.723422073718568e+226
# f([-2.31039115e+113])=5.337907264488391e+226
# f([3.23454761e+113])=1.0462298238397244e+227
# f([-4.52836665e+113])=2.050610454725859e+227
# f([6.33971331e+113])=4.019196491262684e+227
# f([-8.87559864e+113])=7.877625122874858e+227
# f([1.24258381e+114])=1.5440145240834718e+228
# f([-1.73961733e+114])=3.0262684672036038e+228
# f([2.43546427e+114])=5.931486195719063e+228
# f([-3.40964997e+114])=1.162571294360936e+229
# f([4.77350996e+114])=2.278639736947434e+229
# f([-6.68291395e+114])=4.4661338844169705e+229
# f([9.35607953e+114])=8.753622413457262e+229
# f([-1.30985113e+115])=1.7157099930376234e+230
# f([1.83379159e+115])=3.3627915863537414e+230
# f([-2.56730822e+115])=6.591071509253333e+230
# f([3.59423151e+115])=1.2918500158136531e+231
# f([-5.03192412e+115])=2.5320260309947605e+231
# f([7.04469376e+115])=4.96277102074973e+231
# f([-9.86257127e+115])=9.72703120066947e+231
# f([1.38075998e+116])=1.9064981153312163e+232
# f([-1.93306397e+116])=3.7367363060491847e+232
# f([2.70628956e+116])=7.324003159856399e+232
# f([-3.78880538e+116])=1.4355046193318545e+233
# f([5.30432753e+116])=2.813589053890434e+233
# f([-7.42605854e+116])=5.514634545625248e+233
# f([1.0396482e+117])=1.0808683709425485e+234
# f([-1.45550747e+117])=2.118502007047395e+234
# f([2.03771046e+117])=4.1522639338128934e+234
# f([-2.85279465e+117])=8.13843731027327e+234
# f([3.99391251e+117])=1.5951337128135612e+235
# f([-5.59147751e+117])=3.12646207711458e+235
# f([7.82806852e+117])=6.127865671144577e+235
# f([-1.09592959e+118])=1.2010616715443367e+236
# f([1.53430143e+118])=2.3540808762269e+236
# f([-2.148022e+118])=4.613998517404723e+236
# f([3.0072308e+118])=9.043437094113258e+236
# f([-4.21012312e+118])=1.7725136704461983e+237
# f([5.89417237e+118])=3.474126794074548e+237
# f([-8.25184132e+118])=6.809288516386115e+237
# f([1.15525778e+119])=1.334620549211678e+238
# f([-1.6173609e+119])=2.6158562764548886e+238
# f([2.26430526e+119])=5.127078301851582e+238
# f([-3.17002736e+119])=1.0049073471629099e+239
# f([4.43803831e+119])=1.9696184004393032e+239
# f([-6.21325363e+119])=3.8604520648610343e+239
# f([8.69855508e+119])=7.566486047127624e+239
# f([-1.21779771e+120])=1.4830312652370143e+240
# f([1.7049168e+120])=2.906741279864548e+240
# f([-2.38688351e+120])=5.697212908534513e+240
# f([3.34163692e+120])=1.1166537300727644e+241
# f([-4.67829169e+120])=2.1886413109426177e+241
# f([6.54960836e+120])=4.289736969447529e+241
# f([-9.16945171e+120])=8.407884460117155e+241
# f([1.28372324e+121])=1.647945354182962e+242
# f([-1.79721253e+121])=3.229972894198605e+242
# f([2.51609755e+121])=6.330746872629262e+242
# f([-3.52253657e+121])=1.240826387035335e+243
# f([4.93155119e+121])=2.4320197185892572e+243
# f([-6.90417167e+121])=4.766758648434944e+243
# f([9.66584034e+121])=9.34284695093249e+243
# f([-1.35321765e+122])=1.8311980023827682e+244
# f([1.89450471e+122])=3.5891480846702256e+244
# f([-2.65230659e+122])=7.034730245953643e+244
# f([3.71322923e+122])=1.3788071282069137e+245
# f([-5.19852092e+122])=2.7024619712855503e+245
# f([7.27792928e+122])=5.296825463719678e+245
# f([-1.0189101e+123])=1.0381777908890567e+246
# f([1.42647414e+123])=2.034828470142551e+246
# f([-1.9970638e+123])=3.988263801479399e+246
# f([2.79588931e+123])=7.816997050899619e+246
# f([-3.91424504e+123])=1.5321314219763247e+247
# f([5.47994305e+123])=3.0029775870735964e+247
# f([-7.67192028e+123])=5.885836070664247e+247
# f([1.07406884e+124])=1.1536238698501918e+248
# f([-1.50369637e+124])=2.261102784906376e+248
# f([2.10517492e+124])=4.431761458416496e+248
# f([-2.94724489e+124])=8.686252458496329e+248
# f([4.12614285e+124])=1.7025054818652802e+249
# f([-5.77659999e+124])=3.336910744455949e+249
# f([8.08723999e+124])=6.540345059133659e+249
# f([-1.1322136e+125])=1.281907631590197e+250
# f([1.58509904e+125])=2.5125389579167864e+250
# f([-2.21913865e+125])=4.9245763575168995e+250
# f([3.10679411e+125])=9.652169660733122e+250
# f([-4.34951176e+125])=1.891825253503692e+251
# f([6.08931646e+125])=3.7079774968672356e+251
# f([-8.52504305e+125])=7.267635893859783e+251
# f([1.19350603e+126])=1.4244566351965177e+252
# f([-1.67090844e+126])=2.7919350049851737e+252
# f([2.33927181e+126])=5.4721926097709386e+252
# f([-3.27498054e+126])=1.072549751515104e+253
# f([4.58497275e+126])=2.102197512969603e+253
# f([-6.41896185e+126])=4.12030712542042e+253
# f([8.98654659e+126])=8.075801965824022e+253
# f([-1.25811652e+127])=1.582857185301508e+254
# f([1.76136313e+127])=3.1024000831909555e+254
# f([-2.46590838e+127])=6.080704163054272e+254
# f([3.45227174e+127])=1.1918180159586373e+255
# f([-4.83318043e+127])=2.3359633112789288e+255
# f([6.76645261e+127])=4.5784880901067e+255
# f([-9.47303365e+127])=8.97383665660913e+255
# f([1.32622471e+128])=1.7588719846953894e+256
# f([-1.8567146e+128])=3.4473890900029636e+256
# f([2.59940043e+128])=6.756882616405806e+256
# f([-3.63916061e+128])=1.3243489928155373e+257
# f([5.09482485e+128])=2.5957240259184534e+257
# f([-7.13275479e+128])=5.087619090800168e+257
# f([9.98585671e+128])=9.971733417968329e+257
# f([-1.39801994e+129])=1.954459749921793e+258
# f([1.95722791e+129])=3.830741109846714e+258
# f([-2.74011908e+129])=7.508252575299557e+258
# f([3.83616671e+129])=1.4716175047587127e+259
# f([-5.3706334e+129])=2.884370309327077e+259
# f([7.51888676e+129])=5.653365806281069e+259
# f([-1.05264415e+130])=1.1080596980310896e+260
# f([1.4737018e+130])=2.1717970081409353e+260
# f([-2.06318253e+130])=4.256722135956233e+260
# f([2.88845554e+130])=8.343175386474214e+260
# f([-4.04383775e+130])=1.6352623757489462e+261
# f([5.66137285e+130])=3.205114256467934e+261
# f([-7.92592199e+130])=6.282023942677149e+261
# f([1.10962908e+131])=1.2312766927647213e+262
# f([-1.55348071e+131])=2.413302317818854e+262
# f([2.17487299e+131])=4.7300725429249525e+262
# f([-3.04482219e+131])=9.270942184132906e+262
# f([4.26275107e+131])=1.8171046680900497e+263
# f([-5.9678515e+131])=3.561525149456498e+263
# f([8.3549921e+131])=6.980589292934736e+263
# f([-1.16969889e+132])=1.368195501415208e+264
# f([1.63757845e+132])=2.681663182773808e+264
# f([-2.29260983e+132])=5.256059838236664e+264
# f([3.20965376e+132])=1.030187728294386e+265
# f([-4.49351527e+132])=2.019167947456996e+265
# f([6.29092138e+132])=3.9575691770157106e+265
# f([-8.80728993e+132])=7.75683558695079e+265
# f([1.23302059e+133])=1.5203397750423552e+266
# f([-1.72622883e+133])=2.979865959083015e+266
# f([2.41672036e+133])=5.840537279802708e+266
# f([-3.3834085e+133])=1.1447453068413309e+267
# f([4.7367719e+133])=2.2437008014090084e+267
# f([-6.63148066e+133])=4.397653570761656e+267
# f([9.28407292e+133])=8.619400998692844e+267
# f([-1.29977021e+134])=1.689402595743797e+268
# f([1.81967829e+134])=3.311229087657842e+268
# f([-2.54754961e+134])=6.490009011809371e+268
# f([3.56656945e+134])=1.2720417663146364e+269
# f([-4.99319723e+134])=2.4932018619766864e+269
# f([6.99047613e+134])=4.886675649474304e+269
# f([-9.78666658e+134])=9.577884272969632e+269
# f([1.37013332e+135])=1.8772653175020472e+270
# f([-1.91818665e+135])=3.679440022304013e+270
# f([2.68546131e+135])=7.211702443715862e+270
# f([-3.75964583e+135])=1.4134936789683085e+271
# f([5.26350417e+135])=2.7704476107778846e+271
# f([-7.36890583e+135])=5.430077317124652e+271
# f([1.03164682e+136])=1.0642951541564316e+272
# f([-1.44430554e+136])=2.086018502146606e+272
# f([2.02202776e+136])=4.088596264207347e+272
# f([-2.83083886e+136])=8.013648677846402e+272
# f([3.96317441e+136])=1.5706751408578947e+273
# f([-5.54844417e+136])=3.0785232760814736e+273
# f([7.76782184e+136])=6.033905621119689e+273
# f([-1.08749506e+137])=1.1826455017394586e+274
# f([1.52249308e+137])=2.3179851834093386e+274
# f([-2.13149031e+137])=4.543250959482303e+274
# f([2.98408644e+137])=8.904771880585313e+274
# f([-4.17772102e+137])=1.745335288594721e+275
# f([5.84880942e+137])=3.420857165645653e+275
# f([-8.18833319e+137])=6.704880044665478e+275
# f([1.14636665e+138])=1.3141564887544338e+276
# f([-1.60491331e+138])=2.5757467179586892e+276
# f([2.24687863e+138])=5.048463567199029e+276
# f([-3.14563008e+138])=9.8949885917101e+276
# f([4.40388211e+138])=1.9394177639751793e+277
# f([-6.16543495e+138])=3.801258817391351e+277
# f([8.63160894e+138])=7.450467282087046e+277
# f([-1.20842525e+139])=1.460291587289061e+278
# f([1.69179535e+139])=2.8621715110865595e+278
# f([-2.36851349e+139])=5.6098561617296564e+278
# f([3.31591889e+139])=1.0995318076990124e+279
# f([-4.64228644e+139])=2.1550823430900642e+279
# f([6.49920102e+139])=4.223961392456526e+279
# f([-9.09888143e+139])=8.278964329214789e+279
# f([1.2738434e+140])=1.6226770085260988e+280
# f([-1.78338076e+140])=3.1804469367111528e+280
# f([2.49673306e+140])=6.233675995953859e+280
# f([-3.49542629e+140])=1.2218004952069566e+281
# f([4.89359681e+140])=2.3947289706056345e+281
# f([-6.85103553e+140])=4.6936687823870433e+281
# f([9.59144974e+140])=9.199590813478602e+281
# f([-1.34280296e+141])=1.803119799441806e+282
# f([1.87992415e+141])=3.534114806905938e+282
# f([-2.63189381e+141])=6.926865021535636e+282
# f([3.68465133e+141])=1.3576655442209841e+283
# f([-5.15851187e+141])=2.6610244666731285e+283
# f([7.22191661e+141])=5.21560795467933e+283
# f([-1.01106833e+142])=1.0222591591171484e+284
# f([1.41549566e+142])=2.0036279518696102e+284
# f([-1.98169392e+142])=3.927110785664437e+284
# f([2.77437149e+142])=7.697137139902291e+284
# f([-3.88412008e+142])=1.5086388794208486e+285
# f([5.43776811e+142])=2.956932203664863e+285
# f([-7.61287536e+142])=5.795587119183132e+285
# f([1.06580255e+143])=1.1359350753598937e+286
# f([-1.49212357e+143])=2.226432747705391e+286
# f([2.088973e+143])=4.363808185502565e+286
# f([-2.9245622e+143])=8.553064043585027e+286
# f([4.09438708e+143])=1.6764005525426646e+287
# f([-5.73214191e+143])=3.285745082983622e+287
# f([8.02499867e+143])=6.440060362647899e+287
# f([-1.12349981e+144])=1.2622518310789883e+288
# f([1.57289974e+144])=2.474013588914816e+288
# f([-2.20205963e+144])=4.8490666342730405e+288
# f([3.08288349e+144])=9.504170603175158e+288
# f([-4.31603688e+144])=1.8628174382223313e+289
# f([6.04245164e+144])=3.651122178915769e+289
# f([-8.45943229e+144])=7.156199470674904e+289
# f([1.18432052e+145])=1.402615096252281e+290
# f([-1.65804873e+145])=2.7491255886544714e+290
# f([2.32126822e+145])=5.388286153762764e+290
# f([-3.24977551e+145])=1.056104086137502e+291
# f([4.54968571e+145])=2.0699640088295042e+291
# f([-6.36956e+145])=4.057129457305828e+291
# f([8.917384e+145])=7.951973736319421e+291
# f([-1.24843376e+146])=1.5585868523186068e+292
# f([1.74780726e+146])=3.05483023054447e+292
# f([-2.44693017e+146])=5.987467251867161e+292
# f([3.42570224e+146])=1.1735435813659638e+293
# f([-4.79598313e+146])=2.300145419477288e+293
# f([6.71437638e+146])=4.508285022175484e+293
# f([-9.40012694e+146])=8.836238643463952e+293
# f([1.31601777e+147])=1.7319027741189343e+294
# f([-1.84242488e+147])=3.3945294372731103e+294
# f([2.57939483e+147])=6.653277697055296e+294
# f([-3.61115276e+147])=1.3040424286228377e+295
# f([5.05561387e+147])=2.555923160100761e+295
# f([-7.07785942e+147])=5.00960939379749e+295
# f([9.90900318e+147])=9.818834411843078e+295
# f([-1.38726045e+148])=1.9244915447212427e+296
# f([1.94216462e+148])=3.772003427653636e+296
# f([-2.71903047e+148])=7.393126718201126e+296
# f([3.80664266e+148])=1.4490528367674202e+297
# f([-5.32929973e+148])=2.840143560064143e+297
# f([7.46101962e+148])=5.566681377725719e+297
# f([-1.04454275e+149])=1.0910695500342401e+298
# f([1.46235985e+149])=2.13849631806711e+298
# f([-2.04730378e+149])=4.1914527834115365e+298
# f([2.8662253e+149])=8.215247455486609e+298
# f([-4.01271542e+149])=1.6101885012753749e+299
# f([5.61780158e+149])=3.1559694624997356e+299
# f([-7.86492222e+149])=6.185700146499482e+299
# f([1.10108911e+150])=1.2123972287138984e+300
# f([-1.54152475e+150])=2.376298568279241e+300
# f([2.15813466e+150])=4.6575451938273124e+300
# f([-3.02138852e+150])=9.128788579901532e+300
# f([4.22994393e+150])=1.7892425616606996e+301
# f([-5.9219215e+150])=3.506915420854971e+301
# f([8.29069009e+150])=6.873554224875742e+301
# f([-1.16069661e+151])=1.3472166280756452e+302
# f([1.62497526e+151])=2.6405445910282644e+302
# f([-2.27496536e+151])=5.175467398415397e+302
# f([3.18495151e+151])=1.0143916100894178e+303
# f([-4.45893211e+151])=1.988207555775259e+303
# f([6.24250495e+151])=3.8968868093195065e+303
# f([-8.73950693e+151])=7.63789814626623e+303
# f([1.22353097e+152])=1.4970280366681817e+304
# f([-1.71294336e+152])=2.9341749518696363e+304
# f([2.3981207e+152])=5.750982905664487e+304
# f([-3.35736898e+152])=1.1271926495102393e+305
# f([4.70031658e+152])=2.209297593040069e+305
# f([-6.58044321e+152])=4.330223282358535e+305
# f([9.21262049e+152])=8.487237633422727e+305
# f([-1.28976687e+153])=1.6634985761508545e+306
# f([1.80567362e+153])=3.260457209255674e+306
# f([-2.52794306e+153])=6.390496130141118e+306
# f([3.53912029e+153])=1.2525372415076592e+307
# f([-4.9547684e+153])=2.4549729933550124e+307
# f([6.93667577e+153])=4.811747066975823e+307
# f([-9.71134607e+153])=9.431024251272611e+307
# f([1.35958845e+154])=inf
# f([-1.90342383e+154])=inf
# f([2.66479336e+154])=inf
# f([-3.73071071e+154])=inf
# f([5.22299499e+154])=inf
# f([-7.31219299e+154])=inf
# f([1.02370702e+155])=inf
# f([-1.43318983e+155])=inf
# f([2.00646576e+155])=inf
# f([-2.80905206e+155])=inf
# f([3.93267288e+155])=inf
# f([-5.50574203e+155])=inf
# f([7.70803884e+155])=inf
# f([-1.07912544e+156])=inf
# f([1.51077561e+156])=inf
# f([-2.11508586e+156])=inf
# f([2.9611202e+156])=inf
# f([-4.14556828e+156])=inf
# f([5.8037956e+156])=inf
# f([-8.12531384e+156])=inf
# f([1.13754394e+157])=inf
# f([-1.59256151e+157])=inf
# f([2.22958612e+157])=inf
# f([-3.12142056e+157])=inf
# f([4.36998879e+157])=inf
# f([-6.1179843e+157])=inf
# f([8.56517803e+157])=inf
# f([-1.19912492e+158])=inf
# f([1.67877489e+158])=inf
# f([-2.35028485e+158])=inf
# f([3.29039879e+158])=inf
# f([-4.60655831e+158])=inf
# f([6.44918163e+158])=inf
# f([-9.02885428e+158])=inf
# f([1.2640396e+159])=inf
# f([-1.76965544e+159])=inf
# f([2.47751761e+159])=inf
# f([-3.46852466e+159])=inf
# f([4.85593452e+159])=inf
# f([-6.79830833e+159])=inf
# f([9.51763167e+159])=inf
# f([-1.33246843e+160])=inf
# f([1.86545581e+160])=inf
# f([-2.61163813e+160])=inf
# f([3.65629338e+160])=inf
# f([-5.11881073e+160])=inf
# f([7.16633503e+160])=inf
# f([-1.0032869e+161])=inf
# f([1.40460167e+161])=inf
# f([-1.96644233e+161])=inf
# f([2.75301926e+161])=inf
# f([-3.85422697e+161])=inf
# f([5.39591776e+161])=inf
# f([-7.55428486e+161])=inf
# f([1.05759988e+162])=inf
# f([-1.48063983e+162])=inf
# f([2.07289577e+162])=inf
# f([-2.90205407e+162])=inf
# f([4.0628757e+162])=inf
# f([-5.68802598e+162])=inf
# f([7.96323637e+162])=inf
# f([-1.11485309e+163])=inf
# f([1.56079433e+163])=inf
# f([-2.18511206e+163])=inf
# f([3.05915689e+163])=inf
# f([-4.28281964e+163])=inf
# f([5.9959475e+163])=inf
# f([-8.39432649e+163])=inf
# f([1.17520571e+164])=inf
# f([-1.64528799e+164])=inf
# f([2.30340319e+164])=inf
# f([-3.22476447e+164])=inf
# f([4.51467025e+164])=inf
# f([-6.32053835e+164])=inf
# f([8.84875369e+164])=inf
# f([-1.23882552e+165])=inf
# f([1.73435572e+165])=inf
# f([-2.42809801e+165])=inf
# f([3.39933722e+165])=inf
# f([-4.75907211e+165])=inf
# f([6.66270095e+165])=inf
# f([-9.32778133e+165])=inf
# f([1.30588939e+166])=inf
# f([-1.82824514e+166])=inf
# f([2.5595432e+166])=inf
# f([-3.58336048e+166])=inf
# f([5.01670467e+166])=inf
# f([-7.02338653e+166])=inf
# f([9.83274115e+166])=inf
# f([-1.37658376e+167])=inf
# f([1.92721726e+167])=inf
# ...
# f([1.03336871e+219])=inf
# f([-1.4467162e+219])=inf
# f([2.02540267e+219])=inf
# f([-2.83556374e+219])=inf
# f([3.96978924e+219])=inf
# f([-5.55770494e+219])=inf
# f([7.78078691e+219])=inf
# f([-1.08931017e+220])=inf
# f([1.52503423e+220])=inf
# f([-2.13504793e+220])=inf
# f([2.9890671e+220])=inf
# f([-4.18469394e+220])=inf
# f([5.85857152e+220])=inf
# f([-8.20200012e+220])=inf
# f([1.14828002e+221])=inf
# f([-1.60759202e+221])=inf
# f([2.25062883e+221])=inf
# f([-3.15088037e+221])=inf
# f([4.41123251e+221])=inf
# f([-6.17572552e+221])=inf
# f([8.64601573e+221])=inf
# f([-1.2104422e+222])=inf
# f([1.69461908e+222])=inf
# f([-2.37246672e+222])=inf
# f([3.3214534e+222])=inf
# f([-4.65003476e+222])=inf
# f([6.51004867e+222])=inf
# f([-9.11406813e+222])=inf
# f([1.27596954e+223])=inf
# f([-1.78635735e+223])=inf
# f([2.5009003e+223])=inf
# f([-3.50126041e+223])=inf
# f([4.90176458e+223])=inf
# f([-6.86247041e+223])=inf
# f([9.60745858e+223])=inf
# f([-1.3450442e+224])=inf
# f([1.88306188e+224])=inf
# f([-2.63628663e+224])=inf
# f([3.69080129e+224])=inf
# f([-5.1671218e+224])=inf
# f([7.23397052e+224])=inf
# f([-1.01275587e+225])=inf
# f([1.41785822e+225])=inf
# f([-1.98500151e+225])=inf
# f([2.77900212e+225])=inf
# f([-3.89060296e+225])=inf
# f([5.44684415e+225])=inf
# f([-7.62558181e+225])=inf
# f([1.06758145e+226])=inf
# f([-1.49461403e+226])=inf
# f([2.09245965e+226])=inf
# f([-2.92944351e+226])=inf
# f([4.10122091e+226])=inf
# f([-5.74170927e+226])=inf
# f([8.03839298e+226])=inf
# f([-1.12537502e+227])=inf
# f([1.57552502e+227])=inf
# f([-2.20573503e+227])=inf
# f([3.08802905e+227])=inf
# f([-4.32324067e+227])=inf
# f([6.05253693e+227])=inf
# f([-8.47355171e+227])=inf
# f([1.18629724e+228])=inf
# f([-1.66081613e+228])=inf
# f([2.32514259e+228])=inf
# f([-3.25519962e+228])=inf
# f([4.55727947e+228])=inf
# f([-6.38019126e+228])=inf
# f([8.93226777e+228])=inf
# f([-1.25051749e+229])=inf
# f([1.75072448e+229])=inf
# f([-2.45101428e+229])=inf
# f([3.43141999e+229])=inf
# f([-4.80398798e+229])=inf
# f([6.72558317e+229])=inf
# f([-9.41581644e+229])=inf
# f([1.3182143e+230])=inf
# f([-1.84550002e+230])=inf
# f([2.58370003e+230])=inf
# f([-3.61718004e+230])=inf
# f([5.06405206e+230])=inf
# f([-7.08967289e+230])=inf
# f([9.92554204e+230])=inf
# f([-1.38957589e+231])=inf
# f([1.94540624e+231])=inf
# f([-2.72356874e+231])=inf
# f([3.81299623e+231])=inf
# f([-5.33819472e+231])=inf
# f([7.47347261e+231])=inf
# f([-1.04628617e+232])=inf
# f([1.46480063e+232])=inf
# f([-2.05072088e+232])=inf
# f([2.87100924e+232])=inf
# f([-4.01941293e+232])=inf
# f([5.62717811e+232])=inf
# f([-7.87804935e+232])=inf
# f([1.10292691e+233])=inf
# f([-1.54409767e+233])=inf
# f([2.16173674e+233])=inf
# f([-3.02643144e+233])=inf
# f([4.23700401e+233])=inf
# f([-5.93180562e+233])=inf
# f([8.30452787e+233])=inf
# f([-1.1626339e+234])=inf
# f([1.62768746e+234])=inf
# f([-2.27876245e+234])=inf
# f([3.19026743e+234])=inf
# f([-4.4663744e+234])=inf
# f([6.25292415e+234])=inf
# f([-8.75409382e+234])=inf
# f([1.22557313e+235])=inf
# f([-1.71580239e+235])=inf
# f([2.40212334e+235])=inf
# f([-3.36297268e+235])=inf
# f([4.70816175e+235])=inf
# f([-6.59142645e+235])=inf
# f([9.22799703e+235])=inf
# f([-1.29191958e+236])=inf
# f([1.80868742e+236])=inf
# f([-2.53216239e+236])=inf
# f([3.54502734e+236])=inf
# f([-4.96303828e+236])=inf
# f([6.94825359e+236])=inf
# f([-9.72755502e+236])=inf
# f([1.3618577e+237])=inf
# f([-1.90660078e+237])=inf
# f([2.6692411e+237])=inf
# f([-3.73693754e+237])=inf
# f([5.23171255e+237])=inf
# f([-7.32439757e+237])=inf
# f([1.02541566e+238])=inf
# f([-1.43558192e+238])=inf
# f([2.00981469e+238])=inf
# f([-2.81374057e+238])=inf
# f([3.9392368e+238])=inf
# f([-5.51493152e+238])=inf
# f([7.72090413e+238])=inf
# f([-1.08092658e+239])=inf
# f([1.51329721e+239])=inf
# f([-2.11861609e+239])=inf
# f([2.96606253e+239])=inf
# f([-4.15248754e+239])=inf
# f([5.81348256e+239])=inf
# f([-8.13887558e+239])=inf
# f([1.13944258e+240])=inf
# f([-1.59521961e+240])=inf
# f([2.23330746e+240])=inf
# f([-3.12663044e+240])=inf
# f([4.37728262e+240])=inf
# f([-6.12819567e+240])=inf
# f([8.57947394e+240])=inf
# f([-1.20112635e+241])=inf
# f([1.68157689e+241])=inf
# f([-2.35420765e+241])=inf
# f([3.29589071e+241])=inf
# f([-4.61424699e+241])=inf
# f([6.45994579e+241])=inf
# f([-9.0439241e+241])=inf
# f([1.26614937e+242])=inf
# f([-1.77260912e+242])=inf
# f([2.48165277e+242])=inf
# f([-3.47431388e+242])=inf
# f([4.86403944e+242])=inf
# f([-6.80965521e+242])=inf
# f([9.5335173e+242])=inf
# f([-1.33469242e+243])=inf
# f([1.86856939e+243])=inf
# f([-2.61599715e+243])=inf
# f([3.662396e+243])=inf
# f([-5.12735441e+243])=inf
# f([7.17829617e+243])=inf
# f([-1.00496146e+244])=inf
# f([1.40694605e+244])=inf
# f([-1.96972447e+244])=inf
# f([2.75761426e+244])=inf
# f([-3.86065996e+244])=inf
# f([5.40492394e+244])=inf
# f([-7.56689352e+244])=inf
# f([1.05936509e+245])=inf
# f([-1.48311113e+245])=inf
# f([2.07635558e+245])=inf
# f([-2.90689781e+245])=inf
# f([4.06965694e+245])=inf
# f([-5.69751972e+245])=inf
# f([7.9765276e+245])=inf
# f([-1.11671386e+246])=inf
# f([1.56339941e+246])=inf
# f([-2.18875917e+246])=inf
# f([3.06426284e+246])=inf
# f([-4.28996798e+246])=inf
# f([6.00595517e+246])=inf
# f([-8.40833724e+246])=inf
# f([1.17716721e+247])=inf
# f([-1.6480341e+247])=inf
# f([2.30724774e+247])=inf
# f([-3.23014684e+247])=inf
# f([4.52220557e+247])=inf
# f([-6.3310878e+247])=inf
# f([8.86352292e+247])=inf
# f([-1.24089321e+248])=inf
# f([1.73725049e+248])=inf
# f([-2.43215069e+248])=inf
# f([3.40501096e+248])=inf
# f([-4.76701535e+248])=inf
# f([6.67382149e+248])=inf
# f([-9.34335008e+248])=inf
# f([1.30806901e+249])=inf
# f([-1.83129662e+249])=inf
# f([2.56381526e+249])=inf
# f([-3.58934137e+249])=inf
# f([5.02507792e+249])=inf
# f([-7.03510908e+249])=inf
# f([9.84915272e+249])=inf
# f([-1.37888138e+250])=inf
# f([1.93043393e+250])=inf
# f([-2.70260751e+250])=inf
# f([3.78365051e+250])=inf
# f([-5.29711071e+250])=inf
# f([7.41595499e+250])=inf
# f([-1.0382337e+251])=inf
# f([1.45352718e+251])=inf
# f([-2.03493805e+251])=inf
# f([2.84891327e+251])=inf
# f([-3.98847858e+251])=inf
# f([5.58387001e+251])=inf
# f([-7.81741801e+251])=inf
# f([1.09443852e+252])=inf
# f([-1.53221393e+252])=inf
# f([2.1450995e+252])=inf
# f([-3.0031393e+252])=inf
# f([4.20439503e+252])=inf
# f([-5.88615304e+252])=inf
# f([8.24061425e+252])=inf
# f([-1.153686e+253])=inf
# f([1.61516039e+253])=inf
# f([-2.26122455e+253])=inf
# f([3.16571437e+253])=inf
# f([-4.43200012e+253])=inf
# f([6.20480017e+253])=inf
# f([-8.68672023e+253])=inf
# f([1.21614083e+254])=inf
# f([-1.70259717e+254])=inf
# f([2.38363603e+254])=inf
# f([-3.33709044e+254])=inf
# f([4.67192662e+254])=inf
# f([-6.54069727e+254])=inf
# f([9.15697618e+254])=inf
# f([-1.28197667e+255])=inf
# f([1.79476733e+255])=inf
# f([-2.51267426e+255])=inf
# f([3.51774397e+255])=inf
# f([-4.92484156e+255])=inf
# f([6.89477818e+255])=inf
# f([-9.65268945e+255])=inf
# f([1.35137652e+256])=inf
# f([-1.89192713e+256])=inf
# f([2.64869799e+256])=inf
# f([-3.70817718e+256])=inf
# f([5.19144805e+256])=inf
# f([-7.26802727e+256])=inf
# f([1.01752382e+257])=inf
# f([-1.42453335e+257])=inf
# f([1.99434668e+257])=inf
# f([-2.79208536e+257])=inf
# f([3.9089195e+257])=inf
# f([-5.4724873e+257])=inf
# f([7.66148222e+257])=inf
# f([-1.07260751e+258])=inf
# f([1.50165052e+258])=inf
# f([-2.10231072e+258])=inf
# f([2.94323501e+258])=inf
# f([-4.12052901e+258])=inf
# f([5.76874062e+258])=inf
# f([-8.07623687e+258])=inf
# f([1.13067316e+259])=inf
# f([-1.58294243e+259])=inf
# f([2.2161194e+259])=inf
# f([-3.10256715e+259])=inf
# f([4.34359402e+259])=inf
# f([-6.08103162e+259])=inf
# f([8.51344427e+259])=inf
# f([-1.1918822e+260])=inf
# f([1.66863508e+260])=inf
# f([-2.33608911e+260])=inf
# f([3.27052475e+260])=inf
# f([-4.57873465e+260])=inf
# f([6.41022851e+260])=inf
# f([-8.97431992e+260])=inf
# f([1.25640479e+261])=inf
# f([-1.7589667e+261])=inf
# f([2.46255339e+261])=inf
# f([-3.44757474e+261])=inf
# f([4.82660464e+261])=inf
# f([-6.75724649e+261])=inf
# f([9.46014509e+261])=inf
# f([-1.32442031e+262])=inf
# f([1.85418844e+262])=inf
# f([-2.59586381e+262])=inf
# f([3.63420934e+262])=inf
# f([-5.08789307e+262])=inf
# f([7.1230503e+262])=inf
# f([-9.97227042e+262])=inf
# f([1.39611786e+263])=inf
# f([-1.954565e+263])=inf
# f([2.736391e+263])=inf
# f([-3.8309474e+263])=inf
# f([5.36332637e+263])=inf
# f([-7.50865691e+263])=inf
# f([1.05121197e+264])=inf
# f([-1.47169675e+264])=inf
# f([2.06037546e+264])=inf
# f([-2.88452564e+264])=inf
# f([4.03833589e+264])=inf
# f([-5.65367025e+264])=inf
# f([7.91513835e+264])=inf
# f([-1.10811937e+265])=inf
# f([1.55136712e+265])=inf
# f([-2.17191396e+265])=inf
# f([3.04067955e+265])=inf
# f([-4.25695137e+265])=inf
# f([5.95973192e+265])=inf
# f([-8.34362469e+265])=inf
# f([1.16810746e+266])=inf
# f([-1.63535044e+266])=inf
# f([2.28949061e+266])=inf
# f([-3.20528686e+266])=inf
# f([4.4874016e+266])=inf
# f([-6.28236224e+266])=inf
# f([8.79530714e+266])=inf
# f([-1.231343e+267])=inf
# f([1.7238802e+267])=inf
# f([-2.41343228e+267])=inf
# f([3.37880519e+267])=inf
# f([-4.73032727e+267])=inf
# f([6.62245818e+267])=inf
# f([-9.27144145e+267])=inf
# f([1.2980018e+268])=inf
# f([-1.81720252e+268])=inf
# f([2.54408353e+268])=inf
# f([-3.56171695e+268])=inf
# f([4.98640372e+268])=inf
# f([-6.98096521e+268])=inf
# f([9.7733513e+268])=inf
# f([-1.36826918e+269])=inf
# f([1.91557685e+269])=inf
# f([-2.6818076e+269])=inf
# f([3.75453064e+269])=inf
# f([-5.25634289e+269])=inf
# f([7.35888004e+269])=inf
# f([-1.03024321e+270])=inf
# f([1.44234049e+270])=inf
# f([-2.01927668e+270])=inf
# f([2.82698736e+270])=inf
# f([-3.9577823e+270])=inf
# f([5.54089522e+270])=inf
# f([-7.75725331e+270])=inf
# f([1.08601546e+271])=inf
# f([-1.52042165e+271])=inf
# f([2.12859031e+271])=inf
# f([-2.98002643e+271])=inf
# f([4.172037e+271])=inf
# f([-5.84085181e+271])=inf
# f([8.17719253e+271])=inf
# f([-1.14480695e+272])=inf
# f([1.60272974e+272])=inf
# f([-2.24382163e+272])=inf
# f([3.14135028e+272])=inf
# f([-4.39789039e+272])=inf
# f([6.15704655e+272])=inf
# f([-8.61986517e+272])=inf
# f([1.20678112e+273])=inf
# f([-1.68949357e+273])=inf
# f([2.365291e+273])=inf
# f([-3.3114074e+273])=inf
# f([4.63597037e+273])=inf
# f([-6.49035851e+273])=inf
# f([9.08650192e+273])=inf
# f([-1.27211027e+274])=inf
# f([1.78095438e+274])=inf
# f([-2.49333613e+274])=inf
# f([3.49067058e+274])=inf
# f([-4.88693881e+274])=inf
# f([6.84171433e+274])=inf
# f([-9.57840006e+274])=inf
# f([1.34097601e+275])=inf
# f([-1.87736641e+275])=inf
# f([2.62831298e+275])=inf
# f([-3.67963817e+275])=inf
# f([5.15149344e+275])=inf
# f([-7.21209081e+275])=inf
# f([1.00969271e+276])=inf
# f([-1.4135698e+276])=inf
# f([1.97899772e+276])=inf
# f([-2.77059681e+276])=inf
# f([3.87883553e+276])=inf
# f([-5.43036974e+276])=inf
# f([7.60251763e+276])=inf
# f([-1.06435247e+277])=inf
# f([1.49009346e+277])=inf
# f([-2.08613084e+277])=inf
# f([2.92058317e+277])=inf
# f([-4.08881644e+277])=inf
# f([5.72434302e+277])=inf
# f([-8.01408023e+277])=inf
# f([1.12197123e+278])=inf
# f([-1.57075973e+278])=inf
# f([2.19906362e+278])=inf
# f([-3.07868906e+278])=inf
# f([4.31016469e+278])=inf
# f([-6.03423056e+278])=inf
# f([8.44792278e+278])=inf
# f([-1.18270919e+279])=inf
# f([1.65579287e+279])=inf
# f([-2.31811001e+279])=inf
# f([3.24535402e+279])=inf
# f([-4.54349562e+279])=inf
# f([6.36089387e+279])=inf
# f([-8.90525142e+279])=inf
# f([1.2467352e+280])=inf
# f([-1.74542928e+280])=inf
# f([2.44360099e+280])=inf
# f([-3.42104139e+280])=inf
# f([4.78945794e+280])=inf
# f([-6.70524112e+280])=inf
# f([9.38733756e+280])=inf
# f([-1.31422726e+281])=inf
# f([1.83991816e+281])=inf
# f([-2.57588543e+281])=inf
# f([3.6062396e+281])=inf
# f([-5.04873544e+281])=inf
# f([7.06822961e+281])=inf
# f([-9.89552146e+281])=inf
# f([1.385373e+282])=inf
# f([-1.93952221e+282])=inf
# f([2.71533109e+282])=inf
# f([-3.80146352e+282])=inf
# f([5.32204893e+282])=inf
# f([-7.45086851e+282])=inf
# f([1.04312159e+283])=inf
# f([-1.46037023e+283])=inf
# f([2.04451832e+283])=inf
# f([-2.86232565e+283])=inf
# f([4.0072559e+283])=inf
# f([-5.61015827e+283])=inf
# f([7.85422157e+283])=inf
# f([-1.09959102e+284])=inf
# f([1.53942743e+284])=inf
# f([-2.1551984e+284])=inf
# f([3.01727776e+284])=inf
# f([-4.22418886e+284])=inf
# f([5.91386441e+284])=inf
# f([-8.27941017e+284])=inf
# f([1.15911742e+285])=inf
# f([-1.62276439e+285])=inf
# f([2.27187015e+285])=inf
# f([-3.18061821e+285])=inf
# f([4.4528655e+285])=inf
# f([-6.23401169e+285])=inf
# f([8.72761637e+285])=inf
# f([-1.22186629e+286])=inf
# f([1.71061281e+286])=inf
# f([-2.39485793e+286])=inf
# f([3.35280111e+286])=inf
# f([-4.69392155e+286])=inf
# f([6.57149017e+286])=inf
# f([-9.20008623e+286])=inf
# f([1.28801207e+287])=inf
# f([-1.8032169e+287])=inf
# f([2.52450366e+287])=inf
# f([-3.53430513e+287])=inf
# f([4.94802718e+287])=inf
# f([-6.92723805e+287])=inf
# f([9.69813327e+287])=inf
# f([-1.35773866e+288])=inf
# f([1.90083412e+288])=inf
# f([-2.66116777e+288])=inf
# f([3.72563488e+288])=inf
# f([-5.21588883e+288])=inf
# f([7.30224436e+288])=inf
# f([-1.02231421e+289])=inf
# f([1.43123989e+289])=inf
# f([-2.00373585e+289])=inf
# f([2.80523019e+289])=inf
# f([-3.92732227e+289])=inf
# f([5.49825118e+289])=inf
# f([-7.69755165e+289])=inf
# f([1.07765723e+290])=inf
# f([-1.50872012e+290])=inf
# f([2.11220817e+290])=inf
# f([-2.95709144e+290])=inf
# f([4.13992802e+290])=inf
# f([-5.79589922e+290])=inf
# f([8.11425891e+290])=inf
# f([-1.13599625e+291])=inf
# f([1.59039475e+291])=inf
# f([-2.22655265e+291])=inf
# f([3.1171737e+291])=inf
# f([-4.36404319e+291])=inf
# f([6.10966046e+291])=inf
# f([-8.55352465e+291])=inf
# f([1.19749345e+292])=inf
# f([-1.67649083e+292])=inf
# f([2.34708716e+292])=inf
# f([-3.28592203e+292])=inf
# f([4.60029084e+292])=inf
# f([-6.44040717e+292])=inf
# f([9.01657004e+292])=inf
# f([-1.26231981e+293])=inf
# f([1.76724773e+293])=inf
# f([-2.47414682e+293])=inf
# f([3.46380555e+293])=inf
# f([-4.84932777e+293])=inf
# f([6.78905887e+293])=inf
# f([-9.50468242e+293])=inf
# f([1.33065554e+294])=inf
# f([-1.86291776e+294])=inf
# f([2.60808486e+294])=inf
# f([-3.6513188e+294])=inf
# f([5.11184632e+294])=inf
# f([-7.15658485e+294])=inf
# f([1.00192188e+295])=inf
# f([-1.40269063e+295])=inf
# f([1.96376688e+295])=inf
# f([-2.74927364e+295])=inf
# f([3.84898309e+295])=inf
# f([-5.38857633e+295])=inf
# f([7.54400686e+295])=inf
# f([-1.05616096e+296])=inf
# f([1.47862534e+296])=inf
# f([-2.07007548e+296])=inf
# f([2.89810567e+296])=inf
# f([-4.05734794e+296])=inf
# f([5.68028712e+296])=inf
# f([-7.95240197e+296])=inf
# f([1.11333628e+297])=inf
# f([-1.55867079e+297])=inf
# f([2.1821391e+297])=inf
# f([-3.05499474e+297])=inf
# f([4.27699264e+297])=inf
# f([-5.98778969e+297])=inf
# f([8.38290557e+297])=inf
# f([-1.17360678e+298])=inf
# f([1.64304949e+298])=inf
# f([-2.30026929e+298])=inf
# f([3.220377e+298])=inf
# f([-4.5085278e+298])=inf
# f([6.31193892e+298])=inf
# f([-8.83671449e+298])=inf
# f([1.23714003e+299])=inf
# f([-1.73199604e+299])=inf
# f([2.42479446e+299])=inf
# f([-3.39471224e+299])=inf
# f([4.75259714e+299])=inf
# f([-6.65363599e+299])=inf
# f([9.31509039e+299])=inf
# f([-1.30411265e+300])=inf
# f([1.82575772e+300])=inf
# f([-2.5560608e+300])=inf
# f([3.57848512e+300])=inf
# f([-5.00987917e+300])=inf
# f([7.01383084e+300])=inf
# f([-9.81936318e+300])=inf
# f([1.37471084e+301])=inf
# f([-1.92459518e+301])=inf
# f([2.69443326e+301])=inf
# f([-3.77220656e+301])=inf
# f([5.28108918e+301])=inf
# f([-7.39352485e+301])=inf
# f([1.03509348e+302])=inf
# f([-1.44913087e+302])=inf
# f([2.02878322e+302])=inf
# f([-2.84029651e+302])=inf
# f([3.97641511e+302])=inf
# f([-5.56698116e+302])=inf
# f([7.79377362e+302])=inf
# f([-1.09112831e+303])=inf
# f([1.52757963e+303])=inf
# f([-2.13861148e+303])=inf
# f([2.99405607e+303])=inf
# f([-4.1916785e+303])=inf
# f([5.8683499e+303])=inf
# f([-8.21568987e+303])=inf
# f([1.15019658e+304])=inf
# f([-1.61027521e+304])=inf
# f([2.2543853e+304])=inf
# f([-3.15613942e+304])=inf
# f([4.41859519e+304])=inf
# f([-6.18603326e+304])=inf
# f([8.66044656e+304])=inf
# f([-1.21246252e+305])=inf
# f([1.69744753e+305])=inf
# f([-2.37642654e+305])=inf
# f([3.32699715e+305])=inf
# f([-4.65779601e+305])=inf
# f([6.52091442e+305])=inf
# f([-9.12928019e+305])=inf
# f([1.27809923e+306])=inf
# f([-1.78933892e+306])=inf
# f([2.50507448e+306])=inf
# f([-3.50710428e+306])=inf
# f([4.90994599e+306])=inf
# f([-6.87392438e+306])=inf
# f([9.62349413e+306])=inf
# f([-1.34728918e+307])=inf
# f([1.88620485e+307])=inf
# f([-2.64068679e+307])=inf
# f([3.69696151e+307])=inf
# f([-5.17574611e+307])=inf
# f([7.24604455e+307])=inf
# f([-1.01444624e+308])=inf
# f([inf])=inf
# f([nan])=nan
# <ipython-input-36-d122fdaf9ffc>:6: RuntimeWarning: overflow encountered in double_scalars
#   while (diff(*p)**2).sum() >= epsilon**2 and k<10000:
# <ipython-input-78-baab2d70a791>:1: RuntimeWarning: overflow encountered in double_scalars
#   f = lambda x : x**2
# <ipython-input-78-baab2d70a791>:2: RuntimeWarning: overflow encountered in double_scalars
#   diff = lambda x: 2*x
# <ipython-input-36-d122fdaf9ffc>:7: RuntimeWarning: invalid value encountered in subtract
#   p = p - alpha*diff(*p)

# %%
X = np.linspace(-100,100,200)
plt.plot()
Z = points[0:10]
plt.plot(X,X**2, 'r')
plt.scatter(Z,Z**2)
plt.show()

# %% [markdown]
# **Problème du réglage du pas de gradient $\alpha$** :
#   * si $\alpha$ est trop grand l'algorithme ne converge pas
#   * si $\alpha$ est trop petit l'algorithme converge mais trop lentement
#  Il existe donc une façon optimale de régler $\alpha$ entre ces deux extremes qu'il faut trouver.
#  Il y a aussi des méthodes consistant à diminuer $\alpha$ au fur et à mesure.

# %% [markdown]
# ## Exercices

# %% [markdown]
# ### ex
# Retrouvez la dérivée de la fonction $f(x) = x^2 + 5x$ sur $\R$ en étudiant $f(x+h)-f(x)$.

# %% [markdown]
# ### ex
# Retrouvez la dérivée de la fonction $f(x) = \frac{1}{x}$ sur $\R^+$ en étudiant $f(x+h)-f(x)$.

# %% [markdown]
# ### ex
# Pour les trois normes définies dans le cours, dessinez la boule unité fermée dans $\R^2$ et remarquez les inclusions (la boule unité est l'ensemble des $x$ tels que $\|x\| \leq 1$).

# %% [markdown]
# ### ex
# Montrez que pour tout $x \in \R^2$ on a
# $$ \|x\|_\infty \leq \|x\|_2 \leq \|x\|_1 \leq 2 \|x\|_\infty $$
# Retrouvez les inclusions de l'exercice précédent.
# Plus généralement pour $x \in \R^n$ montrer
# $$ \|x\|_\infty \leq \|x\|_2 \leq \|x\|_1 \leq n \|x\|_\infty $$

# %% [markdown]
# ### ex
# Cacluler le minimum de la fonction définie sur $\R^2$ par
# $$f(x_1,x_2) = 3x_1^2 + 12 x_2^2  -4x_1 x_2  - 2x_1 - 4x_2 + 1 $$
# On admettra que ce minimum existe.

# %% [markdown]
# ## ex
# Retrouvez numérique la valeur précédente en effectuant une descente de gradient. Faites une représentation 2D de la fonction pour vérifier.
