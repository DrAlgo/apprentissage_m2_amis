# %% [markdown]
# macros latex
# $$
# \def\R{{\mathbb R}}
# $$

# %% [markdown]
# # Notions de Calcul différentiel

# %% [markdown]
# ## Notion de dérivabilité en dimension 1
# **Rappel** : une fonction d'un intervalle ouvert $I \subset \R$ dans $\mathbb R$ est dite *dérivable* ou *différentiable* en $x \in I$ si la quantité
# $$\lim_{h \rightarrow 0, h \neq 0} \frac{f(x+h)-f(x)}{h}$$
# a une limite, qui est alors notée $f'(x)$.

# %% [markdown]
# Si on pose alors
# $$\epsilon(h) = \frac{f(x+h)-f(x)}{h} -f'(x)$$ la fonction $\epsilon$
# vérifie alors
# $$\lim_{h \to 0, h \neq 0} \epsilon(h) = 0.$$

# %% [markdown]
# On peut reformuler la notion de dérivabilité comme le fait que $f$ puisse s'écrire (pour $h$ assez petit) sous la forme
# $$f(x+h) = f(x) + h \cdot f'(x) + h \cdot\epsilon(h)$$
#
# avec $\epsilon$ une fonction qui tend vers $0$ en $0$.

# %% [markdown]
# La partie
# $$h \mapsto f(h) + h \cdot f'(x)$$
#
# est une approximation linéaire de $h \mapsto f(x+h)$ au voisinage de $0$ et la partie
#
# $$h \cdot \epsilon(h) = o(h)$$
#
# est une fonction **négligeable devant** $h$.

# %% [markdown]
# **exemple** Si $f(x) = x^3$ alors
# $$f(x+h) = (x+h)^3 = x^3 + 3x^2 h + 3x h^2 + h^3$$
# $$ = \boxed{f(x) + 3x^2 \cdot h} + h\cdot (3xh+h^2)$$
# L'application $h \mapsto 3x^2 \cdot h$ est linéaire, et $h \mapsto h(3xh+h^2)$ est négligeable devant $h$ (de la forme $h \times \epsilon(h)$ avec $\lim_{h \rightarrow 0} \epsilon(h) = 0$ ).
# On retrouve donc la formule $(x^3)' = 3x^2$.

# %% [markdown]
# Représentation graphique des fonctions
# $$h \mapsto f(2+h) = (2+h)^3$$
# et
# $$h \mapsto f(2) + h f'(2) = 8+12h$$

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 12))
h = np.linspace(-3,2,100)
plt.plot(h, (2+h)**3, color='red', label= "f(2+h)")
plt.plot(h, 8 + 12*h, color = 'green', label= "f(2) + h f'(2)")
plt.grid()
plt.axhline()
plt.axvline()
plt.legend(fontsize=20)
plt.close()

# %%
fig

# %% [markdown]
# ## L'espace ${\mathbb R}^n$
# ${\mathbb R}^n$ est l'espace vectoriel des $n$-uplets de réels de la forme
# $$x = (x_1, x_2, \dots, x_n)$$
# On peut identifier dans la base canonique ce vecteur à une matrice (vecteur colonne) de dimension $n \times 1$.
# $${\bf x} = \begin{pmatrix}
# x_1 \\
# x_2 \\
# \dots \\
# x_n
# \end{pmatrix}$$

# %% [markdown]
# On peut mesurer les distances en utilisant des **normes**. La norme d'un vecteur mesure sa "longueur" qui peut aussi être vue comme sa distance à $\bf 0$.
#
# Norme 2 (euclidienne) : $\|x\|_2 = \sqrt{\sum_{i=1}^n x_i^2}$
# Norme 1 : $\|x\|_1 = \sum_{i=1}^n | x_i | $
# Norme infinie : $\|x\|_\infty = \max_{1 \leq i \leq n} \| x_i \| $

# %% [markdown]
# On peut alors mesurer des distances entre vecteurs par
# $$d(x,y) = \|x-y\|$$
#
# Pour les propriétés topologiques (continuité, limites) on peut utiliser de façon *équivalente* n'importe laquelle de ces normes.

# %% [markdown]
# Une application linéaire de $\R^n$ dans $\R^m$ est une application
# $$ f :  \R^n \rightarrow \R^m$$
# qui vérifie
# $$\forall x,y \in \R^n, f(x+y) = f(x) + f(y)$$
# $$\forall \lambda \in \R, \forall x \in \R^n, f(\lambda x) = \lambda f(x)$$

# %% [markdown]
# **exemple :** $f$ de $\R^3$ dans $\R^2$ définie par
#
# $$f(x_1,x_2,x_3) = (2x_1+x_2-x_3, x_1+3x_3)$$
# est linéaire.

# %% [markdown]
# Une telle application peut s'écrire sous la forme
# $$f(x_1, x_2, \dots, x_n) = ( \sum_{j=1}^n a_{1,j} x_j, \sum_{i=j}^n a_{2,i} x_j, \dots, \sum_{i=1}^n a_{m,j} x_j )$$

# %% [markdown]
# On peut représenter $f$ par une matrice à $m$ lignes et $n$ colonnes
# $$ A = (a_{i,j})_{1\leq i \leq m, 1 \leq j \leq m} $$
# Les espaces $\R^n$ et $\R^m$ sont identifiés à l'ensemble des  vecteurs colonnes $n \times 1$ et $m \times 1$
# et l'application linéaire correspond au produit matriciel
# $$ Y = A X $$
# $$ (m,1) \sim (m,n) \cdot (n,1)$$

# %% [markdown]
# **cas particulier** Les applications linéaires sur $\R^n$ à valeur dans $\R$ (formes linéaires) sont représentées par des matrices de dimensions $(1,n)$ donc des matrices ligne.
#
# On peut représenter une telle ligne comme la transposée d'un vecteur colonne donc une forme linéaire
# peut s'écrire sous la forme
#
# $$f({\bf x}) = {\bf a}^T \bf x$$
#
# où $\bf a$ est un vecteur colonne de dimension $n$. Le produit
# $${\bf a}^T {\bf x} = \sum_{j=1}^n a_i x_i$$
# est aussi le produit scalaire (euclidien) des vecteurs.

# %% [markdown]
# **exemple :** $f$ de $\R^3$ dans $\R$
#
# $$ f(x_1,x_2,x_3) = 3x_1-x_2-2x_3 $$
# est représentée par le vecteur
# $${\bf a} = \begin{pmatrix}
# 3 \\
# -1 \\
# -2
# \end{pmatrix}$$

# %% [markdown]
# ## Différentielle en dimension $n$
# Soit maintenant $f$ une fonction de ${\mathbb R}^n$ dans ${\mathbb R}$. La différentielle $\ell$ de $f$ en un point $x$ est une approximation linéaire de $f$ et $x$, elle doit donc réaliser
# $$f(x+h) = f(x) + \ell(h) + o(h)$$
# Ici $h \mapsto \ell(h)$ doit être une *application linéaire* (forme linéaire en fait) de ${\mathbb R}^n$ dans ${\mathbb R}$
# et $o(h)$ est une fonction qui est négligeable devant $h$.

# %% [markdown]
# Rappel : une application linéaire de  ${\mathbb R}^n$ dans ${\mathbb R}$ peut s'écrire dans une base
# sous la forme
# $$\ell(h) = \sum_{i=1}^n a_i h_i$$
# On peut représenter ce calcul aussi comme le produit matriciel ${\bf a}^T \cdot \bf h$ où $\bf a$ et $\bf h$ sont les vecteurs colonnes correspondant à $a$ et $h$.

# %% [markdown]
# **exemple :** Soit $f(x_1,x_2) = (x_1+3x_2)^2$. On considère sa différentielle au point $x =(x_1,x_2)$.
#
# On a $$f(x_1 + h_1, x_2 + h_2) = (x_1 + h_1 +3 x_2 + 3 h_2)^2$$
# $$ = (x_1 + 3x_2)^2 + 2(x_1+3x_2)(h_1+3h_2) + (h_1+3h_2)^2$$

# %% [markdown]
# On peut facilement montrer que $h = (h_1,h_2) \mapsto (h_1+3h_2)^2$ est un $o(h)$ (négligeable) car
# $$| (h_1+3h_2)^2 | = (h_1+3h_2)  (h_1+3h_2) \leq 3 (|h_1| + |h_2|) (h_1 + 3h_2)$$
# donc est de la forme $\|h\|_1 \epsilon(h)$.

# %% [markdown]
# On peut donc écrire que
# $$f(x+h) = f(x) +  2(x_1+3x_2)h_1 + 6(x_1+3x_2) h_2 + o(h)$$
# La différentielle de $f$ en $x=(x_1,x_2)$ est l'application linéaire à valeurs dans $\R$
# $$h = (h_1,h_2) \mapsto 2(x_1+3x_2)h_1 + 6(x_1+3x_2) h_2 $$
# et peut être représentée par le vecteur
# $${\bf a} = \begin{pmatrix}
# 2 x_1+ 6 x_2 \\
# 6 x_1 + 18x_2
# \end{pmatrix}$$

# %% [markdown]
# Rappel : $f(x_1,x_2) = (x_1+3x_2)^2$
#
# On a $$\frac{\partial f}{\partial x_1}(x) = 2(x_1 + 3 x_2) = 2x_1 + 6 x_2$$
# et
# $$\frac{\partial f}{\partial x_2}(x) = 3 \times 2(x_1 + 3 x_2) = 6 x_1 + 18 x_2$$
# On retrouve les coordonnées du vecteur de la différentielle.

# %% [markdown]
# Le vecteur $a$ représentant la différentielle de $f$ est appelé le **gradient de f en x** et est noté $grad(f)(x)$ ou  $\nabla f (x)$ et ses coordonnées sont
# $$\nabla f (x) = (\frac{\partial f}{\partial x_1}(x), \frac{\partial f}{\partial x_2}(x), \dots, \frac{\partial f}{\partial x_n}(x))^T$$
# où $\frac{\partial f}{\partial x_i}(x)$ est la dérivée partielle de $f$ par rapport à $x_i$.

# %% [markdown]
# L'ensemble des vecteurs $h$ tels que $\langle \nabla f (x), h\rangle > 0$ forme un demi-espace et  ces vecteurs sont appelés directions de montée ; à l'inverse les vecteurs $h$ tels que $\langle \nabla f (x), h\rangle < 0$ sont les directions de descente.
# Si h est une direction de descente alors
# $$ f(x+h) = f(x) + \langle \nabla f (x), h\rangle + o(||h||) < f(x) $$
# si $h$ est assez petit ($||h|| < \epsilon$ pour un $\epsilon > 0$).

# %% [markdown]
# <img src="images/gradient.png" width=400 alt="schéma gradient" align="left"/>

# %% [markdown]
# ** exemple ** Toujours avec  $f(x_1,x_2) = (x_1+3x_2)^2$ et
# $${\bf \nabla f(x)} = \begin{pmatrix}
# 2 x_1+ 6 x_2 \\
# 6 x_1 + 18x_2
# \end{pmatrix}$$
#
# En $x_0 = (2,1)$ on a $\nabla f(x) = (10, 30)^T$. Toutes les directions $h=(h_1,h_2)$ vérifiant
# $$\langle \nabla f(x), h \rangle = 10 h_1 + 30 h_2 > 0$$
# sont des directions de montée et donc vérifient $f(x_0+h) > f(x_0)$ pour $h$ assez petit,
# et les directions vérifiant  $10 h_1 + 30 h_2 < 0$ sont des directions de descente.

# %% [markdown]
# ## gradient et extremums
# **Propriété** : Si $f$ admet un gradient en $x$ et que $x$ est un minimum ou un maximum local de $f$, alors
# $$\nabla f(x) = 0$$
# Attention, la réciproque est fausse. Considérer $f(x)=x^3$ en $x=0$.
#
# Trouver les $x$ qui annulent le gradient permet trouver les candidats potentiels à être un minimum ou maximum.

# %% [markdown]
# *preuve* (cas du minimum) Si $\nabla f (x) \neq 0$ alors si $t$ est suffisament petit on a
# (en postant $h = - t \nabla f(x)$)
# $$f(x - t \nabla f(x) )  = f(x)  -  \langle \nabla f(x), t \nabla f(x) \rangle + o(t)$$
# soit
# $$f(x - t \nabla f(x) )  = f(x)  -  t ||\nabla f(x)||^2 + o(t)$$
# qui est $ < f(x)$ pour $t$ assez petit, contredisant le fait que $f$ est un minimum local.

# %% [markdown]
# <img src="images/convex2d.png" width=800>
# Une fonction convexe sur $\R^2$

# %% [markdown]
# **exemple**  $f(x_1,x_2) = 2 x_1^2 -4 x_1 + 2x_1 x_2 + x_2^2$ fonction continue qui tend vers $+\infty$ quand $x,y$ tend vers l'infini donc admet (au moins) un minimum. On peut le trouver car
#
# $$\nabla f(x_1,x_2) = (4x_1-4 +2x_2, 2x_1 + 2x_2)^T = \bf 0$$
#
# seulement si $x = (2,-2) $
#
# Comme $f$ doit avoir un minimum c'est forcément $(2,-2)$.

# %% [markdown]
# # Descente de gradient
#
# Bien souvent (en grande dimension) il n'est pas possible de résoudre le système d'équations $\nabla f(x)=\bf 0$.
# On utilise alors une méthode *itérative*.
# La *descente de gradient* est un algorithme pour calculer un minimum d'une fonction.
# L'algorithme produit une suite de points (vecteurs) $p_0, p_1, p_2, \dots$ et va s'arrêter quand le gradient de $f$
# est suffisament petit ( $\| \nabla f\| <  \epsilon$ )

# %% [markdown]
# * paramètres : choisir $\epsilon >0$ la tolérance, et $\alpha > 0$ le pas de gradient
# * Initialisation : choisir $p_0$, poser $k =0$
# * Tant que $\| \nabla f(p_k)\| \geq \epsilon$ répéter :
#     * $\displaystyle p_{k+1} = p_k - \alpha \nabla f(p_k)$
#     * $k \leftarrow k+1$

# %% [markdown]
# Dans le cas général il n'y a pas de garantie de trouver un minimum par cette manière. Cependant si $f$ est convexe (forme en bol comme $x^2$ ) alors la méthode convergera vers l'unique minimum de $f$. Il peut être nécessaire pour cela de faire diminuer le pas lorsqu'on approche du minimum.

# %% [markdown]
# Exemple. On considère la fonction sur ${\mathbb R}^3$
# $$f(x_1,x_2,x_3) = 7x_1^2 - 6 x_1 x_2 + 5 x_2^2 - 12x_1 x_3 + 8 x_2 x_3 + 6 x_3^2 - 36x_1 + 44x_2 + 40x_3 + 100$$

# %%
f = lambda x1,x2,x3 : 7*x1**2 - 6*x1*x2 + 5*x2**2 - 12*x1*x3 + 8*x2*x3 + 6*x3**2 - 36*x1 + 44*x2 + 40*x3 + 100
diff = lambda x1,x2,x3 : np.array((14*x1 - 6*x2 - 12*x3 - 36, -6*x1 + 10*x2 + 8*x3 + 44, -12*x1 + 8*x2 + 12*x3 + 40))

# %%
import numpy as np
def descente_gradient(f, diff, epsilon, alpha, p0):
    p = p0
    k = 0
    while sum(diff(*p)**2) >= epsilon**2 and k<10000:
        p = p - alpha*diff(*p)
        print( "f(" +str(p)+ ")=" + str(f(*p)))
        k +=1

# %%
descente_gradient(f, diff, 0.01, 0.05, np.array((20.0,20.0,20.0)))
# Out:
# f([25.8  5.8 10. ])=1724.239999999999
# f([17.28  4.44 15.16])=781.9568000000002
# f([17.412 -0.86  12.656])=386.9336000000002
# f([14.3592 -2.4688 13.8536])=205.86669632000047
# f([13.67928 -4.66808 13.14448])=117.9831886976001
# f([12.390048 -5.688048 13.332592])=73.76065523993589
# f([11.8101552 -6.6600464 13.0422848])=50.89279370511872
# f([11.17040352 -7.20389056 12.9670256 ])=38.71844915774068
# f([10.77016925 -7.63763446 12.77060858])=31.97049888435629
# f([10.40212558 -7.89600989 12.62539876])=28.001264629920627
# f([10.12707397 -8.07752678 12.44983881])=25.467967783914673
# f([ 9.88476744 -8.18057672 12.28719061])=23.686394879567956
# f([ 9.68357158 -8.23973437 12.1179674 ])=22.3068614829092
# f([ 9.5039316  -8.26198267 11.95322366])=21.15016017805158
# f([ 9.34451888 -8.26110132 11.78844149])=20.12410347615321
# f([ 9.19809016 -8.24257159 11.62652845])=19.180967211811833
# f([ 9.06257264 -8.21247013 11.46649412])=18.295764951102797
# f([ 8.93492722 -8.17406092 11.30912928])=17.45515037061648
# f([ 8.81373746 -8.13020401 11.15423241])=16.651746610476607
# f([ 8.69759949 -8.08267373 11.00201704])=15.881247951855357
# f([ 8.58568795 -8.03286384 10.852436  ])=15.14093800503872
# f([ 8.47730884 -7.98169993 10.70553271])=14.428931740936036
# f([ 8.3720023  -7.9298704  10.56127836])=13.743787439664402
# f([ 8.26940658 -7.87784585 10.41966088])=13.084307700232898
# f([ 8.16926475 -7.8259653  10.28064664])=12.449437090529557
# f([ 8.07137782 -7.77446189 10.14420363])=11.838209207644923
# f([ 7.97559696 -7.72349905 10.0102929 ])=11.249719011893603
# f([ 7.88180511 -7.6731876   9.87887495])=10.68310809917375
# f([ 7.78991023 -7.62360225  9.74990809])=10.13755660709478
# f([ 7.69983725 -7.57479129  9.62335027])=9.612278532245568
# f([ 7.61152395 -7.52678458  9.49915897])=9.106518810960154
# f([ 7.52491719 -7.47959869  9.37729179])=8.61955132083358
# f([ 7.43997062 -7.4332409   9.25770651])=8.150677371593929
# f([ 7.35664282 -7.38771187  9.14036134])=7.699224464175984
# f([ 7.27489609 -7.34300762  9.02521497])=7.264545204301896
# f([ 7.19469552 -7.29912097  8.91222669])=6.84601631183159
# f([ 7.11600838 -7.25604251  8.80135638])=6.443037695222472
# f([ 7.03880359 -7.21376129  8.69256458])=6.055031574850773
# f([ 6.96305144 -7.1722654   8.5858125 ])=5.681441646295184
# f([ 6.88872331 -7.13154227  8.48106203])=5.321732278487559
# f([ 6.81579153 -7.09157895  8.37827571])=4.9753877435860545
# f([ 6.7442292  -7.0523623   8.27741678])=4.641911476449877
# f([ 6.67401014 -7.0138791   8.17844915])=4.320825362130563
# f([ 6.6051088  -6.97611617  8.08133738])=4.011669050094099
# f([ 6.53750022 -6.9390604   7.9860467 ])=3.7139992940569755
# f([ 6.47115997 -6.90269881  7.89254297])=3.427389316412757
# f([ 6.40606413 -6.86701861  7.8007927 ])=3.151428196312736
# f([ 6.34218927 -6.83200714  7.710763  ])=2.8857202804957183
# f([ 6.27951244 -6.79765199  7.62242162])=2.629884616019467
# f([ 6.21801111 -6.76394091  7.53573691])=2.3835544040718446
# f([ 6.1576632  -6.73086189  7.45067779])=2.1463764740794886
# f([ 6.09844707 -6.6984031   7.36721379])=1.9180107773543114
# f([ 6.04034147 -6.66655295  7.285315  ])=1.6981298995570455
# f([ 5.98332556 -6.63530003  7.20495206])=1.4864185912726384
# f([ 5.92737889 -6.60463317  7.12609617])=1.282573316028163
# f([ 5.87248142 -6.57454139  7.04871907])=1.0863018151047754
# f([ 5.81861345 -6.5450139   6.97279303])=0.897322688516681
# f([ 5.76575569 -6.51604013  6.89829084])=0.7153649915613869
# f([ 5.71388917 -6.48760969  6.8251858 ])=0.5401678463578605
# f([ 5.66299532 -6.45971241  6.7534517 ])=0.37148006781916365
# f([ 5.61305589 -6.43233829  6.68306284])=0.2090598035202902
# f([ 5.56405299 -6.40547751  6.61399399])=0.0526741869482521
# f([ 5.51596904 -6.37912046  6.54622039])=-0.09790099636484229
# f([ 5.46878681 -6.35325768  6.47971776])=-0.24288163030536225
# f([ 5.4224894  -6.3278799   6.41446226])=-0.38247557769642526
# f([ 5.37706021 -6.30297803  6.3504305 ])=-0.5168829783166018
# f([ 5.33248295 -6.27854316  6.28759954])=-0.6462965358460622
# f([ 5.28874166 -6.25456651  6.22594685])=-0.7709017941517686
# f([ 5.24582066 -6.23103949  6.16545034])=-0.8908774033055806
# f([ 5.20370455 -6.20795369  6.10608833])=-1.0063953757219792
# f([ 5.16237826 -6.18530081  6.04783954])=-1.117621332775002
# f([ 5.12182696 -6.16307274  5.99068309])=-1.224714742255884
# f([ 5.08203612 -6.14126152  5.93459851])=-1.3278291470055024
# f([ 5.04299148 -6.11985933  5.87956568])=-1.4271123850534195
# f([ 5.00467906 -6.09885849  5.82556489])=-1.5227068015776695
# f([ 4.96708511 -6.07825149  5.77257679])=-1.6147494529891446
# f([ 4.93019616 -6.05803093  5.72058237])=-1.7033723034319905
# f([ 4.89399899 -6.03818957  5.66956302])=-1.7887024139863001
# f([ 4.85848064 -6.01872029  5.61950043])=-1.8708621248375437
# f([ 4.82362836 -5.99961613  5.57037667])=-1.949969230679983
# f([ 4.78942967 -5.98087022  5.52217414])=-2.0261371496017375
# f([ 4.75587232 -5.96247586  5.47487555])=-2.099475085696099
# f([ 4.72294426 -5.94442646  5.42846395])=-2.170088185629993
# f([ 4.69063371 -5.92671553  5.38292272])=-2.2380776893959364
# f([ 4.65892909 -5.90933674  5.33823553])=-2.3035410754626753
# f([ 4.62781902 -5.89228386  5.29438636])=-2.36657220053263
# f([ 4.59729237 -5.87555077  5.2513595 ])=-2.4272614341071517
# f([ 4.56733818 -5.85913147  5.20913953])=-2.4856957880519133
# f([ 4.53794573 -5.84302009  5.16771131])=-2.5419590413479227
# f([ 4.50910448 -5.82721085  5.12706   ])=-2.5961318602076062
# f([ 4.48080409 -5.81169808  5.08717102])=-2.6482919137292242
# f([ 4.45303442 -5.79647622  5.04803009])=-2.6985139852520774
# f([ 4.42578551 -5.78153983  5.00962318])=-2.7468700795765812
# f([ 4.39904761 -5.76688353  4.97193651])=-2.793429526198395
# f([ 4.37281113 -5.75250208  4.93495658])=-2.8382590787092
# f([ 4.34706666 -5.73839034  4.89867015])=-2.8814230105024308
# f([ 4.32180499 -5.72454323  4.86306419])=-2.922983206924357
# f([ 4.29701704 -5.71095579  4.82812596])=-2.9629992540002945
# f([ 4.27269395 -5.69762317  4.79384293])=-3.0015285238654883
# f([ 4.24882699 -5.68454057  4.76020281])=-3.03862625702061
# f([ 4.22540761 -5.67170331  4.72719354])=-3.074345641531636
# f([ 4.20242742 -5.65910679  4.69480331])=-3.1087378892874256
# f([ 4.17987817 -5.64674649  4.66302049])=-3.1418523094233706
# f([ 4.1577518  -5.63461799  4.6318337 ])=-3.1737363790173276
# f([ 4.13604036 -5.62271693  4.60123175])=-3.204435811158902
# f([ 4.11473608 -5.61103906  4.57120369])=-3.2339946204897956
# f([ 4.09383132 -5.59958018  4.54173875])=-3.2624551863083298
# f([ 4.07331859 -5.58833619  4.51282637])=-3.289858313330285
# f([ 4.05319054 -5.57730307  4.48445618])=-3.3162432901914087
# f([ 4.03343995 -5.56647684  4.45661802])=-3.341647945777254
# f([ 4.01405974 -5.55585365  4.42930191])=-3.366108703458792
# f([ 3.99504298 -5.54542967  4.40249807])=-3.3896606333140653
# f([ 3.97638284 -5.53520117  4.37619688])=-3.412337502409059
# f([ 3.95807263 -5.52516449  4.35038892])=-3.4341718232103347
# f([ 3.9401058  -5.51531602  4.32506494])=-3.4551949001994444
# f([ 3.9224759  -5.50565225  4.30021586])=-3.4754368747545357
# f([ 3.90517661 -5.4961697   4.27583278])=-3.494926768365417
# f([ 3.88820174 -5.48686498  4.25190696])=-3.5136925242420602
# f([ 3.8715452  -5.47773475  4.22842982])=-3.53176104737787
# f([ 3.85520103 -5.46877574  4.20539295])=-3.549158243123941
# f([ 3.83916336 -5.45998474  4.1827881 ])=-3.565909054330433
# f([ 3.82342644 -5.4513586   4.16060715])=-3.582037497107649
# f([ 3.80798464 -5.44289423  4.13884217])=-3.597566695258706
# f([ 3.79283242 -5.43458859  4.11748534])=-3.612518913433064
# f([ 3.77796436 -5.4264387   4.09652903])=-3.626915589047428
# f([ 3.76337511 -5.41844166  4.07596571])=-3.640777363021641
# f([ 3.74905946 -5.41059458  4.05578801])=-3.654124109371793
# f([ 3.73501227 -5.40289465  4.03598871])=-3.6669749637046607
# f([ 3.72122851 -5.39533913  4.01656071])=-3.6793483506523046
# f([ 3.70770324 -5.3879253   3.99749704])=-3.691262010288625
# f([ 3.69443161 -5.38065049  3.97879088])=-3.7027330235633826
# f([ 3.68140886 -5.37351212  3.96043551])=-3.7137778367915644
# f([ 3.66863033 -5.3665076   3.94242437])=-3.7244122852336545
# f([ 3.65609144 -5.35963445  3.92475099])=-3.7346516157979863
# f([ 3.64378769 -5.35289019  3.90740904])=-3.7445105089016124
# f([ 3.63171467 -5.3462724   3.89039231])=-3.754003099517689
# f([ 3.61986806 -5.33977872  3.87369469])=-3.7631429974408377
# f([ 3.60824362 -5.33340682  3.8573102 ])=-3.771943306800523
# f([ 3.59683716 -5.3271544   3.84123298])=-3.7804166448486
# f([ 3.58564461 -5.32101924  3.82545725])=-3.7885751600483957
# f([ 3.57466196 -5.31499914  3.80997737])=-3.79643054949355
# f([ 3.56388527 -5.30909193  3.79478778])=-3.8039940756772808
# f([ 3.55331067 -5.3032955   3.77988304])=-3.8112765826403177
# f([ 3.54293438 -5.29760776  3.76525782])=-3.8182885115182614
# f([ 3.53275267 -5.2920267   3.75090686])=-3.8250399155112405
# f([ 3.52276191 -5.28655029  3.73682503])=-3.8315404742976966
# f([ 3.5129585  -5.28117658  3.72300727])=-3.837799507911825
# f([ 3.50333894 -5.27590365  3.70944864])=-3.8438259901068648
# f([ 3.49389977 -5.2707296   3.69614428])=-3.849628561219987
# f([ 3.48463762 -5.26565258  3.68308941])=-3.8552155405613178
# f([ 3.47554916 -5.26067077  3.67027937])=-3.8605949383404834
# f([ 3.46663114 -5.25578238  3.65770955])=-3.8657744671517094
# f([ 3.45788036 -5.25098567  3.64537546])=-3.8707615530317696
# f([ 3.44929368 -5.24627891  3.63327267])=-3.875563346106077
# f([ 3.44086803 -5.24166042  3.62139684])=-3.880186730840876
# f([ 3.43260039 -5.23712854  3.60974372])=-3.884638335913138
# f([ 3.42448779 -5.23268164  3.59830914])=-3.8889245437147224
# f([ 3.41652733 -5.22831814  3.58708898])=-3.8930514995024055
# f([ 3.40871615 -5.22403646  3.57607924])=-3.897025120209321
# f([ 3.40105145 -5.21983509  3.56527597])=-3.900851102927362
# f([ 3.39353049 -5.2157125   3.55467529])=-3.9045349330759223
# f([ 3.38615057 -5.21166722  3.54427341])=-3.908081892265983
# f([ 3.37890905 -5.2076978   3.5340666 ])=-3.9114970658732773
# f([ 3.37180333 -5.20380282  3.52405119])=-3.914785350328202
# f([ 3.36483087 -5.19998089  3.51422361])=-3.917951460136976
# f([ 3.35798916 -5.19623063  3.50458032])=-3.920999934640662
# f([ 3.35127575 -5.19255069  3.49511787])=-3.9239351445229147
# f([ 3.34468824 -5.18893977  3.48583288])=-3.9267612980770537
# f([ 3.33822427 -5.18539656  3.476722  ])=-3.9294824472390246
# f([ 3.33188151 -5.1819198   3.46778199])=-3.932102493397224
# f([ 3.3256577  -5.17850824  3.45900962])=-3.9346251929855782
# f([ 3.31955061 -5.17516066  3.45040177])=-3.9370541628696856
# f([ 3.31355805 -5.17187585  3.44195534])=-3.9393928855322144
# f([ 3.30767786 -5.16865265  3.43366731])=-3.9416447140657453
# f([ 3.30190795 -5.16548989  3.4255347 ])=-3.9438128769802177
# f([ 3.29624624 -5.16238644  3.4175546 ])=-3.9459004828321156
# f([ 3.2906907  -5.15934119  3.40972416])=-3.947910524680765
# f([ 3.28523935 -5.15635305  3.40204056])=-3.9498458843798687
# f([ 3.27989023 -5.15342094  3.39450105])=-3.9517093367091434
# f([ 3.27464142 -5.15054382  3.38710293])=-3.9535035533527036
# f([ 3.26949104 -5.14772066  3.37984355])=-3.9552311067296273
# f([ 3.26443725 -5.14495044  3.37272031])=-3.9568944736818707
# f([ 3.25947823 -5.14223217  3.36573065])=-3.958496039025647
# f([ 3.2546122  -5.13956488  3.35887206])=-3.9600380989701307
# f([ 3.24983744 -5.1369476   3.3521421 ])=-3.961522864410341
# f([ 3.24515221 -5.13437941  3.34553834])=-3.9629524640962757
# f([ 3.24055485 -5.13185938  3.33905843])=-3.9643289476852885
# f([ 3.2360437  -5.12938661  3.33270003])=-3.965654288680753
# f([ 3.23161714 -5.12696021  3.32646087])=-3.9669303872613852
# f([ 3.2272736  -5.12457931  3.32033872])=-3.968159073005836
# f([ 3.22301152 -5.12224306  3.31433137])=-3.9693421075153594
# f([ 3.21882936 -5.11995062  3.30843668])=-3.970481186939878
# f([ 3.21472563 -5.11770118  3.30265254])=-3.971577944409887
# f([ 3.21069886 -5.11549391  3.29697687])=-3.9726339523772367
# f([ 3.2067476  -5.11332805  3.29140763])=-3.973650724870538
# f([ 3.20287044 -5.11120279  3.28594283])=-3.9746297196650175
# f([ 3.19906599 -5.1091174   3.28058052])=-3.975572340373219
# f([ 3.19533289 -5.10707111  3.27531876])=-3.9764799384569756
# f([ 3.19166979 -5.10506319  3.27015568])=-3.977353815165287
# f([ 3.18807539 -5.10309293  3.26508942])=-3.9781952233998368
# f([ 3.18454839 -5.10115962  3.26011818])=-3.9790053695112704
# f([ 3.18108754 -5.09926256  3.25524015])=-3.9797854150290277
# f([ 3.17769158 -5.09740108  3.25045361])=-3.980536478326286
# f([ 3.17435932 -5.09557451  3.24575683])=-3.9812596362237116
# f([ 3.17108954 -5.09378219  3.24114812])=-3.9819559255331853
# f([ 3.16788108 -5.09202348  3.23662585])=-3.982626344544144
# f([ 3.16473279 -5.09029776  3.23218838])=-3.983271854455495
# f([ 3.16164354 -5.08860439  3.22783413])=-3.9838933807529315
# f([ 3.15861222 -5.08694279  3.22356153])=-3.984491814536085
# f([ 3.15563775 -5.08531234  3.21936906])=-3.9850680137964787
# f([ 3.15271906 -5.08371247  3.21525521])=-3.9856228046471642
# f([ 3.1498551  -5.0821426   3.21121851])=-3.9861569825075662
# f([ 3.14704485 -5.08060217  3.2072575 ])=-3.9866713132433347
# f([ 3.14428731 -5.07909063  3.20337078])=-3.9871665342650715
# f([ 3.14158147 -5.07760744  3.19955695])=-3.9876433555851065
# f([ 3.13892638 -5.07615206  3.19581464])=-3.9881024608356768
# f([ 3.13632108 -5.07472397  3.19214251])=-3.988544508248765
# f([ 3.13376464 -5.07332266  3.18853924])=-3.9889701316004107
# f([ 3.13125613 -5.07194764  3.18500354])=-3.989379941118642
# f([ 3.12879467 -5.07059839  3.18153415])=-3.989774524358978
# f([ 3.12637938 -5.06927446  3.17812982])=-3.990154447046592
# f([ 3.12400937 -5.06797534  3.17478934])=-3.9905202538873255
# f([ 3.12168381 -5.0667006   3.17151149])=-3.990872469348716
# f([ 3.11940186 -5.06544975  3.16829512])=-3.991211598412093
# f([ 3.11716271 -5.06422237  3.16513907])=-3.9915381272962236
# f([ 3.11496554 -5.063018    3.1620422 ])=-3.991852524154865
# f([ 3.11280958 -5.06183622  3.1590034 ])=-3.9921552397476603
# f([ 3.11069405 -5.06067659  3.1560216 ])=-3.9924467080865043
# f([ 3.10861819 -5.05953872  3.15309571])=-3.9927273470577234
# f([ 3.10658127 -5.05842218  3.15022469])=-3.9929975590213473
# f([ 3.10458254 -5.05732659  3.14740751])=-3.993257731387885
# f([ 3.10262129 -5.05625154  3.14464316])=-3.993508237173728
# f([ 3.10069682 -5.05519665  3.14193065])=-3.993749435536259
# f([ 3.09880844 -5.05416154  3.13926901])=-3.993981672288214
# f([ 3.09695548 -5.05314584  3.13665729])=-3.994205280394027
# f([ 3.09513726 -5.05214919  3.13409454])=-3.9944205804469846
# f([ 3.09335315 -5.05117123  3.13157985])=-3.9946278811287073
# f([ 3.09160248 -5.05021161  3.12911232])=-3.99482747965223
# f([ 3.08988465 -5.04926999  3.12669106])=-3.99501966218736
# f([ 3.08819904 -5.04834602  3.12431521])=-3.995204704271856
# f([ 3.08654503 -5.04743939  3.12198392])=-3.995382871205578
# f([ 3.08492204 -5.04654975  3.11969634])=-3.995554418431553
# f([ 3.08332949 -5.0456768   3.11745166])=-3.99571959190186
# f([ 3.08176681 -5.04482022  3.11524908])=-3.9958786284303898
# f([ 3.08023342 -5.0439797   3.1130878 ])=-3.9960317560323517
# f([ 3.0787288  -5.04315494  3.11096706])=-3.996179194251013
# f([ 3.07725239 -5.04234565  3.10888608])=-3.9963211544727244
# f([ 3.07580367 -5.04155154  3.10684413])=-3.9964578402298514
# f([ 3.07438211 -5.04077232  3.10484047])=-3.9965894474926245
# f([ 3.07298722 -5.04000771  3.10287438])=-3.9967161649501577
# f([ 3.07161848 -5.03925744  3.10094517])=-3.9968381742806116
# f([ 3.07027541 -5.03852125  3.09905214])=-3.9969556504125308
# f([ 3.06895753 -5.03779885  3.0971946 ])=-3.9970687617746137
# f([ 3.06766436 -5.03709001  3.0953719 ])=-3.9971776705377806
# f([ 3.06639545 -5.03639445  3.09358338])=-3.997282532847578
# f([ 3.06515033 -5.03571195  3.0918284 ])=-3.997383499048084
# f([ 3.06392856 -5.03504224  3.09010634])=-3.997480713897417
# f([ 3.0627297  -5.03438509  3.08841656])=-3.9975743167752142
# f([ 3.06155332 -5.03374026  3.08675848])=-3.9976644418825913
# f([ 3.06039901 -5.03310752  3.08513149])=-3.997751218434388
# f([ 3.05926634 -5.03248666  3.08353501])=-3.997834770844719
# f([ 3.05815491 -5.03187743  3.08196847])=-3.9979152189049785
# f([ 3.05706432 -5.03127963  3.0804313 ])=-3.9979926779557218
# f([ 3.05599419 -5.03069304  3.07892297])=-3.9980672590522204
# f([ 3.05494413 -5.03011745  3.07744292])=-3.9981390691236243
# f([ 3.05391375 -5.02955265  3.07599062])=-3.998208211125842
# f([ 3.0529027  -5.02899845  3.07456556])=-3.998274784189931
# f([ 3.05191061 -5.02845464  3.07316723])=-3.9983388837634095
# f([ 3.05093713 -5.02792103  3.07179511])=-3.9984006017477327
# f([ 3.0499819  -5.02739742  3.07044873])=-3.998460026629587
# f([ 3.04904458 -5.02688363  3.0691276 ])=-3.998517243608248
# f([ 3.04812485 -5.02637948  3.06783124])=-3.998572334717281
# f([ 3.04722236 -5.02588478  3.0665592 ])=-3.998625378942421
# f([ 3.04633679 -5.02539936  3.06531101])=-3.9986764523344505
# f([ 3.04546783 -5.02492305  3.06408622])=-3.9987256281188763
# f([ 3.04461517 -5.02445566  3.06288441])=-3.998772976800481
# f([ 3.0437785  -5.02399704  3.06170513])=-3.998818566264333
# f([ 3.04295751 -5.02354702  3.06054797])=-3.9988624618732445
# f([ 3.04215193 -5.02310545  3.0594125 ])=-3.9989047265617614
# f([ 3.04136145 -5.02267215  3.05829834])=-3.9989454209257502
# f([ 3.04058579 -5.02224697  3.05720506])=-3.998984603310049
# f([ 3.03982468 -5.02182977  3.05613229])=-3.999022329891517
# f([ 3.03907785 -5.0214204   3.05507963])=-3.9990586547597218
# f([ 3.03834501 -5.0210187   3.05404672])=-3.999093629994732
# f([ 3.03762593 -5.02062453  3.05303318])=-3.9991273057415526
# f([ 3.03692032 -5.02023776  3.05203864])=-3.9991597302819457
# f([ 3.03622795 -5.01985824  3.05106275])=-3.99919095010398
# f([ 3.03554857 -5.01948583  3.05010517])=-3.9992210099683234
# f([ 3.03488192 -5.01912041  3.04916554])=-3.999249952972704
# f([ 3.03422778 -5.01876185  3.04824354])=-3.9992778206135
# f([ 3.0335859  -5.01841     3.04733882])=-3.99930465284541
# f([ 3.03295606 -5.01806476  3.04645107])=-3.9993304881384972
# f([ 3.03233803 -5.01772599  3.04557997])=-3.999355363533539
# f([ 3.03173159 -5.01739357  3.0447252 ])=-3.9993793146950054
# f([ 3.03113653 -5.01706739  3.04388647])=-3.9994023759625748
# f([ 3.03055262 -5.01674732  3.04306346])=-3.9994245803996336
# f([ 3.02997966 -5.01643326  3.04225589])=-3.999445959841381
# f([ 3.02941745 -5.01612508  3.04146346])=-3.9994665449401055
# f([ 3.02886578 -5.01582269  3.04068589])=-3.999486365209407
# f([ 3.02832446 -5.01552596  3.0399229 ])=-3.999505449065907
# f([ 3.02779329 -5.0152348   3.03917422])=-3.9995238238708737
# f([ 3.02727208 -5.0149491   3.03843958])=-3.9995415159685734
# f([ 3.02676064 -5.01466876  3.03771872])=-3.999558550724828
# f([ 3.0262588  -5.01439368  3.03701138])=-3.9995749525629094
# f([ 3.02576636 -5.01412375  3.0363173 ])=-3.999590744998443
# f([ 3.02528317 -5.01385889  3.03563624])=-3.999605950673498
# f([ 3.02480903 -5.01359899  3.03496795])=-3.9996205913889185
# f([ 3.02434378 -5.01334397  3.03431219])=-3.999634688135586
# f([ 3.02388726 -5.01309373  3.03366873])=-3.9996482611242925
# f([ 3.0234393  -5.01284818  3.03303734])=-3.9996613298150123
# f([ 3.02299974 -5.01260723  3.03241779])=-3.999673912944843
# f([ 3.02256842 -5.01237081  3.03180985])=-3.999686028554322
# f([ 3.0221452  -5.01213882  3.03121332])=-3.999697694014202
# f([ 3.0217299  -5.01191118  3.03062797])=-3.9997089260494647
# f([ 3.0213224  -5.01168781  3.0300536 ])=-3.9997197407637373
# f([ 3.02092254 -5.01146862  3.02949   ])=-3.9997301536624548
# f([ 3.02053018 -5.01125355  3.02893698])=-3.999740179674845
# f([ 3.02014517 -5.01104251  3.02839432])=-3.999749833175599
# f([ 3.01976739 -5.01083543  3.02786184])=-3.99975912800501
# f([ 3.01939669 -5.01063223  3.02733934])=-3.999768077489506
# f([ 3.01903294 -5.01043285  3.02682664])=-3.9997766944601523
# f([ 3.01867601 -5.0102372   3.02632356])=-3.999784991271383
# f([ 3.01832578 -5.01004522  3.02582991])=-3.999792979818494
# f([ 3.01798212 -5.00985684  3.02534552])=-3.9998006715549366
# f([ 3.0176449  -5.00967199  3.02487021])=-3.9998080775086464
# f([ 3.017314   -5.00949061  3.02440382])=-3.999815208297548
# f([ 3.01698931 -5.00931264  3.02394617])=-3.9998220741454134
# f([ 3.01667071 -5.00913799  3.02349711])=-3.9998286848960163
# f([ 3.01635808 -5.00896663  3.02305646])=-3.999835050027201
# f([ 3.01605131 -5.00879848  3.02262408])=-3.999841178665065
# f([ 3.0157503  -5.00863348  3.02219981])=-3.9998470795963357
# f([ 3.01545493 -5.00847157  3.0217835 ])=-3.999852761281261
# f([ 3.01516511 -5.00831271  3.02137499])=-3.9998582318658293
# f([ 3.01488071 -5.00815682  3.02097414])=-3.9998634991935376
# f([ 3.01460165 -5.00800385  3.02058081])=-3.9998685708160906

# %% [markdown]
# **Etude  théorique**
# On a dans la base canonique
# $$\nabla f (x) = (14x_1 - 6x_2 - 12x_3 - 36, -6x_1 + 10x_2 + 8x_3 + 44, -12x_1 + 8x_2 + 12x_3 + 40)$$
# Résoudre $\nabla f (x) =0$ donne une solution unique $x^* = (3,-5,3)$ et $f(x^*)= -4$.

# %%
f(3,-5,3)
# Out:
# -4

# %% [markdown]
# ## Exercices

# %% [markdown]
# ## ex
# Retrouvez la dérivée de la fonction $f(x) = x^2 + 5x$ sur $\R$ en étudiant $f(x+h)-f(x)$.

# %% [markdown]
# ### ex
# Retrouvez la dérivée de la fonction $f(x) = \frac{1}{x}$ sur $\R^+$ en étudiant $f(x+h)-f(x)$.

# %% [markdown]
# ## ex
# Pour les trois normes définies dans le cours, dessinez la boule unité fermée dans $\R^2$ et remarquez les inclusions (la boule unité est l'ensemble des $x$ tels que $\|x\| \leq 1$).

# %% [markdown]
# ## ex
# Montrez que pour tout $x \in \R^2$ on a
# $$ \|x\|_\infty \leq \|x\|_2 \leq \|x\|_2 \leq 2 \|x\|_\infty $$
# Retrouvez les inclusions de l'exercice précédent.
