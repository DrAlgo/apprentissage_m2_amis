# %% [markdown]
# macros latex
# $$
# \def\R{{\mathbb R}}
# $$

# %% [markdown]
# # Notions de Calcul différentiel

# %% [markdown]
# ## Notion de dérivabilité en dimension 1
# **Rappel** : une fonction d'un intervalle ouvert $I \subset \R$ dans $\mathbb R$ est dite *dérivable* ou *différentiable* en $x \in I$ si la quantité
# $$\lim_{h \rightarrow 0, h \neq 0} \frac{f(x+h)-f(x)}{h}$$
# a une limite, qui est alors notée $f'(x)$.

# %% [markdown]
# Si on pose alors
# $$\epsilon(h) = \frac{f(x+h)-f(x)}{h} -f'(x)$$ la fonction $\epsilon$
# vérifie alors
# $$\lim_{h \to 0, h \neq 0} \epsilon(h) = 0.$$

# %% [markdown]
# On peut reformuler la notion de dérivabilité comme le fait que $f$ puisse s'écrire (pour $h$ assez petit) sous la forme
# $$f(x+h) = f(x) + h \cdot f'(x) + h \cdot\epsilon(h)$$
#
# avec $\epsilon$ une fonction qui tend vers $0$ en $0$.

# %% [markdown]
# La partie
# $$h \mapsto f(h) + h \cdot f'(x)$$
#
# est une approximation linéaire de $h \mapsto f(x+h)$ au voisinage de $0$ et la partie
#
# $$h \cdot \epsilon(h) = o(h)$$
#
# est une fonction **négligeable devant** $h$.

# %% [markdown]
# **exemple** Si $f(x) = x^3$ alors
# $$f(x+h) = (x+h)^3 = x^3 + 3x^2 h + 3x h^2 + h^3$$
# $$ = \boxed{f(x) + 3x^2 \cdot h} + h\cdot (3xh+h^2)$$
# L'application $h \mapsto 3x^2 \cdot h$ est linéaire, et $h \mapsto h(3xh+h^2)$ est négligeable devant $h$ (de la forme $h \times \epsilon(h)$ avec $\lim_{h \rightarrow 0} \epsilon(h) = 0$ ).
# On retrouve donc la formule $(x^3)' = 3x^2$.

# %% [markdown]
# Représentation graphique des fonctions
# $$h \mapsto f(2+h) = (2+h)^2$$
# et
# $$h \mapsto f(2) + h f'(2) = 8+12h$$

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 12))
h = np.linspace(-3,2,100)
plt.plot(h, (2+h)**3, color='red', label= "f(2+h)")
plt.plot(h, 8 + 12*h, color = 'green', label= "f(2) + h f'(2)")
plt.grid()
plt.axhline()
plt.axvline()
plt.legend(fontsize=20)
plt.close()

# %%
fig

# %% [markdown]
# ## L'espace ${\mathbb R}^n$
# ${\mathbb R}^n$ est l'espace vectoriel des $n$-uplets de réels de la forme
# $$x = (x_1, x_2, \dots, x_n)$$
# On peut identifier dans la base canonique ce vecteur à une matrice (vecteur colonne) de dimension $n \times 1$.
# $${\bf x} = \begin{pmatrix}
# x_1 \\
# x_2 \\
# \dots \\
# x_n
# \end{pmatrix}$$

# %% [markdown]
# On peut mesurer les distances en utilisant des **normes**. La norme d'un vecteur mesure sa "longueur" qui peut aussi être vue comme sa distance à $\bf 0$.
#
# Norme 2 (euclidienne) : $\|x\|_2 = \sqrt{\sum_{i=1}^n x_i^2}$
# Norme 1 : $\|x\|_1 = \sum_{i=1}^n | x_i | $
# Norme infinie : $\|x\|_\infty = \max_{1 \leq i \leq n} \| x_i \| $

# %% [markdown]
# On peut alors mesurer des distances entre vecteurs par
# $$d(x,y) = \|x-y\|$$
#
# Pour les propriétés topologiques (continuité, limites) on peut utiliser de façon *équivalente* n'importe laquelle de ces normes.

# %% [markdown]
# Une application linéaire de $\R^n$ dans $\R^m$ est une application
# $$ f :  \R^n \rightarrow \R^m$$
# qui vérifie
# $$\forall x,y \in \R^n, f(x+y) = f(x) + f(y)$$
# $$\forall \lambda \in \R, \forall x \in \R^n, f(\lambda x) = \lambda f(x)$$

# %% [markdown]
# **exemple :** $f$ de $\R^3$ dans $\R^2$ définie par
#
# $$f(x,y,z) = (2x+y-z, x+3z)$$

# %% [markdown]
# Une telle application peut s'écrire sous la forme
# $$f(x_1, x_2, \dots, x_n) = ( \sum_{j=1}^n a_{1,j} x_j, \sum_{i=j}^n a_{2,i} x_j, \dots, \sum_{i=1}^n a_{m,j} x_j )$$

# %% [markdown]
# On peut représenter $f$ par une matrice à $m$ lignes et $n$ colonnes
# $$ A = (a_{i,j})_{1\leq i \leq m, 1 \leq j \leq m} $$
# Les espaces $\R^n$ et $\R^m$ sont identifiés à l'ensemble des  vecteurs colonnes $n \times 1$ et $m \times 1$
# et l'application linéaire correspond au produit matriciel
# $$ Y = A X $$
# $$ (n,1) \sim (m,n) \cdot (n,1)$$

# %% [markdown]
# **cas particulier** Les applications linéaires sur $\R^n$ à valeur dans $\R$ (formes linéaires) sont représentées par des matrices de dimensions $(1,n)$ donc des matrices ligne.
#
# On peut représenter une telle ligne comme la transposée d'un vecteur colonne donc une forme linéaire
# peut s'écrire sous la forme
#
# $$f({\bf x}) = {\bf a}^T x$$
#
# où $\bf a$ est un vecteur colonne de dimension $n$. Le produit
# $${\bf a}^T x = \sum_{j=1}^n a_i x_i$$
# est aussi le produit scalaire (euclidien) des vecteurs.

# %% [markdown]
# **exemple :** $f$ de $\R^3$ dans $\R$
#
# $$ f(x,y,z) = 3x-y-2z $$
# est représentée par le vecteur
# $${\bf a} = \begin{pmatrix}
# 3 \\
# -1 \\
# -2
# \end{pmatrix}$$

# %% [markdown]
# ## Différentielle en dimension $n$
# Soit maintenant $f$ une fonction de ${\mathbb R}^n$ dans ${\mathbb R}$. La différentielle $\ell$ de $f$ en un point $x$ est une approximation linéaire de $f$ et $x$, elle doit donc réaliser
# $$f(x+h) = f(x) + \ell(h) + o(h)$$
# Ici $h \mapsto \ell(h)$ doit être une *application linéaire* (forme linéaire en fait) de ${\mathbb R}^n$ dans ${\mathbb R}$
# et $o(h)$ est une fonction qui est négligeable devant $h$.

# %% [markdown]
# Rappel : une application linéaire de  ${\mathbb R}^n$ dans ${\mathbb R}$ peut s'écrire dans une base
# sous la forme
# $$\ell(h) = \sum_{i=1}^n a_i h_i$$
# On peut représenter ce calcul aussi comme le produit matriciel ${\bf a}^T \cdot \bf h$ où $\bf a$ et $\bf h$ sont les vecteurs colonnes correspondant à $a$ et $h$.

# %% [markdown]
# **exemple :** Soit $f(x_1,x_2) = (x_1+3x_2)^2$. On considère sa différentielle au point $x =(x_1,x_2)$.
#
# On a $$f(x_1 + h_1, x_2 + h_2) = (x_1 + h_1 +3 x_2 + 3 h_2)^2$$
# $$ = (x_1 + 3x_2)^2 + 2(x_1+3x_2)(h_1+3h_2) + (h_1+3h_2)^2$$

# %% [markdown]
# On peut facilement montrer que $h = (h_1,h_2) \mapsto (h_1+3h_2)^2$ est un $o(h)$ (négligeable) car
# $$| (h_1+3h_2)^2 | = (h_1+3h_2)  (h_1+3h_2) \leq 3 (|h_1| + |h_2|) (h_1 + 3h_2)$$
# donc est de la forme $\|h\|_1 \epsilon(h)$.

# %% [markdown]
# On peut donc écrire que
# $$f(x+h) = f(x) +  2(x_1+3x_2)h_1 + 6(x_1+3x_2) h_2 + o(h)$$
# La différentielle de $f$ en $x=(x_1,x_2)$ est l'application linéaire à valeurs dans $\R$
# $$h = (h_1,h_2) \mapsto 2(x_1+3x_2)h_1 + 6(x_1+3x_2) h_2 $$
# et peut être représentée par le vecteur
# $${\bf a} = \begin{pmatrix}
# 2 x_1+ 6 x_2 \\
# 6 x_1 + 18x_2
# \end{pmatrix}$$

# %% [markdown]
# Rappel : $f(x_1,x_2) = (x_1+3x_2)^2$
#
# On a $$\frac{\partial f}{\partial x_1}(x) = 2(x_1 + 3 x_2) = 2x_1 + 6 x_2$$
# et
# $$\frac{\partial f}{\partial x_2}(x) = 3 \times 2(x_1 + 3 x_2) = 6 x_1 + 18 x_2$$
# On retrouve les coordonnées du vecteur de la différentielle.

# %% [markdown]
# Le vecteur $a$ représentant la différentielle de $f$ est appelé le **gradient de f en x** et est noté $grad(f)(x)$ ou  $\nabla f (x)$ et ses coordonnées sont
# $$\nabla f (x) = (\frac{\partial f}{\partial x_1}(x), \frac{\partial f}{\partial x_2}(x), \dots, \frac{\partial f}{\partial x_n}(x))^T$$
# où $\frac{\partial f}{\partial x_i}(x)$ est la dérivée partielle de $f$ par rapport à $x_i$.

# %% [markdown]
# L'ensemble des vecteurs $h$ tels que $\langle \nabla f (x), h\rangle > 0$ forme un demi-espace et  ces vecteurs sont appelés directions de montée ; à l'inverse les vecteurs $h$ tels que $\langle \nabla f (x), h\rangle < 0$ sont les directions de descente.
# Si h est une direction de descente alors
# $$ f(x+h) = f(x) + \langle \nabla f (x), h\rangle + o(||h||) < f(x) $$
# si $h$ est assez petit ($||h|| < \epsilon$ pour un $\epsilon > 0$).

# %% [markdown]
# <img src="images/gradient.png" width=400 alt="schéma gradient" align="left"/>

# %% [markdown]
# ** exemple ** Toujours avec  $f(x_1,x_2) = (x_1+3x_2)^2$ et
# $${\bf \nabla f(x)} = \begin{pmatrix}
# 2 x_1+ 6 x_2 \\
# 6 x_1 + 18x_2
# \end{pmatrix}$$
#
# En $x_0 = (2,1)$ on a $\nabla f(x) = (10, 30)^T$. Toutes les directions $h=(h_1,h_2)$ vérifiant
# $$\langle \nabla f(x), h \rangle = 10 h_1 + 30 h_2 > 0$$
# sont des directions de montée et donc vérifient $f(x_0+h) > f(x_0)$ pour $h$ assez petit,
# et les directions vérifiant  $10 h_1 + 30 h_2 < 0$ sont des directions de descente.

# %% [markdown]
# ## gradient et extremums
# **Propriété** : Si $f$ admet un gradient en $x$ et que $x$ est un minimum ou un maximum local de $f$, alors
# $$\nabla f(x) = 0$$
# Attention, la réciproque est fausse. Considérer $f(x)=x^3$ en $x=0$.
#
# Trouver les $x$ qui annulent le gradient permet trouver les candidats potentiels à être un minimum ou maximum.

# %% [markdown]
# *preuve* (cas du minimum) Si $\nabla f (x) \neq 0$ alors si $t$ est suffisament petit on a
# (en postant $h = - t \nabla f(x)$)
# $$f(x - t \nabla f(x) )  = f(x)  -  \langle \nabla f(x), t \nabla f(x) \rangle + o(t)$$
# soit
# $$f(x - t \nabla f(x) )  = f(x)  -  t ||\nabla f(x)||^2 + o(t)$$
# qui est $ < f(x)$ pour $t$ assez petit, contredisant le fait que $f$ est un minimum local.

# %% [markdown]
# <img src="images/convex2d.png" width=400>
# Une fonction convexe sur $\R^2$

# %% [markdown]
# **exemple**  $f(x,y) = 2 x^2 - 7x -xy + y^2$ fonction continue qui tend vers $+\infty$ quand $x,y$ tend vers l'infini donc admet (au moins) un minimum. On peut le trouver car
#
# $$\nabla f(x,y) = (4x-4 -7y, -x + 2y)^T = \bf 0$$
#
# seulement si x=8 et y=4.
#
# Comme $f$ doit avoir un minimum c'est forcément $(8,4)$.

# %% [markdown]
# # Descente de gradient
#
# Bien souvent (en grande dimension) il n'est pas possible de résoudre le système d'équations $\nabla f(x)=\bf 0$.
# On utilise alors une méthode *itérative*.
# La *descente de gradient* est un algorithme pour calculer un minimum d'une fonction.
# L'algorithme produit une suite de points $x_0, x_1, x_2, \dots$ et va s'arrêter quand le gradient de $f$
# est suffisament petit ( $\| \nabla f\| <  \epsilon$ )

# %% [markdown]
# * paramètres : choisir $\epsilon >0$ la tolérance, et $\alpha > 0$ le pas de gradient
# * Initialisation : choisir $x_0$, poser $k =0$
# * Tant que $\| \nabla f\| \geq \epsilon$ répéter :
#     * $\displaystyle x_{k+1} = x_k - \alpha \nabla f(x_k)$
#     * $k \leftarrow k+1$

# %% [markdown]
# Dans le cas général il n'y a pas de garantie de trouver un minimum par cette manière. Cependant si $f$ est convexe (forme en bol comme $x^2$ ) alors la méthode convergera vers l'unique minimum de $f$. Il peut être nécessaire pour cela de faire diminuer le pas lorsqu'on approche du minimum.

# %% [markdown]
# Exemple. On considère la fonction sur ${\mathbb R}^3$
# $$f(x,y,z) = 7x^2 - 6xy + 5y^2 - 12xz + 8yz + 6z^2 - 36x + 44y + 40z + 10 + 1$$

# %%
f = lambda x,y,z : 7*x**2 - 6*x*y + 5*y**2 - 12*x*z + 8*y*z + 6*z**2 - 36*x + 44*y + 40*z + 105
diff = lambda x,y,z : np.array((14*x - 6*y - 12*z - 36, -6*x + 10*y + 8*z + 44, -12*x + 8*y + 12*z + 40))

# %%
import numpy as np
def descente_gradient(f, diff, epsilon, alpha, x0):
    x = x0
    k = 0
    while sum(x**2) >= epsilon**2 and k<1000:
        x = x - alpha*diff(*x)
        print( "f(" +str(x)+ ")=" + str(f(*x)))
        k +=1

# %%
descente_gradient(f, diff, 0.1, 0.05, np.array((20.0,20.0,20.0)))
# Out:
# f([25.8  5.8 10. ])=1729.239999999999
# f([17.28  4.44 15.16])=786.9568000000002
# f([17.412 -0.86  12.656])=391.9336000000002
# f([14.3592 -2.4688 13.8536])=210.86669632000047
# f([13.67928 -4.66808 13.14448])=122.9831886976001
# f([12.390048 -5.688048 13.332592])=78.76065523993589
# f([11.8101552 -6.6600464 13.0422848])=55.89279370511872
# f([11.17040352 -7.20389056 12.9670256 ])=43.71844915774068
# f([10.77016925 -7.63763446 12.77060858])=36.97049888435629
# f([10.40212558 -7.89600989 12.62539876])=33.00126462992063
# f([10.12707397 -8.07752678 12.44983881])=30.467967783914673
# f([ 9.88476744 -8.18057672 12.28719061])=28.686394879567956
# f([ 9.68357158 -8.23973437 12.1179674 ])=27.3068614829092
# f([ 9.5039316  -8.26198267 11.95322366])=26.15016017805158
# f([ 9.34451888 -8.26110132 11.78844149])=25.12410347615321
# f([ 9.19809016 -8.24257159 11.62652845])=24.180967211811833
# f([ 9.06257264 -8.21247013 11.46649412])=23.295764951102797
# f([ 8.93492722 -8.17406092 11.30912928])=22.45515037061648
# f([ 8.81373746 -8.13020401 11.15423241])=21.651746610476607
# f([ 8.69759949 -8.08267373 11.00201704])=20.881247951855357
# f([ 8.58568795 -8.03286384 10.852436  ])=20.14093800503872
# f([ 8.47730884 -7.98169993 10.70553271])=19.428931740936036
# f([ 8.3720023  -7.9298704  10.56127836])=18.743787439664402
# f([ 8.26940658 -7.87784585 10.41966088])=18.0843077002329
# f([ 8.16926475 -7.8259653  10.28064664])=17.449437090529557
# f([ 8.07137782 -7.77446189 10.14420363])=16.838209207644923
# f([ 7.97559696 -7.72349905 10.0102929 ])=16.249719011893603
# f([ 7.88180511 -7.6731876   9.87887495])=15.68310809917375
# f([ 7.78991023 -7.62360225  9.74990809])=15.13755660709478
# f([ 7.69983725 -7.57479129  9.62335027])=14.612278532245568
# f([ 7.61152395 -7.52678458  9.49915897])=14.106518810960154
# f([ 7.52491719 -7.47959869  9.37729179])=13.61955132083358
# f([ 7.43997062 -7.4332409   9.25770651])=13.150677371593929
# f([ 7.35664282 -7.38771187  9.14036134])=12.699224464175984
# f([ 7.27489609 -7.34300762  9.02521497])=12.264545204301896
# f([ 7.19469552 -7.29912097  8.91222669])=11.84601631183159
# f([ 7.11600838 -7.25604251  8.80135638])=11.443037695222472
# f([ 7.03880359 -7.21376129  8.69256458])=11.055031574850773
# f([ 6.96305144 -7.1722654   8.5858125 ])=10.681441646295184
# f([ 6.88872331 -7.13154227  8.48106203])=10.32173227848756
# f([ 6.81579153 -7.09157895  8.37827571])=9.975387743586055
# f([ 6.7442292  -7.0523623   8.27741678])=9.641911476449877
# f([ 6.67401014 -7.0138791   8.17844915])=9.320825362130563
# f([ 6.6051088  -6.97611617  8.08133738])=9.011669050094099
# f([ 6.53750022 -6.9390604   7.9860467 ])=8.713999294056975
# f([ 6.47115997 -6.90269881  7.89254297])=8.427389316412757
# f([ 6.40606413 -6.86701861  7.8007927 ])=8.151428196312736
# f([ 6.34218927 -6.83200714  7.710763  ])=7.885720280495718
# f([ 6.27951244 -6.79765199  7.62242162])=7.629884616019467
# f([ 6.21801111 -6.76394091  7.53573691])=7.383554404071845
# f([ 6.1576632  -6.73086189  7.45067779])=7.146376474079489
# f([ 6.09844707 -6.6984031   7.36721379])=6.918010777354311
# f([ 6.04034147 -6.66655295  7.285315  ])=6.6981298995570455
# f([ 5.98332556 -6.63530003  7.20495206])=6.486418591272638
# f([ 5.92737889 -6.60463317  7.12609617])=6.282573316028163
# f([ 5.87248142 -6.57454139  7.04871907])=6.086301815104775
# f([ 5.81861345 -6.5450139   6.97279303])=5.897322688516681
# f([ 5.76575569 -6.51604013  6.89829084])=5.715364991561387
# f([ 5.71388917 -6.48760969  6.8251858 ])=5.5401678463578605
# f([ 5.66299532 -6.45971241  6.7534517 ])=5.371480067819164
# f([ 5.61305589 -6.43233829  6.68306284])=5.20905980352029
# f([ 5.56405299 -6.40547751  6.61399399])=5.052674186948252
# f([ 5.51596904 -6.37912046  6.54622039])=4.902099003635158
# f([ 5.46878681 -6.35325768  6.47971776])=4.757118369694638
# f([ 5.4224894  -6.3278799   6.41446226])=4.617524422303575
# f([ 5.37706021 -6.30297803  6.3504305 ])=4.483117021683398
# f([ 5.33248295 -6.27854316  6.28759954])=4.353703464153938
# f([ 5.28874166 -6.25456651  6.22594685])=4.229098205848231
# f([ 5.24582066 -6.23103949  6.16545034])=4.109122596694419
# f([ 5.20370455 -6.20795369  6.10608833])=3.9936046242780208
# f([ 5.16237826 -6.18530081  6.04783954])=3.882378667224998
# f([ 5.12182696 -6.16307274  5.99068309])=3.775285257744116
# f([ 5.08203612 -6.14126152  5.93459851])=3.6721708529944976
# f([ 5.04299148 -6.11985933  5.87956568])=3.5728876149465805
# f([ 5.00467906 -6.09885849  5.82556489])=3.4772931984223305
# f([ 4.96708511 -6.07825149  5.77257679])=3.3852505470108554
# f([ 4.93019616 -6.05803093  5.72058237])=3.2966276965680095
# f([ 4.89399899 -6.03818957  5.66956302])=3.2112975860137
# f([ 4.85848064 -6.01872029  5.61950043])=3.1291378751624563
# f([ 4.82362836 -5.99961613  5.57037667])=3.050030769320017
# f([ 4.78942967 -5.98087022  5.52217414])=2.9738628503982625
# f([ 4.75587232 -5.96247586  5.47487555])=2.900524914303901
# f([ 4.72294426 -5.94442646  5.42846395])=2.829911814370007
# f([ 4.69063371 -5.92671553  5.38292272])=2.7619223106040636
# f([ 4.65892909 -5.90933674  5.33823553])=2.6964589245373247
# f([ 4.62781902 -5.89228386  5.29438636])=2.63342779946737
# f([ 4.59729237 -5.87555077  5.2513595 ])=2.5727385658928483
# f([ 4.56733818 -5.85913147  5.20913953])=2.5143042119480867
# f([ 4.53794573 -5.84302009  5.16771131])=2.4580409586520773
# f([ 4.50910448 -5.82721085  5.12706   ])=2.4038681397923938
# f([ 4.48080409 -5.81169808  5.08717102])=2.3517080862707758
# f([ 4.45303442 -5.79647622  5.04803009])=2.3014860147479226
# f([ 4.42578551 -5.78153983  5.00962318])=2.2531299204234188
# f([ 4.39904761 -5.76688353  4.97193651])=2.206570473801605
# f([ 4.37281113 -5.75250208  4.93495658])=2.1617409212908
# f([ 4.34706666 -5.73839034  4.89867015])=2.1185769894975692
# f([ 4.32180499 -5.72454323  4.86306419])=2.077016793075643
# f([ 4.29701704 -5.71095579  4.82812596])=2.0370007459997055
# f([ 4.27269395 -5.69762317  4.79384293])=1.9984714761345117
# f([ 4.24882699 -5.68454057  4.76020281])=1.96137374297939
# f([ 4.22540761 -5.67170331  4.72719354])=1.925654358468364
# f([ 4.20242742 -5.65910679  4.69480331])=1.8912621107125744
# f([ 4.17987817 -5.64674649  4.66302049])=1.8581476905766294
# f([ 4.1577518  -5.63461799  4.6318337 ])=1.8262636209826724
# f([ 4.13604036 -5.62271693  4.60123175])=1.795564188841098
# f([ 4.11473608 -5.61103906  4.57120369])=1.7660053795102044
# f([ 4.09383132 -5.59958018  4.54173875])=1.7375448136916702
# f([ 4.07331859 -5.58833619  4.51282637])=1.710141686669715
# f([ 4.05319054 -5.57730307  4.48445618])=1.6837567098085913
# f([ 4.03343995 -5.56647684  4.45661802])=1.6583520542227461
# f([ 4.01405974 -5.55585365  4.42930191])=1.6338912965412078
# f([ 3.99504298 -5.54542967  4.40249807])=1.6103393666859347
# f([ 3.97638284 -5.53520117  4.37619688])=1.5876624975909408
# f([ 3.95807263 -5.52516449  4.35038892])=1.5658281767896653
# f([ 3.9401058  -5.51531602  4.32506494])=1.5448050998005556
# f([ 3.9224759  -5.50565225  4.30021586])=1.5245631252454643
# f([ 3.90517661 -5.4961697   4.27583278])=1.505073231634583
# f([ 3.88820174 -5.48686498  4.25190696])=1.4863074757579398
# f([ 3.8715452  -5.47773475  4.22842982])=1.46823895262213
# f([ 3.85520103 -5.46877574  4.20539295])=1.4508417568760592
# f([ 3.83916336 -5.45998474  4.1827881 ])=1.434090945669567
# f([ 3.82342644 -5.4513586   4.16060715])=1.417962502892351
# f([ 3.80798464 -5.44289423  4.13884217])=1.4024333047412938
# f([ 3.79283242 -5.43458859  4.11748534])=1.387481086566936
# f([ 3.77796436 -5.4264387   4.09652903])=1.373084410952572
# f([ 3.76337511 -5.41844166  4.07596571])=1.3592226369783589
# f([ 3.74905946 -5.41059458  4.05578801])=1.3458758906282071
# f([ 3.73501227 -5.40289465  4.03598871])=1.3330250362953393
# f([ 3.72122851 -5.39533913  4.01656071])=1.3206516493476954
# f([ 3.70770324 -5.3879253   3.99749704])=1.308737989711375
# f([ 3.69443161 -5.38065049  3.97879088])=1.2972669764366174
# f([ 3.68140886 -5.37351212  3.96043551])=1.2862221632084356
# f([ 3.66863033 -5.3665076   3.94242437])=1.2755877147663455
# f([ 3.65609144 -5.35963445  3.92475099])=1.2653483842020137
# f([ 3.64378769 -5.35289019  3.90740904])=1.2554894910983876
# f([ 3.63171467 -5.3462724   3.89039231])=1.2459969004823108
# f([ 3.61986806 -5.33977872  3.87369469])=1.2368570025591623
# f([ 3.60824362 -5.33340682  3.8573102 ])=1.228056693199477
# f([ 3.59683716 -5.3271544   3.84123298])=1.2195833551514
# f([ 3.58564461 -5.32101924  3.82545725])=1.2114248399516043
# f([ 3.57466196 -5.31499914  3.80997737])=1.2035694505064498
# f([ 3.56388527 -5.30909193  3.79478778])=1.1960059243227192
# f([ 3.55331067 -5.3032955   3.77988304])=1.1887234173596823
# f([ 3.54293438 -5.29760776  3.76525782])=1.1817114884817386
# f([ 3.53275267 -5.2920267   3.75090686])=1.1749600844887595
# f([ 3.52276191 -5.28655029  3.73682503])=1.1684595257023034
# f([ 3.5129585  -5.28117658  3.72300727])=1.162200492088175
# f([ 3.50333894 -5.27590365  3.70944864])=1.1561740098931352
# f([ 3.49389977 -5.2707296   3.69614428])=1.150371438780013
# f([ 3.48463762 -5.26565258  3.68308941])=1.1447844594386822
# f([ 3.47554916 -5.26067077  3.67027937])=1.1394050616595166
# f([ 3.46663114 -5.25578238  3.65770955])=1.1342255328482906
# f([ 3.45788036 -5.25098567  3.64537546])=1.1292384469682304
# f([ 3.44929368 -5.24627891  3.63327267])=1.1244366538939232
# f([ 3.44086803 -5.24166042  3.62139684])=1.119813269159124
# f([ 3.43260039 -5.23712854  3.60974372])=1.115361664086862
# f([ 3.42448779 -5.23268164  3.59830914])=1.1110754562852776
# f([ 3.41652733 -5.22831814  3.58708898])=1.1069485004975945
# f([ 3.40871615 -5.22403646  3.57607924])=1.102974879790679
# f([ 3.40105145 -5.21983509  3.56527597])=1.099148897072638
# f([ 3.39353049 -5.2157125   3.55467529])=1.0954650669240777
# f([ 3.38615057 -5.21166722  3.54427341])=1.091918107734017
# f([ 3.37890905 -5.2076978   3.5340666 ])=1.0885029341267227
# f([ 3.37180333 -5.20380282  3.52405119])=1.0852146496717978
# f([ 3.36483087 -5.19998089  3.51422361])=1.082048539863024
# f([ 3.35798916 -5.19623063  3.50458032])=1.0790000653593381
# f([ 3.35127575 -5.19255069  3.49511787])=1.0760648554770853
# f([ 3.34468824 -5.18893977  3.48583288])=1.0732387019229463
# f([ 3.33822427 -5.18539656  3.476722  ])=1.0705175527609754
# f([ 3.33188151 -5.1819198   3.46778199])=1.067897506602776
# f([ 3.3256577  -5.17850824  3.45900962])=1.0653748070144218
# f([ 3.31955061 -5.17516066  3.45040177])=1.0629458371303144
# f([ 3.31355805 -5.17187585  3.44195534])=1.0606071144677856
# f([ 3.30767786 -5.16865265  3.43366731])=1.0583552859342547
# f([ 3.30190795 -5.16548989  3.4255347 ])=1.0561871230197823
# f([ 3.29624624 -5.16238644  3.4175546 ])=1.0540995171678844
# f([ 3.2906907  -5.15934119  3.40972416])=1.0520894753192351
# f([ 3.28523935 -5.15635305  3.40204056])=1.0501541156201313
# f([ 3.27989023 -5.15342094  3.39450105])=1.0482906632908566
# f([ 3.27464142 -5.15054382  3.38710293])=1.0464964466472964
# f([ 3.26949104 -5.14772066  3.37984355])=1.0447688932703727
# f([ 3.26443725 -5.14495044  3.37272031])=1.0431055263181293
# f([ 3.25947823 -5.14223217  3.36573065])=1.041503960974353
# f([ 3.2546122  -5.13956488  3.35887206])=1.0399619010298693
# f([ 3.24983744 -5.1369476   3.3521421 ])=1.038477135589659
# f([ 3.24515221 -5.13437941  3.34553834])=1.0370475359037243
# f([ 3.24055485 -5.13185938  3.33905843])=1.0356710523147115
# f([ 3.2360437  -5.12938661  3.33270003])=1.0343457113192471
# f([ 3.23161714 -5.12696021  3.32646087])=1.0330696127386148
# f([ 3.2272736  -5.12457931  3.32033872])=1.031840926994164
# f([ 3.22301152 -5.12224306  3.31433137])=1.0306578924846406
# f([ 3.21882936 -5.11995062  3.30843668])=1.0295188130601218
# f([ 3.21472563 -5.11770118  3.30265254])=1.028422055590113
# f([ 3.21069886 -5.11549391  3.29697687])=1.0273660476227633
# f([ 3.2067476  -5.11332805  3.29140763])=1.026349275129462
# f([ 3.20287044 -5.11120279  3.28594283])=1.0253702803349825
# f([ 3.19906599 -5.1091174   3.28058052])=1.024427659626781
# f([ 3.19533289 -5.10707111  3.27531876])=1.0235200615430244
# f([ 3.19166979 -5.10506319  3.27015568])=1.0226461848347128
# f([ 3.18807539 -5.10309293  3.26508942])=1.0218047766001632
# f([ 3.18454839 -5.10115962  3.26011818])=1.0209946304887296
# f([ 3.18108754 -5.09926256  3.25524015])=1.0202145849709723
# f([ 3.17769158 -5.09740108  3.25045361])=1.019463521673714
# f([ 3.17435932 -5.09557451  3.24575683])=1.0187403637762884
# f([ 3.17108954 -5.09378219  3.24114812])=1.0180440744668147
# f([ 3.16788108 -5.09202348  3.23662585])=1.017373655455856
# f([ 3.16473279 -5.09029776  3.23218838])=1.016728145544505
# f([ 3.16164354 -5.08860439  3.22783413])=1.0161066192470685
# f([ 3.15861222 -5.08694279  3.22356153])=1.015508185463915
# f([ 3.15563775 -5.08531234  3.21936906])=1.0149319862035213
# f([ 3.15271906 -5.08371247  3.21525521])=1.0143771953528358
# f([ 3.1498551  -5.0821426   3.21121851])=1.0138430174924338
# f([ 3.14704485 -5.08060217  3.2072575 ])=1.0133286867566653
# f([ 3.14428731 -5.07909063  3.20337078])=1.0128334657349285
# f([ 3.14158147 -5.07760744  3.19955695])=1.0123566444148935
# f([ 3.13892638 -5.07615206  3.19581464])=1.0118975391643232
# f([ 3.13632108 -5.07472397  3.19214251])=1.011455491751235
# f([ 3.13376464 -5.07332266  3.18853924])=1.0110298683995893
# f([ 3.13125613 -5.07194764  3.18500354])=1.0106200588813579
# f([ 3.12879467 -5.07059839  3.18153415])=1.0102254756410218
# f([ 3.12637938 -5.06927446  3.17812982])=1.0098455529534078
# f([ 3.12400937 -5.06797534  3.17478934])=1.0094797461126745
# f([ 3.12168381 -5.0667006   3.17151149])=1.0091275306512841
# f([ 3.11940186 -5.06544975  3.16829512])=1.008788401587907
# f([ 3.11716271 -5.06422237  3.16513907])=1.0084618727037764
# f([ 3.11496554 -5.063018    3.1620422 ])=1.008147475845135
# f([ 3.11280958 -5.06183622  3.1590034 ])=1.0078447602523397
# f([ 3.11069405 -5.06067659  3.1560216 ])=1.0075532919134957
# f([ 3.10861819 -5.05953872  3.15309571])=1.0072726529422766
# f([ 3.10658127 -5.05842218  3.15022469])=1.0070024409786527
# f([ 3.10458254 -5.05732659  3.14740751])=1.0067422686121148
# f([ 3.10262129 -5.05625154  3.14464316])=1.006491762826272
# f([ 3.10069682 -5.05519665  3.14193065])=1.0062505644637412
# f([ 3.09880844 -5.05416154  3.13926901])=1.0060183277117858
# f([ 3.09695548 -5.05314584  3.13665729])=1.0057947196059729
# f([ 3.09513726 -5.05214919  3.13409454])=1.0055794195530154
# f([ 3.09335315 -5.05117123  3.13157985])=1.0053721188712927
# f([ 3.09160248 -5.05021161  3.12911232])=1.0051725203477702
# f([ 3.08988465 -5.04926999  3.12669106])=1.0049803378126398
# f([ 3.08819904 -5.04834602  3.12431521])=1.0047952957281439
# f([ 3.08654503 -5.04743939  3.12198392])=1.0046171287944219
# f([ 3.08492204 -5.04654975  3.11969634])=1.0044455815684472
# f([ 3.08332949 -5.0456768   3.11745166])=1.0042804080981398
# f([ 3.08176681 -5.04482022  3.11524908])=1.0041213715696102
# f([ 3.08023342 -5.0439797   3.1130878 ])=1.0039682439676483
# f([ 3.0787288  -5.04315494  3.11096706])=1.0038208057489868
# f([ 3.07725239 -5.04234565  3.10888608])=1.0036788455272756
# f([ 3.07580367 -5.04155154  3.10684413])=1.0035421597701486
# f([ 3.07438211 -5.04077232  3.10484047])=1.0034105525073755
# f([ 3.07298722 -5.04000771  3.10287438])=1.0032838350498423
# f([ 3.07161848 -5.03925744  3.10094517])=1.0031618257193884
# f([ 3.07027541 -5.03852125  3.09905214])=1.0030443495874692
# f([ 3.06895753 -5.03779885  3.0971946 ])=1.0029312382253863
# f([ 3.06766436 -5.03709001  3.0953719 ])=1.0028223294622194
# f([ 3.06639545 -5.03639445  3.09358338])=1.0027174671524222
# f([ 3.06515033 -5.03571195  3.0918284 ])=1.0026165009519161
# f([ 3.06392856 -5.03504224  3.09010634])=1.002519286102583
# f([ 3.0627297  -5.03438509  3.08841656])=1.0024256832247858
# f([ 3.06155332 -5.03374026  3.08675848])=1.0023355581174087
# f([ 3.06039901 -5.03310752  3.08513149])=1.002248781565612
# f([ 3.05926634 -5.03248666  3.08353501])=1.0021652291552812
# f([ 3.05815491 -5.03187743  3.08196847])=1.0020847810950215
# f([ 3.05706432 -5.03127963  3.0804313 ])=1.0020073220442782
# f([ 3.05599419 -5.03069304  3.07892297])=1.0019327409477796
# f([ 3.05494413 -5.03011745  3.07744292])=1.0018609308763757
# f([ 3.05391375 -5.02955265  3.07599062])=1.0017917888741579
# f([ 3.0529027  -5.02899845  3.07456556])=1.001725215810069
# f([ 3.05191061 -5.02845464  3.07316723])=1.0016611162365905
# f([ 3.05093713 -5.02792103  3.07179511])=1.0015993982522673
# f([ 3.0499819  -5.02739742  3.07044873])=1.001539973370413
# f([ 3.04904458 -5.02688363  3.0691276 ])=1.001482756391752
# f([ 3.04812485 -5.02637948  3.06783124])=1.0014276652827192
# f([ 3.04722236 -5.02588478  3.0665592 ])=1.001374621057579
# f([ 3.04633679 -5.02539936  3.06531101])=1.0013235476655495
# f([ 3.04546783 -5.02492305  3.06408622])=1.0012743718811237
# f([ 3.04461517 -5.02445566  3.06288441])=1.0012270231995188
# f([ 3.0437785  -5.02399704  3.06170513])=1.0011814337356668
# f([ 3.04295751 -5.02354702  3.06054797])=1.0011375381267555
# f([ 3.04215193 -5.02310545  3.0594125 ])=1.0010952734382386
# f([ 3.04136145 -5.02267215  3.05829834])=1.0010545790742498
# f([ 3.04058579 -5.02224697  3.05720506])=1.0010153966899509
# f([ 3.03982468 -5.02182977  3.05613229])=1.0009776701084832
# f([ 3.03907785 -5.0214204   3.05507963])=1.0009413452402782
# f([ 3.03834501 -5.0210187   3.05404672])=1.0009063700052678
# f([ 3.03762593 -5.02062453  3.05303318])=1.0008726942584474
# f([ 3.03692032 -5.02023776  3.05203864])=1.0008402697180543
# f([ 3.03622795 -5.01985824  3.05106275])=1.00080904989602
# f([ 3.03554857 -5.01948583  3.05010517])=1.0007789900316766
# f([ 3.03488192 -5.01912041  3.04916554])=1.0007500470272959
# f([ 3.03422778 -5.01876185  3.04824354])=1.0007221793865
# f([ 3.0335859  -5.01841     3.04733882])=1.0006953471545899
# f([ 3.03295606 -5.01806476  3.04645107])=1.0006695118615028
# f([ 3.03233803 -5.01772599  3.04557997])=1.0006446364664612
# f([ 3.03173159 -5.01739357  3.0447252 ])=1.0006206853049946
# f([ 3.03113653 -5.01706739  3.04388647])=1.0005976240374252
# f([ 3.03055262 -5.01674732  3.04306346])=1.0005754196003664
# f([ 3.02997966 -5.01643326  3.04225589])=1.0005540401586188
# f([ 3.02941745 -5.01612508  3.04146346])=1.0005334550598945
# f([ 3.02886578 -5.01582269  3.04068589])=1.0005136347905932
# f([ 3.02832446 -5.01552596  3.0399229 ])=1.0004945509340928
# f([ 3.02779329 -5.0152348   3.03917422])=1.0004761761291263
# f([ 3.02727208 -5.0149491   3.03843958])=1.0004584840314266
# f([ 3.02676064 -5.01466876  3.03771872])=1.000441449275172
# f([ 3.0262588  -5.01439368  3.03701138])=1.0004250474370906
# f([ 3.02576636 -5.01412375  3.0363173 ])=1.000409255001557
# f([ 3.02528317 -5.01385889  3.03563624])=1.000394049326502
# f([ 3.02480903 -5.01359899  3.03496795])=1.0003794086110815
# f([ 3.02434378 -5.01334397  3.03431219])=1.0003653118644138
# f([ 3.02388726 -5.01309373  3.03366873])=1.0003517388757075
# f([ 3.0234393  -5.01284818  3.03303734])=1.0003386701849877
# f([ 3.02299974 -5.01260723  3.03241779])=1.0003260870551571
# f([ 3.02256842 -5.01237081  3.03180985])=1.000313971445678
# f([ 3.0221452  -5.01213882  3.03121332])=1.000302305985798
# f([ 3.0217299  -5.01191118  3.03062797])=1.0002910739505353
# f([ 3.0213224  -5.01168781  3.0300536 ])=1.0002802592362627
# f([ 3.02092254 -5.01146862  3.02949   ])=1.0002698463375452
# f([ 3.02053018 -5.01125355  3.02893698])=1.0002598203251551
# f([ 3.02014517 -5.01104251  3.02839432])=1.0002501668244008
# f([ 3.01976739 -5.01083543  3.02786184])=1.0002408719949898
# f([ 3.01939669 -5.01063223  3.02733934])=1.000231922510494
# f([ 3.01903294 -5.01043285  3.02682664])=1.0002233055398477
# f([ 3.01867601 -5.0102372   3.02632356])=1.0002150087286168
# f([ 3.01832578 -5.01004522  3.02582991])=1.0002070201815059
# f([ 3.01798212 -5.00985684  3.02534552])=1.0001993284450634
# f([ 3.0176449  -5.00967199  3.02487021])=1.0001919224913536
# f([ 3.017314   -5.00949061  3.02440382])=1.000184791702452
# f([ 3.01698931 -5.00931264  3.02394617])=1.0001779258545866
# f([ 3.01667071 -5.00913799  3.02349711])=1.0001713151039837
# f([ 3.01635808 -5.00896663  3.02305646])=1.000164949972799
# f([ 3.01605131 -5.00879848  3.02262408])=1.000158821334935
# f([ 3.0157503  -5.00863348  3.02219981])=1.0001529204036643
# f([ 3.01545493 -5.00847157  3.0217835 ])=1.0001472387187391
# f([ 3.01516511 -5.00831271  3.02137499])=1.0001417681341707
# f([ 3.01488071 -5.00815682  3.02097414])=1.0001365008064624
# f([ 3.01460165 -5.00800385  3.02058081])=1.0001314291839094
# f([ 3.01432783 -5.00785375  3.02019486])=1.0001265459950304
# f([ 3.01405914 -5.00770647  3.01981614])=1.0001218442387483
# f([ 3.01379548 -5.00756195  3.01944453])=1.000117317173931
# f([ 3.01353678 -5.00742014  3.01907988])=1.0001129583100976
# f([ 3.01328292 -5.00728099  3.01872207])=1.0001087613977973
# f([ 3.01303382 -5.00714445  3.01837098])=1.0001047204197562
# f([ 3.0127894  -5.00701047  3.01802646])=1.0001008295822942
# f([ 3.01254956 -5.006879    3.01768841])=1.0000970833070824
# f([ 3.01231421 -5.00675     3.0173567 ])=1.0000934762229576
# f([ 3.01208329 -5.00662341  3.01703121])=1.0000900031583342
# f([ 3.01185669 -5.0064992   3.01671182])=1.0000866591337996
# f([ 3.01163434 -5.00637732  3.01639842])=1.0000834393548246
# f([ 3.01141616 -5.00625773  3.0160909 ])=1.0000803392052688
# f([ 3.01120207 -5.00614038  3.01578915])=1.0000773542402612
# f([ 3.01099199 -5.00602523  3.01549305])=1.0000744801802455
# f([ 3.01078586 -5.00591224  3.01520251])=1.0000717129045427
# f([ 3.01058359 -5.00580136  3.01491741])=1.0000690484455959
# f([ 3.01038512 -5.00569257  3.01463767])=1.0000664829835273
# f([ 3.01019036 -5.00558582  3.01436316])=1.000064012839772
# f([ 3.00999926 -5.00548106  3.01409381])=1.0000616344731839
# f([ 3.00981175 -5.00537828  3.01382951])=1.0000593444736268
# f([ 3.00962775 -5.00527742  3.01357016])=1.0000571395578959
# f([ 3.0094472  -5.00517845  3.01331568])=1.0000550165647724
# f([ 3.00927003 -5.00508134  3.01306597])=1.0000529724504474
# f([ 3.00909619 -5.00498605  3.01282094])=1.0000510042842166
# f([ 3.00892561 -5.00489254  3.01258051])=1.0000491092443156
# f([ 3.00875822 -5.00480079  3.01234459])=1.0000472846136859
# f([ 3.00859398 -5.00471076  3.01211309])=1.0000455277763365
# f([ 3.00843282 -5.00462242  3.01188593])=1.0000438362133934
# f([ 3.00827468 -5.00453574  3.01166303])=1.0000422074997317
# f([ 3.0081195  -5.00445068  3.01144431])=1.0000406393002237
# f([ 3.00796723 -5.00436721  3.0112297 ])=1.0000391293662716
# f([ 3.00781782 -5.00428532  3.0110191 ])=1.0000376755332923
# f([ 3.00767121 -5.00420495  3.01081246])=1.0000362757167238
# f([ 3.00752736 -5.0041261   3.01060969])=1.000034927909752
# f([ 3.00738619 -5.00404872  3.01041073])=1.0000336301798995
# f([ 3.00724768 -5.00397279  3.0102155 ])=1.0000323806665108
# f([ 3.00711176 -5.00389829  3.01002392])=1.0000311775782507
# f([ 3.0069784  -5.00382519  3.00983594])=1.0000300191900635
# f([ 3.00684753 -5.00375345  3.00965149])=1.000028903841411
# f([ 3.00671912 -5.00368306  3.00947049])=1.0000278299328897
# f([ 3.00659311 -5.00361399  3.00929289])=1.0000267959249953
# f([ 3.00646947 -5.00354622  3.00911862])=1.0000258003351519
# f([ 3.00634815 -5.00347972  3.00894762])=1.0000248417359217
# f([ 3.0062291  -5.00341446  3.00877982])=1.0000239187530298
# f([ 3.00611229 -5.00335043  3.00861518])=1.0000230300631188
# f([ 3.00599766 -5.0032876   3.00845361])=1.0000221743920577
# f([ 3.00588519 -5.00322595  3.00829508])=1.0000213505130233
# f([ 3.00577482 -5.00316545  3.00813952])=1.0000205572448664
# f([ 3.00566653 -5.00310609  3.00798688])=1.0000197934502637
# f([ 3.00556026 -5.00304784  3.0078371 ])=1.0000190580339563
# f([ 3.00545599 -5.00299068  3.00769013])=1.0000183499417972
# f([ 3.00535367 -5.0029346   3.00754592])=1.0000176681584207
# f([ 3.00525327 -5.00287957  3.00740441])=1.0000170117064044
# f([ 3.00515476 -5.00282556  3.00726556])=1.000016379644535
# f([ 3.00505809 -5.00277258  3.0071293 ])=1.0000157710666144
# f([ 3.00496324 -5.00272058  3.00699561])=1.000015185100196
# f([ 3.00487016 -5.00266956  3.00686442])=1.0000146209050058
# f([ 3.00477883 -5.0026195   3.00673569])=1.0000140776722048
# f([ 3.00468921 -5.00257038  3.00660937])=1.0000135546229671
# f([ 3.00460127 -5.00252217  3.00648543])=1.0000130510074143
# f([ 3.00451499 -5.00247488  3.00636381])=1.0000125661034076
# f([ 3.00443032 -5.00242846  3.00624446])=1.0000120992158088
# f([ 3.00434723 -5.00238292  3.00612736])=1.0000116496752156
# f([ 3.00426571 -5.00233824  3.00601245])=1.0000112168370805
# f([ 3.00418571 -5.00229439  3.0058997 ])=1.0000108000808297
# f([ 3.00410722 -5.00225136  3.00578906])=1.0000103988089535
# f([ 3.0040302  -5.00220914  3.0056805 ])=1.000010012446154
# f([ 3.00395462 -5.00216771  3.00557397])=1.000009640438492
# f([ 3.00388046 -5.00212706  3.00546945])=1.0000092822525346
# f([ 3.00380769 -5.00208717  3.00536688])=1.0000089373749006
# f([ 3.00373628 -5.00204803  3.00526623])=1.0000086053109953
# f([ 3.00366621 -5.00200962  3.00516747])=1.0000082855847268
# f([ 3.00359746 -5.00197194  3.00507057])=1.000007977737738
# f([ 3.00353    -5.00193496  3.00497548])=1.0000076813286967
# f([ 3.0034638  -5.00189867  3.00488217])=1.0000073959325846
# f([ 3.00339884 -5.00186306  3.00479062])=1.0000071211402144
# f([ 3.0033351  -5.00182813  3.00470078])=1.0000068565576754
# f([ 3.00327256 -5.00179384  3.00461262])=1.0000066018054383
# f([ 3.00321119 -5.0017602   3.00452612])=1.0000063565185542
# f([ 3.00315097 -5.00172719  3.00444124])=1.000006120345148
# f([ 3.00309188 -5.0016948   3.00435796])=1.0000058929466036
# f([ 3.0030339  -5.00166302  3.00427623])=1.000005673996995
# f([ 3.002977   -5.00163183  3.00419604])=1.000005463182319
# f([ 3.00292117 -5.00160123  3.00411735])=1.0000052602003535
# f([ 3.00286639 -5.0015712   3.00404014])=1.0000050647601597
# f([ 3.00281264 -5.00154174  3.00396437])=1.0000048765813858
# f([ 3.00275989 -5.00151283  3.00389003])=1.0000046953943524
# f([ 3.00270814 -5.00148446  3.00381708])=1.000004520939143
# f([ 3.00265735 -5.00145662  3.00374549])=1.0000043529657887
# f([ 3.00260752 -5.0014293   3.00367526])=1.000004191233458
# f([ 3.00255862 -5.0014025   3.00360633])=1.0000040355101874
# f([ 3.00251064 -5.0013762   3.0035387 ])=1.0000038855727382
# f([ 3.00246355 -5.00135039  3.00347234])=1.0000037412060578
# f([ 3.00241735 -5.00132506  3.00340722])=1.0000036022033783
# f([ 3.00237202 -5.00130022  3.00334333])=1.0000034683652501
# f([ 3.00232754 -5.00127583  3.00328063])=1.0000033394997274
# f([ 3.00228389 -5.00125191  3.00321911])=1.0000032154222254
# f([ 3.00224106 -5.00122843  3.00315874])=1.0000030959546962
# f([ 3.00219903 -5.00120539  3.0030995 ])=1.0000029809260127
# f([ 3.00215779 -5.00118279  3.00304138])=1.000002870171059
# f([ 3.00211733 -5.00116061  3.00298434])=1.0000027635313415
# f([ 3.00207762 -5.00113884  3.00292838])=1.0000026608535961
# f([ 3.00203866 -5.00111749  3.00287346])=1.00000256199084
# f([ 3.00200043 -5.00109653  3.00281958])=1.000002466801277
# f([ 3.00196292 -5.00107597  3.0027667 ])=1.0000023751484832
# f([ 3.0019261  -5.00105579  3.00271482])=1.0000022869009513
# f([ 3.00188998 -5.00103599  3.0026639 ])=1.000002201932233
# f([ 3.00185454 -5.00101656  3.00261395])=1.0000021201204845
# f([ 3.00181976 -5.0009975   3.00256493])=1.0000020413484094
# f([ 3.00178564 -5.00097879  3.00251683])=1.0000019655030314
# f([ 3.00175215 -5.00096044  3.00246963])=1.0000018924757512
# f([ 3.00171929 -5.00094242  3.00242332])=1.000001822161721
# f([ 3.00168705 -5.00092475  3.00237787])=1.0000017544601576
# f([ 3.00165541 -5.00090741  3.00233328])=1.0000016892740575
# f([ 3.00162437 -5.00089039  3.00228952])=1.0000016265098282
# f([ 3.00159391 -5.00087369  3.00224659])=1.000001566077728
# f([ 3.00156402 -5.00085731  3.00220446])=1.000001507890758
# f([ 3.00153469 -5.00084123  3.00216312])=1.0000014518658276
# f([ 3.00150591 -5.00082546  3.00212255])=1.0000013979224605
# f([ 3.00147766 -5.00080998  3.00208275])=1.0000013459832928
# f([ 3.00144995 -5.00079479  3.00204369])=1.0000012959738882
# f([ 3.00142276 -5.00077988  3.00200536])=1.000001247822638
# f([ 3.00139608 -5.00076526  3.00196776])=1.0000012014603783
# f([ 3.0013699  -5.00075091  3.00193085])=1.000001156820673
# f([ 3.00134421 -5.00073683  3.00189465])=1.0000011138395593
# f([ 3.001319   -5.00072301  3.00185911])=1.0000010724553619
# f([ 3.00129427 -5.00070945  3.00182425])=1.0000010326087931
# f([ 3.00127    -5.00069614  3.00179004])=1.0000009942426829
# f([ 3.00124618 -5.00068309  3.00175647])=1.0000009573020918
# f([ 3.00122281 -5.00067028  3.00172353])=1.000000921733971
# f([ 3.00119988 -5.00065771  3.00169121])=1.0000008874874027
# f([ 3.00117738 -5.00064538  3.0016595 ])=1.0000008545132175
# f([ 3.0011553  -5.00063327  3.00162837])=1.0000008227642638
# f([ 3.00113363 -5.0006214   3.00159784])=1.0000007921947827
# f([ 3.00111237 -5.00060974  3.00156787])=1.0000007627612035
# f([ 3.00109151 -5.00059831  3.00153847])=1.0000007344210928
# f([ 3.00107104 -5.00058709  3.00150962])=1.0000007071340775
# f([ 3.00105096 -5.00057608  3.00148131])=1.0000006808608646
# f([ 3.00103125 -5.00056528  3.00145353])=1.0000006555637526
# f([ 3.00101191 -5.00055468  3.00142627])=1.0000006312066603
# f([ 3.00099293 -5.00054427  3.00139952])=1.0000006077544725
# f([ 3.00097431 -5.00053407  3.00137328])=1.0000005851736091
# f([ 3.00095604 -5.00052405  3.00134753])=1.000000563431783
# f([ 3.00093811 -5.00051422  3.00132226])=1.0000005424977445
# f([ 3.00092052 -5.00050458  3.00129746])=1.0000005223414519
# f([ 3.00090326 -5.00049512  3.00127313])=1.0000005029341423
# f([ 3.00088632 -5.00048583  3.00124925])=1.0000004842478205
# f([ 3.0008697  -5.00047672  3.00122583])=1.000000466255898
# f([ 3.00085339 -5.00046778  3.00120284])=1.000000448932326
# f([ 3.00083738 -5.00045901  3.00118028])=1.0000004322524774
# f([ 3.00082168 -5.0004504   3.00115815])=1.00000041619235
# f([ 3.00080627 -5.00044196  3.00113643])=1.0000004007289363
# f([ 3.00079115 -5.00043367  3.00111512])=1.0000003858400248
# f([ 3.00077632 -5.00042553  3.0010942 ])=1.0000003715043135
# f([ 3.00076176 -5.00041755  3.00107368])=1.0000003577012535
# f([ 3.00074747 -5.00040972  3.00105355])=1.0000003444110064
# f([ 3.00073345 -5.00040204  3.00103379])=1.0000003316145722
# f([ 3.0007197  -5.0003945   3.00101441])=1.0000003192936333
# f([ 3.0007062  -5.0003871   3.00099538])=1.0000003074304544
# f([ 3.00069296 -5.00037984  3.00097672])=1.0000002960079826
# f([ 3.00067996 -5.00037272  3.0009584 ])=1.0000002850099463
# f([ 3.00066721 -5.00036573  3.00094043])=1.000000274420529
# f([ 3.0006547  -5.00035887  3.00092279])=1.0000002642246102
# f([ 3.00064242 -5.00035214  3.00090549])=1.0000002544074391
# f([ 3.00063038 -5.00034554  3.0008885 ])=1.0000002449550607
# f([ 3.00061855 -5.00033906  3.00087184])=1.0000002358538325
# f([ 3.00060695 -5.0003327   3.00085549])=1.0000002270908368
# f([ 3.00059557 -5.00032646  3.00083945])=1.000000218653355
# f([ 3.0005844  -5.00032034  3.00082371])=1.0000002105293788
# f([ 3.00057344 -5.00031433  3.00080826])=1.0000002027072696
# f([ 3.00056269 -5.00030844  3.0007931 ])=1.0000001951757582
# f([ 3.00055214 -5.00030265  3.00077823])=1.0000001879241154
# f([ 3.00054178 -5.00029698  3.00076364])=1.0000001809419246
# f([ 3.00053162 -5.00029141  3.00074932])=1.0000001742190818
# f([ 3.00052165 -5.00028594  3.00073526])=1.0000001677460943
# f([ 3.00051187 -5.00028058  3.00072147])=1.0000001615135545
# f([ 3.00050227 -5.00027532  3.00070794])=1.0000001555125948
# f([ 3.00049285 -5.00027016  3.00069467])=1.0000001497346034
# f([ 3.00048361 -5.00026509  3.00068164])=1.000000144171267
# f([ 3.00047454 -5.00026012  3.00066886])=1.0000001388146984
# f([ 3.00046564 -5.00025524  3.00065632])=1.0000001336570676
# f([ 3.00045691 -5.00025045  3.00064401])=1.0000001286911413
# f([ 3.00044834 -5.00024576  3.00063193])=1.000000123909615
# f([ 3.00043993 -5.00024115  3.00062008])=1.0000001193058665
# f([ 3.00043168 -5.00023663  3.00060845])=1.0000001148730746
# f([ 3.00042359 -5.00023219  3.00059704])=1.0000001106050291
# f([ 3.00041564 -5.00022783  3.00058584])=1.0000001064955484
# f([ 3.00040785 -5.00022356  3.00057486])=1.0000001025387633
# f([ 3.0004002  -5.00021937  3.00056408])=1.0000000987290179
# f([ 3.0003927  -5.00021526  3.0005535 ])=1.0000000950607415
# f([ 3.00038533 -5.00021122  3.00054312])=1.0000000915287899
# f([ 3.00037811 -5.00020726  3.00053293])=1.0000000881281608
# f([ 3.00037102 -5.00020337  3.00052294])=1.0000000848537383
# f([ 3.00036406 -5.00019956  3.00051313])=1.000000081701046
# f([ 3.00035723 -5.00019581  3.00050351])=1.0000000786654653
# f([ 3.00035053 -5.00019214  3.00049407])=1.0000000757427188
# f([ 3.00034396 -5.00018854  3.0004848 ])=1.0000000729285148
# f([ 3.00033751 -5.000185    3.00047571])=1.0000000702189027
# f([ 3.00033118 -5.00018153  3.00046679])=1.0000000676099319
# f([ 3.00032497 -5.00017813  3.00045804])=1.0000000650979501
# f([ 3.00031887 -5.00017479  3.00044945])=1.0000000626793053
# f([ 3.00031289 -5.00017151  3.00044102])=1.0000000603504304
# f([ 3.00030703 -5.0001683   3.00043275])=1.000000058108128
# f([ 3.00030127 -5.00016514  3.00042463])=1.0000000559491298
# f([ 3.00029562 -5.00016204  3.00041667])=1.0000000538704086
# f([ 3.00029007 -5.000159    3.00040886])=1.0000000518689092
# f([ 3.00028463 -5.00015602  3.00040119])=1.0000000499417183
# f([ 3.0002793  -5.0001531   3.00039366])=1.0000000480861502
# f([ 3.00027406 -5.00015022  3.00038628])=1.000000046299533
# f([ 3.00026892 -5.00014741  3.00037904])=1.0000000445792239
# f([ 3.00026388 -5.00014464  3.00037193])=1.0000000429230056
# f([ 3.00025893 -5.00014193  3.00036496])=1.0000000413281782
# f([ 3.00025407 -5.00013927  3.00035811])=1.000000039792667
# f([ 3.00024931 -5.00013666  3.0003514 ])=1.0000000383141696
# f([ 3.00024463 -5.00013409  3.00034481])=1.0000000368906399
# f([ 3.00024004 -5.00013158  3.00033834])=1.000000035519946
# f([ 3.00023554 -5.00012911  3.00033199])=1.0000000342002409
# f([ 3.00023113 -5.00012669  3.00032577])=1.0000000329295489
# f([ 3.00022679 -5.00012432  3.00031966])=1.0000000317060653
# f([ 3.00022254 -5.00012198  3.00031367])=1.000000030528028
# f([ 3.00021837 -5.0001197   3.00030778])=1.0000000293937603
# f([ 3.00021427 -5.00011745  3.00030201])=1.0000000283016846
# f([ 3.00021025 -5.00011525  3.00029635])=1.0000000272501808
# f([ 3.00020631 -5.00011309  3.00029079])=1.0000000262376432
# f([ 3.00020244 -5.00011097  3.00028534])=1.0000000252628354
# f([ 3.00019864 -5.00010889  3.00027999])=1.00000002432418
# f([ 3.00019492 -5.00010684  3.00027474])=1.000000023420455
# f([ 3.00019126 -5.00010484  3.00026958])=1.0000000225502674
# f([ 3.00018768 -5.00010287  3.00026453])=1.0000000217124239
# f([ 3.00018416 -5.00010095  3.00025957])=1.0000000209056736
# f([ 3.0001807  -5.00009905  3.0002547 ])=1.0000000201289936
# f([ 3.00017731 -5.00009719  3.00024992])=1.0000000193811047
# f([ 3.00017399 -5.00009537  3.00024524])=1.0000000186609839
# f([ 3.00017073 -5.00009358  3.00024064])=1.0000000179677215
# f([ 3.00016753 -5.00009183  3.00023612])=1.0000000173000814
# f([ 3.00016438 -5.00009011  3.0002317 ])=1.0000000166572818
# f([ 3.0001613  -5.00008842  3.00022735])=1.000000016038399
# f([ 3.00015828 -5.00008676  3.00022309])=1.0000000154425095
# f([ 3.00015531 -5.00008513  3.0002189 ])=1.000000014868732
# f([ 3.0001524  -5.00008354  3.0002148 ])=1.000000014316356
# f([ 3.00014954 -5.00008197  3.00021077])=1.000000013784387
# f([ 3.00014673 -5.00008043  3.00020682])=1.000000013272242
# f([ 3.00014398 -5.00007892  3.00020294])=1.0000000127791395
# f([ 3.00014128 -5.00007744  3.00019913])=1.000000012304298
# f([ 3.00013863 -5.00007599  3.0001954 ])=1.0000000118471206
# f([ 3.00013603 -5.00007457  3.00019174])=1.0000000114069394
# f([ 3.00013348 -5.00007317  3.00018814])=1.0000000109831149
# f([ 3.00013098 -5.0000718   3.00018461])=1.0000000105751212
# f([ 3.00012852 -5.00007045  3.00018115])=1.0000000101821627
# f([ 3.00012611 -5.00006913  3.00017775])=1.0000000098038555
# f([ 3.00012375 -5.00006783  3.00017442])=1.0000000094396455
# f([ 3.00012143 -5.00006656  3.00017115])=1.0000000090888932
# f([ 3.00011915 -5.00006531  3.00016794])=1.000000008751158
# f([ 3.00011691 -5.00006409  3.00016479])=1.0000000084260279
# f([ 3.00011472 -5.00006288  3.0001617 ])=1.0000000081130054
# f([ 3.00011257 -5.00006171  3.00015867])=1.0000000078115363
# f([ 3.00011046 -5.00006055  3.00015569])=1.0000000075212938
# f([ 3.00010839 -5.00005941  3.00015277])=1.0000000072417947
# f([ 3.00010636 -5.0000583   3.00014991])=1.0000000069727548
# f([ 3.00010436 -5.00005721  3.0001471 ])=1.0000000067137194
# f([ 3.0001024  -5.00005613  3.00014434])=1.0000000064642762
# f([ 3.00010048 -5.00005508  3.00014163])=1.0000000062240986
# f([ 3.0000986  -5.00005405  3.00013897])=1.0000000059928311
# f([ 3.00009675 -5.00005303  3.00013637])=1.0000000057701754
# f([ 3.00009494 -5.00005204  3.00013381])=1.0000000055557905
# f([ 3.00009316 -5.00005106  3.0001313 ])=1.0000000053493636
# f([ 3.00009141 -5.00005011  3.00012884])=1.0000000051505822
# f([ 3.00008969 -5.00004917  3.00012642])=1.0000000049592757
# f([ 3.00008801 -5.00004824  3.00012405])=1.000000004774975
# f([ 3.00008636 -5.00004734  3.00012173])=1.000000004597581
# f([ 3.00008474 -5.00004645  3.00011944])=1.000000004426738
# f([ 3.00008315 -5.00004558  3.0001172 ])=1.0000000042623043
# f([ 3.00008159 -5.00004473  3.000115  ])=1.000000004103896
# f([ 3.00008006 -5.00004389  3.00011285])=1.0000000039514703
# f([ 3.00007856 -5.00004306  3.00011073])=1.000000003804658
# f([ 3.00007709 -5.00004226  3.00010866])=1.0000000036632457
# f([ 3.00007564 -5.00004146  3.00010662])=1.0000000035271626
# f([ 3.00007422 -5.00004069  3.00010462])=1.0000000033960816
# f([ 3.00007283 -5.00003992  3.00010266])=1.0000000032699177
# f([ 3.00007147 -5.00003917  3.00010073])=1.0000000031484433
# f([ 3.00007013 -5.00003844  3.00009884])=1.000000003031488
# f([ 3.00006881 -5.00003772  3.00009699])=1.00000000291881
# f([ 3.00006752 -5.00003701  3.00009517])=1.000000002810367
# f([ 3.00006625 -5.00003632  3.00009338])=1.0000000027059457
# f([ 3.00006501 -5.00003564  3.00009163])=1.000000002605418
# f([ 3.00006379 -5.00003497  3.00008992])=1.0000000025086422
# f([ 3.0000626  -5.00003431  3.00008823])=1.0000000024154048
# f([ 3.00006142 -5.00003367  3.00008657])=1.0000000023256916
# f([ 3.00006027 -5.00003304  3.00008495])=1.0000000022392896
# f([ 3.00005914 -5.00003242  3.00008336])=1.0000000021560709
# f([ 3.00005803 -5.00003181  3.00008179])=1.0000000020759359
# f([ 3.00005694 -5.00003121  3.00008026])=1.0000000019988136
# f([ 3.00005588 -5.00003063  3.00007876])=1.0000000019245618
# f([ 3.00005483 -5.00003005  3.00007728])=1.0000000018530386
# f([ 3.0000538  -5.00002949  3.00007583])=1.000000001784187
# f([ 3.00005279 -5.00002894  3.00007441])=1.000000001717865
# f([ 3.0000518  -5.00002839  3.00007301])=1.0000000016541009
# f([ 3.00005083 -5.00002786  3.00007164])=1.000000001592639
# f([ 3.00004988 -5.00002734  3.0000703 ])=1.0000000015334365
# f([ 3.00004894 -5.00002683  3.00006898])=1.0000000014764936
# f([ 3.00004802 -5.00002632  3.00006769])=1.0000000014215686
# f([ 3.00004712 -5.00002583  3.00006642])=1.000000001368818
# f([ 3.00004624 -5.00002535  3.00006517])=1.0000000013178862
# f([ 3.00004537 -5.00002487  3.00006395])=1.0000000012689725
# f([ 3.00004452 -5.0000244   3.00006275])=1.0000000012218209
# f([ 3.00004369 -5.00002395  3.00006157])=1.0000000011764314
# f([ 3.00004287 -5.0000235   3.00006042])=1.0000000011327188
# f([ 3.00004206 -5.00002306  3.00005929])=1.000000001090683
# f([ 3.00004127 -5.00002262  3.00005817])=1.0000000010501537
# f([ 3.0000405  -5.0000222   3.00005708])=1.0000000010111592
# f([ 3.00003974 -5.00002178  3.00005601])=1.0000000009735004
# f([ 3.000039   -5.00002137  3.00005496])=1.000000000937348
# f([ 3.00003826 -5.00002097  3.00005393])=1.000000000902503
# f([ 3.00003755 -5.00002058  3.00005292])=1.0000000008689938
# f([ 3.00003684 -5.00002019  3.00005193])=1.0000000008367351
# f([ 3.00003615 -5.00001982  3.00005095])=1.0000000008056134
# f([ 3.00003547 -5.00001944  3.00005   ])=1.0000000007756853
# f([ 3.00003481 -5.00001908  3.00004906])=1.0000000007468515
# f([ 3.00003416 -5.00001872  3.00004814])=1.0000000007191545
# f([ 3.00003351 -5.00001837  3.00004724])=1.0000000006923955
# f([ 3.00003289 -5.00001803  3.00004635])=1.0000000006666596
# f([ 3.00003227 -5.00001769  3.00004548])=1.0000000006419327
# f([ 3.00003166 -5.00001736  3.00004463])=1.0000000006180727
# f([ 3.00003107 -5.00001703  3.00004379])=1.0000000005950795
# f([ 3.00003049 -5.00001671  3.00004297])=1.0000000005729817
# f([ 3.00002992 -5.0000164   3.00004217])=1.0000000005517222
# f([ 3.00002936 -5.00001609  3.00004138])=1.0000000005312017
# f([ 3.0000288  -5.00001579  3.0000406 ])=1.000000000511477
# f([ 3.00002826 -5.00001549  3.00003984])=1.0000000004925198
# f([ 3.00002773 -5.0000152   3.00003909])=1.0000000004741878
# f([ 3.00002721 -5.00001492  3.00003836])=1.0000000004565095
# f([ 3.0000267  -5.00001464  3.00003764])=1.000000000439627
# f([ 3.0000262  -5.00001436  3.00003693])=1.000000000423256
# f([ 3.00002571 -5.00001409  3.00003624])=1.000000000407482
# f([ 3.00002523 -5.00001383  3.00003556])=1.0000000003923617
# f([ 3.00002476 -5.00001357  3.00003489])=1.0000000003777814
# f([ 3.00002429 -5.00001332  3.00003424])=1.0000000003637126
# f([ 3.00002384 -5.00001307  3.0000336 ])=1.0000000003502834
# f([ 3.00002339 -5.00001282  3.00003297])=1.000000000337252
# f([ 3.00002295 -5.00001258  3.00003235])=1.0000000003246896
# f([ 3.00002252 -5.00001234  3.00003174])=1.0000000003126672
# f([ 3.0000221  -5.00001211  3.00003115])=1.000000000300986
# f([ 3.00002168 -5.00001189  3.00003056])=1.000000000289802
# f([ 3.00002128 -5.00001166  3.00002999])=1.0000000002790443
# f([ 3.00002088 -5.00001144  3.00002943])=1.0000000002687273
# f([ 3.00002049 -5.00001123  3.00002888])=1.0000000002587655
# f([ 3.0000201  -5.00001102  3.00002833])=1.0000000002490879
# f([ 3.00001973 -5.00001081  3.0000278 ])=1.0000000002399076
# f([ 3.00001936 -5.00001061  3.00002728])=1.000000000230969
# f([ 3.00001899 -5.00001041  3.00002677])=1.0000000002223288
# f([ 3.00001864 -5.00001022  3.00002627])=1.0000000002140723
# f([ 3.00001829 -5.00001002  3.00002578])=1.0000000002061853
# f([ 3.00001794 -5.00000984  3.00002529])=1.0000000001984972
# f([ 3.00001761 -5.00000965  3.00002482])=1.0000000001911076
# f([ 3.00001728 -5.00000947  3.00002435])=1.0000000001840448
# f([ 3.00001695 -5.00000929  3.0000239 ])=1.0000000001771525
# f([ 3.00001664 -5.00000912  3.00002345])=1.0000000001705587
# f([ 3.00001632 -5.00000895  3.00002301])=1.0000000001641922
# f([ 3.00001602 -5.00000878  3.00002258])=1.0000000001581526
# f([ 3.00001572 -5.00000862  3.00002215])=1.0000000001523404
# f([ 3.00001542 -5.00000845  3.00002174])=1.0000000001466276
# f([ 3.00001513 -5.0000083   3.00002133])=1.0000000001411706
# f([ 3.00001485 -5.00000814  3.00002093])=1.000000000135941
# f([ 3.00001457 -5.00000799  3.00002054])=1.0000000001308251
# f([ 3.0000143  -5.00000784  3.00002015])=1.0000000001260219
# f([ 3.00001403 -5.00000769  3.00001977])=1.0000000001213323
# f([ 3.00001377 -5.00000755  3.0000194 ])=1.0000000001168132
# f([ 3.00001351 -5.0000074   3.00001904])=1.0000000001125215
# f([ 3.00001325 -5.00000727  3.00001868])=1.0000000001083151
# f([ 3.00001301 -5.00000713  3.00001833])=1.000000000104336
# f([ 3.00001276 -5.000007    3.00001799])=1.0000000001003855
# f([ 3.00001252 -5.00000686  3.00001765])=1.0000000000966622
# f([ 3.00001229 -5.00000674  3.00001732])=1.0000000000930527
# f([ 3.00001206 -5.00000661  3.000017  ])=1.000000000089642
# f([ 3.00001183 -5.00000649  3.00001668])=1.0000000000862883
# f([ 3.00001161 -5.00000636  3.00001636])=1.000000000083105
# f([ 3.00001139 -5.00000624  3.00001606])=1.0000000000799787
# f([ 3.00001118 -5.00000613  3.00001576])=1.0000000000770228
# f([ 3.00001097 -5.00000601  3.00001546])=1.0000000000741522
# f([ 3.00001076 -5.0000059   3.00001517])=1.0000000000713953
# f([ 3.00001056 -5.00000579  3.00001489])=1.0000000000687805
# f([ 3.00001036 -5.00000568  3.00001461])=1.0000000000662084
# f([ 3.00001017 -5.00000557  3.00001433])=1.00000000006375
# f([ 3.00000998 -5.00000547  3.00001406])=1.0000000000613198
# f([ 3.00000979 -5.00000537  3.0000138 ])=1.0000000000590603
# f([ 3.00000961 -5.00000527  3.00001354])=1.0000000000569287
# f([ 3.00000943 -5.00000517  3.00001329])=1.0000000000547686
# f([ 3.00000925 -5.00000507  3.00001304])=1.0000000000527933
# f([ 3.00000908 -5.00000498  3.00001279])=1.0000000000508322
# f([ 3.00000891 -5.00000488  3.00001255])=1.0000000000488853
# f([ 3.00000874 -5.00000479  3.00001232])=1.0000000000470948
# f([ 3.00000858 -5.0000047   3.00001209])=1.0000000000453326
# f([ 3.00000841 -5.00000461  3.00001186])=1.0000000000436842
# f([ 3.00000826 -5.00000453  3.00001164])=1.0000000000420073
# f([ 3.0000081  -5.00000444  3.00001142])=1.0000000000404725
# f([ 3.00000795 -5.00000436  3.00001121])=1.0000000000389377
# f([ 3.0000078  -5.00000428  3.000011  ])=1.0000000000375735
# f([ 3.00000765 -5.0000042   3.00001079])=1.0000000000361524
# f([ 3.00000751 -5.00000412  3.00001059])=1.0000000000347598
# f([ 3.00000737 -5.00000404  3.00001039])=1.0000000000334524
# f([ 3.00000723 -5.00000396  3.00001019])=1.0000000000322729
# f([ 3.0000071  -5.00000389  3.00001   ])=1.000000000031065
# f([ 3.00000696 -5.00000382  3.00000982])=1.0000000000299565
# f([ 3.00000683 -5.00000375  3.00000963])=1.0000000000287628
# f([ 3.0000067  -5.00000368  3.00000945])=1.0000000000276827
# f([ 3.00000658 -5.00000361  3.00000927])=1.0000000000266738
# f([ 3.00000646 -5.00000354  3.0000091 ])=1.0000000000257216
# f([ 3.00000633 -5.00000347  3.00000893])=1.0000000000247269
# f([ 3.00000622 -5.00000341  3.00000876])=1.000000000023789
# f([ 3.0000061  -5.00000334  3.0000086 ])=1.0000000000229363
# f([ 3.00000598 -5.00000328  3.00000844])=1.0000000000220837
# f([ 3.00000587 -5.00000322  3.00000828])=1.0000000000212594
# f([ 3.00000576 -5.00000316  3.00000812])=1.0000000000204636
# f([ 3.00000565 -5.0000031   3.00000797])=1.0000000000197247
# f([ 3.00000555 -5.00000304  3.00000782])=1.0000000000190141
# f([ 3.00000544 -5.00000298  3.00000767])=1.0000000000182325
# f([ 3.00000534 -5.00000293  3.00000753])=1.0000000000175646
# f([ 3.00000524 -5.00000287  3.00000739])=1.0000000000168825
# f([ 3.00000514 -5.00000282  3.00000725])=1.000000000016314
# f([ 3.00000505 -5.00000277  3.00000711])=1.0000000000156604
# f([ 3.00000495 -5.00000271  3.00000698])=1.0000000000151488
# f([ 3.00000486 -5.00000266  3.00000685])=1.0000000000145803
# f([ 3.00000477 -5.00000261  3.00000672])=1.0000000000140403
# f([ 3.00000468 -5.00000256  3.0000066 ])=1.0000000000135572
# f([ 3.00000459 -5.00000252  3.00000647])=1.0000000000130171
# f([ 3.00000451 -5.00000247  3.00000635])=1.0000000000125056
# f([ 3.00000442 -5.00000242  3.00000623])=1.0000000000120508
# f([ 3.00000434 -5.00000238  3.00000611])=1.0000000000116245
# f([ 3.00000426 -5.00000233  3.000006  ])=1.0000000000111413
# f([ 3.00000418 -5.00000229  3.00000589])=1.0000000000106866
# f([ 3.0000041  -5.00000225  3.00000578])=1.0000000000103455
# f([ 3.00000402 -5.0000022   3.00000567])=1.0000000000099192
# f([ 3.00000395 -5.00000216  3.00000556])=1.0000000000095923
# f([ 3.00000387 -5.00000212  3.00000546])=1.0000000000092655
# f([ 3.0000038  -5.00000208  3.00000536])=1.0000000000089244
# f([ 3.00000373 -5.00000204  3.00000526])=1.0000000000085407
# f([ 3.00000366 -5.00000201  3.00000516])=1.0000000000082991
# f([ 3.00000359 -5.00000197  3.00000506])=1.000000000007958
# f([ 3.00000352 -5.00000193  3.00000496])=1.0000000000076739
# f([ 3.00000346 -5.00000189  3.00000487])=1.000000000007418
# f([ 3.00000339 -5.00000186  3.00000478])=1.000000000007077
# f([ 3.00000333 -5.00000182  3.00000469])=1.0000000000068354
# f([ 3.00000327 -5.00000179  3.0000046 ])=1.000000000006537
# f([ 3.0000032  -5.00000176  3.00000452])=1.0000000000063096
# f([ 3.00000314 -5.00000172  3.00000443])=1.0000000000060538
# f([ 3.00000309 -5.00000169  3.00000435])=1.0000000000058833
# f([ 3.00000303 -5.00000166  3.00000427])=1.000000000005656
# f([ 3.00000297 -5.00000163  3.00000419])=1.0000000000054285
# f([ 3.00000291 -5.0000016   3.00000411])=1.0000000000052296
# f([ 3.00000286 -5.00000157  3.00000403])=1.0000000000050306
# f([ 3.00000281 -5.00000154  3.00000396])=1.0000000000048885
# f([ 3.00000275 -5.00000151  3.00000388])=1.0000000000046043
# f([ 3.0000027  -5.00000148  3.00000381])=1.0000000000045333
# f([ 3.00000265 -5.00000145  3.00000374])=1.0000000000043627
# f([ 3.0000026  -5.00000143  3.00000367])=1.0000000000041211
# f([ 3.00000255 -5.0000014   3.0000036 ])=1.0000000000040217
# f([ 3.00000251 -5.00000137  3.00000353])=1.0000000000038654
# f([ 3.00000246 -5.00000135  3.00000346])=1.0000000000037232
# f([ 3.00000241 -5.00000132  3.0000034 ])=1.0000000000035527
# f([ 3.00000237 -5.0000013   3.00000334])=1.0000000000034674
# f([ 3.00000232 -5.00000127  3.00000327])=1.000000000003297
# f([ 3.00000228 -5.00000125  3.00000321])=1.0000000000032117
# f([ 3.00000224 -5.00000123  3.00000315])=1.0000000000030411
# f([ 3.00000219 -5.0000012   3.00000309])=1.0000000000029559
# f([ 3.00000215 -5.00000118  3.00000303])=1.0000000000028848
# f([ 3.00000211 -5.00000116  3.00000298])=1.000000000002757
# f([ 3.00000207 -5.00000114  3.00000292])=1.0000000000027
# f([ 3.00000203 -5.00000112  3.00000287])=1.0000000000025864
# f([ 3.000002   -5.00000109  3.00000281])=1.0000000000024443
# f([ 3.00000196 -5.00000107  3.00000276])=1.0000000000023874
# f([ 3.00000192 -5.00000105  3.00000271])=1.0000000000022737
# f([ 3.00000189 -5.00000103  3.00000266])=1.0000000000021316
# f([ 3.00000185 -5.00000101  3.00000261])=1.0000000000021032
# f([ 3.00000182 -5.000001    3.00000256])=1.0000000000020464
# f([ 3.00000178 -5.00000098  3.00000251])=1.000000000001961
# f([ 3.00000175 -5.00000096  3.00000246])=1.0000000000018758
# f([ 3.00000172 -5.00000094  3.00000242])=1.0000000000018048
# f([ 3.00000168 -5.00000092  3.00000237])=1.0000000000017621
# f([ 3.00000165 -5.00000091  3.00000233])=1.0000000000017053
# f([ 3.00000162 -5.00000089  3.00000228])=1.0000000000016485
# f([ 3.00000159 -5.00000087  3.00000224])=1.0000000000015348
# f([ 3.00000156 -5.00000086  3.0000022 ])=1.0000000000014495
# f([ 3.00000153 -5.00000084  3.00000216])=1.0000000000014353
# f([ 3.0000015  -5.00000082  3.00000212])=1.0000000000013927
# f([ 3.00000147 -5.00000081  3.00000208])=1.0000000000013074
# f([ 3.00000145 -5.00000079  3.00000204])=1.0000000000012648
# f([ 3.00000142 -5.00000078  3.000002  ])=1.0000000000011937
# f([ 3.00000139 -5.00000076  3.00000196])=1.0000000000012221
# f([ 3.00000137 -5.00000075  3.00000193])=1.0000000000011369
# f([ 3.00000134 -5.00000074  3.00000189])=1.00000000000108
# f([ 3.00000132 -5.00000072  3.00000186])=1.0000000000010658
# f([ 3.00000129 -5.00000071  3.00000182])=1.0000000000010232
# f([ 3.00000127 -5.00000069  3.00000179])=1.0000000000009663
# f([ 3.00000124 -5.00000068  3.00000175])=1.0000000000009948
# f([ 3.00000122 -5.00000067  3.00000172])=1.000000000000881
# f([ 3.0000012  -5.00000066  3.00000169])=1.000000000000881
# f([ 3.00000117 -5.00000064  3.00000166])=1.000000000000881
# f([ 3.00000115 -5.00000063  3.00000162])=1.0000000000008242
# f([ 3.00000113 -5.00000062  3.00000159])=1.0000000000007958
# f([ 3.00000111 -5.00000061  3.00000156])=1.0000000000007674
# f([ 3.00000109 -5.0000006   3.00000154])=1.0000000000006537
# f([ 3.00000107 -5.00000059  3.00000151])=1.0000000000006821
# f([ 3.00000105 -5.00000057  3.00000148])=1.0000000000006253
# f([ 3.00000103 -5.00000056  3.00000145])=1.0000000000006537
# f([ 3.00000101 -5.00000055  3.00000142])=1.0000000000006253
# f([ 3.00000099 -5.00000054  3.0000014 ])=1.0000000000005826
# f([ 3.00000097 -5.00000053  3.00000137])=1.0000000000006253
# f([ 3.00000095 -5.00000052  3.00000134])=1.00000000000054
# f([ 3.00000094 -5.00000051  3.00000132])=1.00000000000054
# f([ 3.00000092 -5.0000005   3.00000129])=1.00000000000054
# f([ 3.0000009  -5.00000049  3.00000127])=1.0000000000004832
# f([ 3.00000088 -5.00000048  3.00000125])=1.0000000000004832
# f([ 3.00000087 -5.00000048  3.00000122])=1.000000000000469
# f([ 3.00000085 -5.00000047  3.0000012 ])=1.0000000000004405
# f([ 3.00000084 -5.00000046  3.00000118])=1.0000000000004263
# f([ 3.00000082 -5.00000045  3.00000116])=1.0000000000004263
# f([ 3.0000008  -5.00000044  3.00000113])=1.000000000000398
# f([ 3.00000079 -5.00000043  3.00000111])=1.000000000000398
# f([ 3.00000077 -5.00000042  3.00000109])=1.0000000000003553
# f([ 3.00000076 -5.00000042  3.00000107])=1.000000000000398
# f([ 3.00000075 -5.00000041  3.00000105])=1.0000000000003837
# f([ 3.00000073 -5.0000004   3.00000103])=1.0000000000003268
# f([ 3.00000072 -5.00000039  3.00000101])=1.0000000000002842
# f([ 3.0000007  -5.00000039  3.00000099])=1.000000000000341
# f([ 3.00000069 -5.00000038  3.00000097])=1.0000000000002842
# f([ 3.00000068 -5.00000037  3.00000096])=1.0000000000003268
# f([ 3.00000067 -5.00000036  3.00000094])=1.0000000000002274
# f([ 3.00000065 -5.00000036  3.00000092])=1.00000000000027
# f([ 3.00000064 -5.00000035  3.0000009 ])=1.0000000000002274
# f([ 3.00000063 -5.00000034  3.00000089])=1.0000000000002558
# f([ 3.00000062 -5.00000034  3.00000087])=1.0000000000002842
# f([ 3.00000061 -5.00000033  3.00000085])=1.000000000000199
# f([ 3.00000059 -5.00000033  3.00000084])=1.0000000000002274
# f([ 3.00000058 -5.00000032  3.00000082])=1.0000000000001847
# f([ 3.00000057 -5.00000031  3.00000081])=1.0000000000002274
# f([ 3.00000056 -5.00000031  3.00000079])=1.0000000000002274
# f([ 3.00000055 -5.0000003   3.00000078])=1.0000000000001705
# f([ 3.00000054 -5.0000003   3.00000076])=1.0000000000001705
# f([ 3.00000053 -5.00000029  3.00000075])=1.000000000000199
# f([ 3.00000052 -5.00000029  3.00000073])=1.000000000000199
# f([ 3.00000051 -5.00000028  3.00000072])=1.0000000000001137
# f([ 3.0000005  -5.00000027  3.00000071])=1.0000000000000853
# f([ 3.00000049 -5.00000027  3.00000069])=1.000000000000128
# f([ 3.00000048 -5.00000026  3.00000068])=1.0000000000001705
# f([ 3.00000047 -5.00000026  3.00000067])=1.000000000000128
# f([ 3.00000046 -5.00000025  3.00000065])=1.000000000000142
# f([ 3.00000046 -5.00000025  3.00000064])=1.0000000000001705
# f([ 3.00000045 -5.00000025  3.00000063])=1.0000000000001137
# f([ 3.00000044 -5.00000024  3.00000062])=1.0000000000000853
# f([ 3.00000043 -5.00000024  3.00000061])=1.000000000000142
# f([ 3.00000042 -5.00000023  3.0000006 ])=1.0000000000001705
# f([ 3.00000041 -5.00000023  3.00000058])=1.000000000000142
# f([ 3.00000041 -5.00000022  3.00000057])=1.0000000000000853
# f([ 3.0000004  -5.00000022  3.00000056])=1.0000000000001137
# f([ 3.00000039 -5.00000021  3.00000055])=1.0000000000000853
# f([ 3.00000038 -5.00000021  3.00000054])=1.000000000000071
# f([ 3.00000038 -5.00000021  3.00000053])=1.0000000000001137
# f([ 3.00000037 -5.0000002   3.00000052])=1.0000000000000995
# f([ 3.00000036 -5.0000002   3.00000051])=1.0000000000000853
# f([ 3.00000036 -5.0000002   3.0000005 ])=1.0000000000000853
# f([ 3.00000035 -5.00000019  3.00000049])=1.0000000000000284
# f([ 3.00000034 -5.00000019  3.00000048])=1.0000000000000853
# f([ 3.00000034 -5.00000018  3.00000047])=1.0000000000000284
# f([ 3.00000033 -5.00000018  3.00000047])=1.0000000000000568
# f([ 3.00000032 -5.00000018  3.00000046])=1.0000000000000853
# f([ 3.00000032 -5.00000017  3.00000045])=1.0000000000000284
# f([ 3.00000031 -5.00000017  3.00000044])=1.0000000000000853
# f([ 3.00000031 -5.00000017  3.00000043])=1.0000000000000568
# f([ 3.0000003  -5.00000016  3.00000042])=1.000000000000071
# f([ 3.00000029 -5.00000016  3.00000042])=1.0000000000000284
# f([ 3.00000029 -5.00000016  3.00000041])=1.000000000000071
# f([ 3.00000028 -5.00000016  3.0000004 ])=1.0000000000000284
# f([ 3.00000028 -5.00000015  3.00000039])=1.0000000000000142
# f([ 3.00000027 -5.00000015  3.00000039])=1.0000000000000284
# f([ 3.00000027 -5.00000015  3.00000038])=1.0000000000000853
# f([ 3.00000026 -5.00000014  3.00000037])=1.0000000000000568
# f([ 3.00000026 -5.00000014  3.00000036])=1.0000000000000284
# f([ 3.00000025 -5.00000014  3.00000036])=1.0
# f([ 3.00000025 -5.00000014  3.00000035])=1.0000000000000284
# f([ 3.00000024 -5.00000013  3.00000034])=1.0000000000000426
# f([ 3.00000024 -5.00000013  3.00000034])=1.0
# f([ 3.00000024 -5.00000013  3.00000033])=1.0000000000000426
# f([ 3.00000023 -5.00000013  3.00000033])=1.0
# f([ 3.00000023 -5.00000012  3.00000032])=1.0000000000000568
# f([ 3.00000022 -5.00000012  3.00000031])=1.0000000000000568
# f([ 3.00000022 -5.00000012  3.00000031])=1.000000000000071
# f([ 3.00000021 -5.00000012  3.0000003 ])=1.0000000000000284
# f([ 3.00000021 -5.00000012  3.0000003 ])=1.0000000000000284
# f([ 3.00000021 -5.00000011  3.00000029])=1.0
# f([ 3.0000002  -5.00000011  3.00000028])=1.0000000000000284
# f([ 3.0000002  -5.00000011  3.00000028])=0.9999999999999858
# f([ 3.00000019 -5.00000011  3.00000027])=1.0000000000000568
# f([ 3.00000019 -5.0000001   3.00000027])=1.0000000000000568
# f([ 3.00000019 -5.0000001   3.00000026])=1.0000000000000142
# f([ 3.00000018 -5.0000001   3.00000026])=1.0000000000000284
# f([ 3.00000018 -5.0000001   3.00000025])=1.0000000000000426
# f([ 3.00000018 -5.0000001   3.00000025])=1.0000000000000568
# f([ 3.00000017 -5.0000001   3.00000024])=1.0000000000000568
# f([ 3.00000017 -5.00000009  3.00000024])=0.9999999999999716
# f([ 3.00000017 -5.00000009  3.00000024])=1.0
# f([ 3.00000016 -5.00000009  3.00000023])=1.0000000000000568
# f([ 3.00000016 -5.00000009  3.00000023])=1.0000000000000142
# f([ 3.00000016 -5.00000009  3.00000022])=1.0000000000000568
# f([ 3.00000015 -5.00000008  3.00000022])=1.0000000000000568
# f([ 3.00000015 -5.00000008  3.00000021])=1.0000000000000284
# f([ 3.00000015 -5.00000008  3.00000021])=0.9999999999999858
# f([ 3.00000015 -5.00000008  3.00000021])=1.0
# f([ 3.00000014 -5.00000008  3.0000002 ])=1.0000000000000142
# f([ 3.00000014 -5.00000008  3.0000002 ])=1.0000000000000853
# f([ 3.00000014 -5.00000008  3.00000019])=1.0000000000000284
# f([ 3.00000014 -5.00000007  3.00000019])=1.0000000000000284
# f([ 3.00000013 -5.00000007  3.00000019])=0.9999999999999858
# f([ 3.00000013 -5.00000007  3.00000018])=1.0000000000000284
# f([ 3.00000013 -5.00000007  3.00000018])=1.0000000000000284
# f([ 3.00000013 -5.00000007  3.00000018])=1.0000000000000568
# f([ 3.00000012 -5.00000007  3.00000017])=1.0
# f([ 3.00000012 -5.00000007  3.00000017])=1.0000000000000284
# f([ 3.00000012 -5.00000007  3.00000017])=1.0000000000000284
# f([ 3.00000012 -5.00000006  3.00000016])=1.0
# f([ 3.00000011 -5.00000006  3.00000016])=1.0000000000000142
# f([ 3.00000011 -5.00000006  3.00000016])=1.0
# f([ 3.00000011 -5.00000006  3.00000016])=1.0
# f([ 3.00000011 -5.00000006  3.00000015])=1.0000000000000853
# f([ 3.00000011 -5.00000006  3.00000015])=1.0
# f([ 3.0000001  -5.00000006  3.00000015])=0.9999999999999716
# f([ 3.0000001  -5.00000006  3.00000014])=1.0
# f([ 3.0000001  -5.00000005  3.00000014])=1.0000000000000284
# f([ 3.0000001  -5.00000005  3.00000014])=1.0000000000000284
# f([ 3.0000001  -5.00000005  3.00000014])=0.9999999999999716
# f([ 3.00000009 -5.00000005  3.00000013])=1.0000000000000426
# f([ 3.00000009 -5.00000005  3.00000013])=0.9999999999999716
# f([ 3.00000009 -5.00000005  3.00000013])=0.9999999999999716
# f([ 3.00000009 -5.00000005  3.00000013])=0.9999999999999716
# f([ 3.00000009 -5.00000005  3.00000012])=1.0
# f([ 3.00000009 -5.00000005  3.00000012])=1.0000000000000284
# f([ 3.00000008 -5.00000005  3.00000012])=0.9999999999999716
# f([ 3.00000008 -5.00000005  3.00000012])=1.0
# f([ 3.00000008 -5.00000004  3.00000011])=1.0000000000000426
# f([ 3.00000008 -5.00000004  3.00000011])=0.9999999999999716
# f([ 3.00000008 -5.00000004  3.00000011])=1.0
# f([ 3.00000008 -5.00000004  3.00000011])=1.0
# f([ 3.00000008 -5.00000004  3.00000011])=0.9999999999999716
# f([ 3.00000007 -5.00000004  3.0000001 ])=1.0
# f([ 3.00000007 -5.00000004  3.0000001 ])=0.9999999999999858
# f([ 3.00000007 -5.00000004  3.0000001 ])=1.0000000000000568
# f([ 3.00000007 -5.00000004  3.0000001 ])=0.9999999999999716
# f([ 3.00000007 -5.00000004  3.0000001 ])=1.0
# f([ 3.00000007 -5.00000004  3.00000009])=0.9999999999999716
# f([ 3.00000007 -5.00000004  3.00000009])=0.9999999999999858
# f([ 3.00000006 -5.00000004  3.00000009])=0.9999999999999716
# f([ 3.00000006 -5.00000003  3.00000009])=1.0000000000000426
# f([ 3.00000006 -5.00000003  3.00000009])=0.9999999999999858
# f([ 3.00000006 -5.00000003  3.00000009])=1.0
# f([ 3.00000006 -5.00000003  3.00000008])=1.0
# f([ 3.00000006 -5.00000003  3.00000008])=1.0
# f([ 3.00000006 -5.00000003  3.00000008])=1.0000000000000142
# f([ 3.00000006 -5.00000003  3.00000008])=0.9999999999999716
# f([ 3.00000006 -5.00000003  3.00000008])=1.0
# f([ 3.00000005 -5.00000003  3.00000008])=0.999999999999929
# f([ 3.00000005 -5.00000003  3.00000008])=1.0
# f([ 3.00000005 -5.00000003  3.00000007])=0.9999999999999432
# f([ 3.00000005 -5.00000003  3.00000007])=1.0000000000000284
# f([ 3.00000005 -5.00000003  3.00000007])=0.9999999999999858
# f([ 3.00000005 -5.00000003  3.00000007])=1.0000000000000284

# %% [markdown]
# Etude  théorique
# On a dans la base canonique
# $$\nabla f (x) = (14x - 6y - 12z - 36, -6x + 10y + 8z + 44, -12x + 8y + 12z + 40)$$
# Résoudre $\nabla f (x) =0$ donne une solution unique $x_1 = (3,-5,3)$ et $f(x_1)= 1$.

# %% [markdown]
# ## Exercices

# %% [markdown]
# ## ex
# Retrouvez la dérivée de la fonction $f(x) = x^2 + 5x$ sur $\R$ en étudiant $f(x+h)-f(x)$.

# %% [markdown]
# ### ex
# Retrouvez la dérivée de la fonction $f(x) = \frac{1}{x}$ sur $\R^+$ en étudiant $f(x+h)-f(x)$.

# %% [markdown]
# ## ex
# Pour les trois normes définies dans le cours, dessinez la boule unité fermée dans $\R^2$ et remarquez les inclusions (la boule unité est l'ensemble des $x$ tels que $\|x\| \leq 1$).

# %% [markdown]
# ## ex
# Montrez que pour tout $x \in \R^2$ on a
# $$ \|x\|_\infty \leq \|x\|_2 \leq \|x\|_2 \leq 2 \|x\|_\infty $$
# Retrouvez les inclusions de l'exercice précédent.
